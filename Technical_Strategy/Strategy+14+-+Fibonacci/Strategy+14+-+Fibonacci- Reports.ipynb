# %% [markdown]
# # Fibonacci

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get Result

# %% [markdown]
# ## Load results strategy Buy and Hold

# %%
benchmark_D1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
benchmark_H4 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
benckmark_H1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
benckmark_M30 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %% [markdown]
# ## Load results Strategy

# %%
folder_strategy = 'Fibonacci'

# %%
result_D1 = pd.read_csv(f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
result_H4 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
# result_H1 = pd.read_csv(
#     f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
# result_M30 = pd.read_csv(
#     f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %% [markdown]
# ## Define Strategy

# %% [markdown]
# # Reports each time frame

# %% [markdown]
# ## TF D1

# %%
qs.reports.full(result_D1['returns'])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2007-01-01
# End Period                 2023-03-10
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          136.51%
# CAGR﹪                     3.74%
#
# Sharpe                     0.34
# Prob. Sharpe Ratio         94.61%
# Smart Sharpe               0.32
# Sortino                    0.59
# Smart Sortino              0.56
# Sortino/√2                 0.41
# Smart Sortino/√2           0.39
# Omega                      1.15
#
# Max Drawdown               -89.97%
# Longest DD Days            2972
# Volatility (ann.)          56.58%
# Calmar                     0.04
# Skew                       5.32
# Kurtosis                   131.41
#
# Expected Daily %           0.02%
# Expected Monthly %         0.44%
# Expected Yearly %          5.19%
# Kelly Criterion            6.37%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -5.79%
# Expected Shortfall (cVaR)  -5.79%
#
# Max Consecutive Wins       10
# Max Consecutive Losses     11
# Gain/Pain Ratio            0.15
# Gain/Pain (1M)             0.82
#
# Payoff Ratio               1.15
# Profit Factor              1.15
# Common Sense Ratio         1.11
# CPC Index                  0.66
# Tail Ratio                 0.97
# Outlier Win Ratio          8.64
# Outlier Loss Ratio         7.92
#
# MTD                        -0.32%
# 3M                         0.09%
# 6M                         8.11%
# YTD                        0.63%
# 1Y                         4.36%
# 3Y (ann.)                  2.67%
# 5Y (ann.)                  2.94%
# 10Y (ann.)                 1.8%
# All-time (ann.)            3.74%
#
# Best Day                   78.66%
# Worst Day                  -41.14%
# Best Month                 145.6%
# Worst Month                -65.74%
# Best Year                  27.58%
# Worst Year                 -41.75%
#
# Avg. Drawdown              -6.84%
# Avg. Drawdown Days         109
# Recovery Factor            4.29
# Ulcer Index                0.24
# Serenity Index             1.32
#
# Avg. Up Month              8.75%
# Avg. Down Month            -5.61%
# Win Days %                 49.83%
# Win Month %                51.28%
# Win Quarter %              63.08%
# Win Year %                 82.35%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2012-10-05  2013-06-27  2020-11-23  2972    -89.973126        -69.024362
# 2  2011-07-03  2011-09-05  2011-12-27   178    -82.469744        -79.463324
# 3  2007-11-09  2008-03-16  2008-12-14   402    -42.683620        -37.550955
# 4  2011-12-30  2012-06-28  2012-08-22   237    -32.890683        -30.595574
# 5  2020-12-01  2022-10-20  2022-11-14   714    -29.002230        -26.471744
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ### Reports

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_D1['returns'], benchmark=benchmark_D1)
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-10   2007-01-10
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          6.1%         136.51%
# CAGR﹪                     0.25%        3.74%
#
# Sharpe                     0.3          0.34
# Prob. Sharpe Ratio         90.97%       94.61%
# Smart Sharpe               0.29         0.32
# Sortino                    0.41         0.59
# Smart Sortino              0.39         0.56
# Sortino/√2                 0.29         0.41
# Smart Sortino/√2           0.28         0.39
# Omega                      1.15         1.15
#
# Max Drawdown               -4.03%       -89.97%
# Longest DD Days            3259         2972
# Volatility (ann.)          1.0%         56.63%
# R^2                        0.02         0.02
# Information Ratio          0.02         0.02
# Calmar                     0.06         0.04
# Skew                       -0.76        5.32
# Kurtosis                   8.7          131.2
#
# Expected Daily %           0.0%         0.02%
# Expected Monthly %         0.03%        0.44%
# Expected Yearly %          0.35%        5.19%
# Kelly Criterion            4.7%         1.05%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.1%        -5.79%
# Expected Shortfall (cVaR)  -0.1%        -5.79%
#
# Max Consecutive Wins       11           10
# Max Consecutive Losses     9            11
# Gain/Pain Ratio            0.06         0.15
# Gain/Pain (1M)             0.29         0.82
#
# Payoff Ratio               0.96         1.03
# Profit Factor              1.06         1.15
# Common Sense Ratio         1.06         1.11
# CPC Index                  0.54         0.59
# Tail Ratio                 1.0          0.97
# Outlier Win Ratio          131.12       4.39
# Outlier Loss Ratio         97.16        4.05
#
# MTD                        0.03%        -0.32%
# 3M                         0.17%        0.09%
# 6M                         0.55%        8.11%
# YTD                        0.04%        0.63%
# 1Y                         -0.74%       4.36%
# 3Y (ann.)                  0.17%        2.67%
# 5Y (ann.)                  0.33%        2.94%
# 10Y (ann.)                 0.08%        1.8%
# All-time (ann.)            0.25%        3.74%
#
# Best Day                   0.43%        78.66%
# Worst Day                  -0.66%       -41.14%
# Best Month                 1.01%        145.6%
# Worst Month                -0.96%       -65.74%
# Best Year                  1.82%        27.58%
# Worst Year                 -2.23%       -41.75%
#
# Avg. Drawdown              -0.19%       -6.97%
# Avg. Drawdown Days         74           111
# Recovery Factor            1.5          4.29
# Ulcer Index                0.02         0.24
# Serenity Index             0.05         1.32
#
# Avg. Up Month              0.26%        8.48%
# Avg. Down Month            -0.23%       -5.36%
# Win Days %                 53.31%       49.83%
# Win Month %                51.79%       51.28%
# Win Quarter %              64.62%       63.08%
# Win Year %                 64.71%       82.35%
#
# Beta                       -            -7.5
# Alpha                      -            0.22
# Correlation                -            -13.23%
# Treynor Ratio              -            -18.2%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2012-10-05  2013-06-27  2020-11-23  2972    -89.973126        -69.024362
# 2  2011-07-03  2011-09-05  2011-12-27   178    -82.469744        -79.463324
# 3  2007-11-09  2008-03-16  2008-12-14   402    -42.683620        -37.550955
# 4  2011-12-30  2012-06-28  2012-08-22   237    -32.890683        -30.595574
# 5  2020-12-01  2022-10-20  2022-11-14   714    -29.002230        -26.471744
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ## TF H4

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_H4['returns'],benchmark=benchmark_H4)
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-02   2007-01-02
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          6.12%        34.2%
# CAGR﹪                     0.25%        1.26%
#
# Sharpe                     0.14         0.09
# Prob. Sharpe Ratio         91.5%        81.37%
# Smart Sharpe               0.13         0.09
# Sortino                    0.19         0.13
# Smart Sortino              0.19         0.13
# Sortino/√2                 0.13         0.09
# Smart Sortino/√2           0.13         0.09
# Omega                      1.03         1.03
#
# Max Drawdown               -4.04%       -74.76%
# Longest DD Days            3259         4028
# Volatility (ann.)          0.43%        13.28%
# R^2                        0.0          0.0
# Information Ratio          0.01         0.01
# Calmar                     0.06         0.02
# Skew                       -0.19        2.04
# Kurtosis                   15.04        115.73
#
# Expected Daily %           0.0%         0.0%
# Expected Monthly %         0.03%        0.15%
# Expected Yearly %          0.35%        1.75%
# Kelly Criterion            2.54%        2.41%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.04%       -1.37%
# Expected Shortfall (cVaR)  -0.04%       -1.37%
#
# Max Consecutive Wins       10           11
# Max Consecutive Losses     11           11
# Gain/Pain Ratio            0.06         0.06
# Gain/Pain (1M)             0.29         0.27
#
# Payoff Ratio               1.02         1.05
# Profit Factor              1.03         1.03
# Common Sense Ratio         1.03         1.05
# CPC Index                  0.53         0.54
# Tail Ratio                 1.01         1.03
# Outlier Win Ratio          73.98        3.58
# Outlier Loss Ratio         71.9         3.61
#
# MTD                        0.18%        0.73%
# 3M                         0.32%        -15.35%
# 6M                         0.7%         -12.14%
# YTD                        0.19%        -11.43%
# 1Y                         -0.62%       -24.35%
# 3Y (ann.)                  0.2%         -2.16%
# 5Y (ann.)                  0.35%        -7.48%
# 10Y (ann.)                 0.09%        -1.95%
# All-time (ann.)            0.25%        1.26%
#
# Best Day                   0.34%        29.08%
# Worst Day                  -0.36%       -17.29%
# Best Month                 1.01%        49.89%
# Worst Month                -0.96%       -33.84%
# Best Year                  1.82%        40.65%
# Worst Year                 -2.23%       -35.0%
#
# Avg. Drawdown              -0.11%       -3.24%
# Avg. Drawdown Days         32           64
# Recovery Factor            1.49         1.6
# Ulcer Index                0.02         0.25
# Serenity Index             0.02         0.1
#
# Avg. Up Month              0.24%        5.09%
# Avg. Down Month            -0.3%        -4.61%
# Win Days %                 50.8%        49.91%
# Win Month %                51.79%       61.03%
# Win Quarter %              64.62%       63.08%
# Win Year %                 64.71%       58.82%
#
# Beta                       -            -1.5
# Alpha                      -            0.01
# Correlation                -            -4.89%
# Treynor Ratio              -            -22.8%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2012-02-29  2020-02-24  2023-03-10  4028    -74.755232        -52.023399
# 2  2011-10-17  2011-12-29  2012-01-25   101    -33.237122        -28.447398
# 3  2007-11-08  2008-03-17  2008-11-21   379    -27.148209        -22.828476
# 4  2009-01-15  2009-10-14  2010-07-01   532    -19.677015        -17.743890
# 5  2011-03-07  2011-05-02  2011-07-18   133    -15.468222        -13.973726
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_H4['returns'], benchmark=benchmark_H4)
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-02   2007-01-02
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          6.12%        34.2%
# CAGR﹪                     0.25%        1.26%
#
# Sharpe                     0.14         0.09
# Prob. Sharpe Ratio         91.5%        81.37%
# Smart Sharpe               0.13         0.09
# Sortino                    0.19         0.13
# Smart Sortino              0.19         0.13
# Sortino/√2                 0.13         0.09
# Smart Sortino/√2           0.13         0.09
# Omega                      1.03         1.03
#
# Max Drawdown               -4.04%       -74.76%
# Longest DD Days            3259         4028
# Volatility (ann.)          0.43%        13.28%
# R^2                        0.0          0.0
# Information Ratio          0.01         0.01
# Calmar                     0.06         0.02
# Skew                       -0.19        2.04
# Kurtosis                   15.04        115.73
#
# Expected Daily %           0.0%         0.0%
# Expected Monthly %         0.03%        0.15%
# Expected Yearly %          0.35%        1.75%
# Kelly Criterion            2.54%        2.41%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.04%       -1.37%
# Expected Shortfall (cVaR)  -0.04%       -1.37%
#
# Max Consecutive Wins       10           11
# Max Consecutive Losses     11           11
# Gain/Pain Ratio            0.06         0.06
# Gain/Pain (1M)             0.29         0.27
#
# Payoff Ratio               1.02         1.05
# Profit Factor              1.03         1.03
# Common Sense Ratio         1.03         1.05
# CPC Index                  0.53         0.54
# Tail Ratio                 1.01         1.03
# Outlier Win Ratio          73.98        3.58
# Outlier Loss Ratio         71.9         3.61
#
# MTD                        0.18%        0.73%
# 3M                         0.32%        -15.35%
# 6M                         0.7%         -12.14%
# YTD                        0.19%        -11.43%
# 1Y                         -0.62%       -24.35%
# 3Y (ann.)                  0.2%         -2.16%
# 5Y (ann.)                  0.35%        -7.48%
# 10Y (ann.)                 0.09%        -1.95%
# All-time (ann.)            0.25%        1.26%
#
# Best Day                   0.34%        29.08%
# Worst Day                  -0.36%       -17.29%
# Best Month                 1.01%        49.89%
# Worst Month                -0.96%       -33.84%
# Best Year                  1.82%        40.65%
# Worst Year                 -2.23%       -35.0%
#
# Avg. Drawdown              -0.11%       -3.24%
# Avg. Drawdown Days         32           64
# Recovery Factor            1.49         1.6
# Ulcer Index                0.02         0.25
# Serenity Index             0.02         0.1
#
# Avg. Up Month              0.24%        5.09%
# Avg. Down Month            -0.3%        -4.61%
# Win Days %                 50.8%        49.91%
# Win Month %                51.79%       61.03%
# Win Quarter %              64.62%       63.08%
# Win Year %                 64.71%       58.82%
#
# Beta                       -            -1.5
# Alpha                      -            0.01
# Correlation                -            -4.89%
# Treynor Ratio              -            -22.8%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2012-02-29  2020-02-24  2023-03-10  4028    -74.755232        -52.023399
# 2  2011-10-17  2011-12-29  2012-01-25   101    -33.237122        -28.447398
# 3  2007-11-08  2008-03-17  2008-11-21   379    -27.148209        -22.828476
# 4  2009-01-15  2009-10-14  2010-07-01   532    -19.677015        -17.743890
# 5  2011-03-07  2011-05-02  2011-07-18   133    -15.468222        -13.973726
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ## TF H1

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_H1['returns'])

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_H1['returns'], benchmark=benckmark_H1)

# %% [markdown]
# ## TF M30

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_M30['returns'])

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_M30['returns'], benchmark=benckmark_M30)
