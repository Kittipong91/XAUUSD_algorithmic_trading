# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
import os
import matplotlib.style
from pandas.core.common import flatten
from functools import partial, reduce

# %%
import sys
sys.path.append('../../')

# %%
from config.constants import *

# %%
plt.style.use('ggplot')

# %%
pairs_list = [
    'XAUUSD/XAUUSD_H1 - XAUUSD_H1',
]

# %%
df ={}
for pair in range(len(pairs_list)) :
    df[pair] = pd.read_csv(PATH_DATA + SYMBOL['XAUUSD']
                           ['H1'] + '.csv', index_col='Time', parse_dates=True)
    df[pair]['Day'] = df[pair].index.dayofweek
    dmap = {0: 'Mon', 1: 'Tue', 2: 'Wed', 3: 'Thu', 4: 'Fri', 5: 'Sat', 6: 'Sun'}
    df[pair]['Day'] = df[pair]['Day'].map(dmap)
    df[pair].index = pd.to_datetime(df[pair].index, format = '%Y-%m-%d %H:%M:%S.%f')

# %%
df[0]
# Out:
#                          Open      High       Low     Close  Volume  Day  \
# Time
# 2007-01-01 00:00:00   635.679   636.194   635.306   635.624      20  Mon
# 2007-01-01 01:00:00   635.784   636.059   635.102   635.838      21  Mon
# 2007-01-01 02:00:00   635.375   636.154   635.196   636.089      27  Mon
# 2007-01-01 03:00:00   636.025   636.163   635.009   635.497      27  Mon
# 2007-01-01 04:00:00   635.336   636.169   635.287   635.608      22  Mon
# ...                       ...       ...       ...       ...     ...  ...
# 2023-03-10 13:00:00  1836.545  1844.878  1831.384  1842.385      60  Fri
# 2023-03-10 14:00:00  1842.375  1860.225  1839.885  1858.274      60  Fri
# 2023-03-10 15:00:00  1858.278  1867.348  1857.548  1862.975      60  Fri
# 2023-03-10 16:00:00  1862.985  1863.915  1854.005  1855.215      60  Fri
# 2023-03-10 17:00:00  1855.225  1865.005  1854.855  1864.098      60  Fri
#
#                          ATR  london_opening  spread     size
# Time
# 2007-01-01 00:00:00      NaN           False  0.0002  10000.0
# 2007-01-01 01:00:00      NaN           False  0.0002  10000.0
# 2007-01-01 02:00:00      NaN           False  0.0002  10000.0
# 2007-01-01 03:00:00      NaN           False  0.0002  10000.0
# 2007-01-01 04:00:00      NaN           False  0.0002  10000.0
# ...                      ...             ...     ...      ...
# 2023-03-10 13:00:00  4.22120           False  0.0002  10000.0
# 2023-03-10 14:00:00  5.03970           False  0.0002  10000.0
# 2023-03-10 15:00:00  5.19205           False  0.0002  10000.0
# 2023-03-10 16:00:00  5.45840           False  0.0002  10000.0
# 2023-03-10 17:00:00  5.83390           False  0.0002  10000.0
#
# [97954 rows x 10 columns]

# %%
#Strategy parameters
account_size = 1000
slippage = 2
size = 1
ATR_SL = 0.5
entry_time = 8

# %%
def ATR(df, n):
    df = df.copy()
    df['High-Low'] = abs(df['High'] - df['Low'])
    df['High-PrevClose'] = abs(df['High'] - df['Close'].shift(1))
    df['Low-PrevClose'] = abs(df['Low'] - df['Close'].shift(1))
    df['TR'] = df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis = 1, skipna = False)
    df['ATR'] = df['TR'].rolling(n).mean()
    df = df.drop(['High-Low', 'High-PrevClose', 'Low-PrevClose'], axis = 1)
    return df

def CAGR(df, source_df):
    df = df.copy()
    n = len(source_df) / (252*24)
    return round((((df['cum_res'][-1] / account_size)**(1/n)) - 1) * 100, 1)

def sharpe_ratio(df):
    df = df.copy()
    returns = df['cum_res'].pct_change()
    volatility = returns.std() * np.sqrt(252)
    return round((returns.mean() - 0.02) / volatility, 2)

def max_drawdown(df):
    df = df.copy()
    cum_returns = (1 + df['cum_res']).cumprod()
    drawdown = 1 - df['cum_res'].div(df['cum_res'].cummax())
    return round(max(drawdown.expanding().max() * 100), 2)

# %%
for pair in range(len(pairs_list)):
    df[pair]['ATR'] = ATR(df[pair], 20)['ATR']
    df[pair]['london_opening'] = np.where((df[pair].index.hour + 1) == entry_time, True, False)
    if 'JPY' not in pairs_list[pair]:
        df[pair]['spread'] = float(slippage) / float(10000)
        df[pair]['size'] = float(size) * float(10000)
        print('Pair: ', pairs_list[pair], 'a')
    else:
        df[pair]['spread'] = float(slippage) / float(100)
        df[pair]['size'] = float(size) * float(100)
        print('Pair: ', pairs_list[pair], 'b')
# Out:
# Pair:  XAUUSD/XAUUSD_H1 - XAUUSD_H1 a

# %%
open_trade = {}
trade = {}
long_take_profit = {}
short_take_profit = {}
long_stop_loss = {}
short_stop_loss = {}
long_entry_price = {}
short_entry_price = {}

for pair in range(len(pairs_list)):
    open_trade[pair] = []
    trade[pair] = {}
    long_take_profit[pair] = []
    short_take_profit[pair] = []
    long_stop_loss[pair] = []
    short_stop_loss[pair] = []
    long_entry_price[pair] = []
    short_entry_price[pair] = []
    
    for i in range(50, len(df[pair])):
        #Buy
        if df[pair]['london_opening'][i] == True and df[pair]['Close'][i] >= df[pair]['Close'].rolling(8).max()[i] and len(open_trade[pair]) == 0:
            print(i, 'New Long trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                              'date_of_trade': df[pair].index[i],
                              'day_of_trade': df[pair]['Day'][i],
                              'entry_price': df[pair]['Close'][i],
                              'signal': 'Buy',
                              'result': 0,
                              'TP': df[pair]['Close'][i] + df[pair]['ATR'][i] * 5 * ATR_SL,
                              'SL': df[pair]['Close'][i] - df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            long_take_profit[pair].append(trade[pair][i]['TP'])
            long_stop_loss[pair].append(trade[pair][i]['SL'])
            long_entry_price[pair].append(trade[pair][i]['entry_price'])
        
        #Sell
        if df[pair]['london_opening'][i] == True and df[pair]['Close'][i] <= df[pair]['Close'].rolling(8).min()[i] and len(open_trade[pair]) == 0:
            print(i, 'New Short trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                              'date_of_trade': df[pair].index[i],
                              'day_of_trade': df[pair]['Day'][i],
                              'entry_price': df[pair]['Close'][i],
                              'signal': 'Sell',
                              'result': 0,
                              'TP': df[pair]['Close'][i] - df[pair]['ATR'][i] * 5 * ATR_SL,
                              'SL': df[pair]['Close'][i] + df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            short_take_profit[pair].append(trade[pair][i]['TP'])
            short_stop_loss[pair].append(trade[pair][i]['SL'])
            short_entry_price[pair].append(trade[pair][i]['entry_price'])
            
        #Exit trades---------------------------------------------------------------------------
        #Buy Trailing SL
        if any(y <= df[pair]['Close'][i] for y in long_entry_price[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    #Move SL to BE
                    if df[pair]['Close'][i] >= trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * ATR_SL):
                        long_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] + df[pair]['spread'][i]})
                        print(j, 
                             'Moved SL to BE:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        long_entry_price[pair] = []
                        long_stop_loss[pair].append(trade[pair][j]['SL'])
                    #Move SL to first ATR
                    if df[pair]['Close'][i] >= trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * 2 * ATR_SL):
                        long_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * ATR_SL)})
                        print(j, 
                             'Trailing SL to first ATR:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        long_stop_loss[pair].append(trade[pair][j]['SL'])
                    #Move SL to second ATR
                    if df[pair]['Close'][i] >= trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * 3 * ATR_SL):
                        long_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * 2 * ATR_SL)})
                        print(j, 
                             'Trailing SL to first ATR:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        long_stop_loss[pair].append(trade[pair][j]['SL'])
        #Sell Trailing SL
        if any(y >= df[pair]['Close'][i] for y in short_entry_price[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    #Move SL to BE
                    if df[pair]['Close'][i] <= trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * ATR_SL):
                        short_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] - df[pair]['spread'][i]})
                        print(j, 
                             'Moved SL to BE:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        short_entry_price[pair] = []
                        short_stop_loss[pair].append(trade[pair][j]['SL'])
                    #Move SL to first ATR
                    if df[pair]['Close'][i] <= trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * 2 * ATR_SL):
                        short_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * ATR_SL)})
                        print(j, 
                             'Trailing SL to first ATR:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        short_stop_loss[pair].append(trade[pair][j]['SL'])
                    #Move SL to first ATR
                    if df[pair]['Close'][i] <= trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * 3 * ATR_SL):
                        short_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * 2 * ATR_SL)})
                        print(j, 
                             'Trailing SL to first ATR:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        short_stop_loss[pair].append(trade[pair][j]['SL'])
                        
        #Buy profit
        if any(y <= df[pair]['Close'][i] for y in long_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] >= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['TP'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Buy loss
        if any(y >= df[pair]['Close'][i] for y in long_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] <= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['SL'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
                        
        #Sell profit
        if any(y >= df[pair]['Close'][i] for y in short_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] <= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['TP'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Sell loss
        if any(y <= df[pair]['Close'][i] for y in short_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] >= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['SL'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Exit after time
        if len(open_trade[pair]) != 0:
            for j in open_trade[pair]:
                if (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    trade[pair][j].update({'result' : (df[pair]['Close'][i] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Long exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    long_take_profit[pair].remove(trade[pair][j]['TP'])
                    long_stop_loss[pair].remove(trade[pair][j]['SL'])
                elif (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - df[pair]['Close'][i] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Short exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    short_take_profit[pair].remove(trade[pair][j]['TP'])
                    short_stop_loss[pair].remove(trade[pair][j]['SL'])
# Out:
# 127 New Short trade at price: 606.916  On day: 2007-01-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 127 Moved SL to BE: 606.9158 On day: 2007-01-08 16:00:00
#
# 127 Short loss at price: 607.107 On day: 2007-01-08 17:00:00 With loss: -0.0
#
# 175 New Long trade at price: 612.39  On day: 2007-01-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 175 Long loss at price: 610.322 On day: 2007-01-10 08:00:00 With loss: -12803.75
#
# 199 New Long trade at price: 611.489  On day: 2007-01-11 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 199 Moved SL to BE: 611.4892 On day: 2007-01-11 12:00:00
#
# 199 Long loss at price: 611.488 On day: 2007-01-11 19:00:00 With loss: -0.0
#
# 223 New Long trade at price: 613.097  On day: 2007-01-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 223 Long loss at price: 611.832 On day: 2007-01-12 12:00:00 With loss: -11768.0
#
# 271 New Long trade at price: 626.049  On day: 2007-01-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 271 Long loss at price: 624.429 On day: 2007-01-16 08:00:00 With loss: -8145.0
#
# 319 New Short trade at price: 632.052  On day: 2007-01-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 319 Short loss at price: 633.757 On day: 2007-01-18 08:00:00 With loss: -12976.0
#
# 367 New Short trade at price: 634.158  On day: 2007-01-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 367 Moved SL to BE: 634.1578 On day: 2007-01-22 09:00:00
#
# 367 Short loss at price: 634.565 On day: 2007-01-22 11:00:00 With loss: -0.0
#
# 391 New Long trade at price: 635.363  On day: 2007-01-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 391 Moved SL to BE: 635.3632 On day: 2007-01-23 10:00:00
#
# 391 Long profit at price: 642.936 On day: 2007-01-23 13:00:00 With profit: 58679.25
#
# 415 New Short trade at price: 641.656  On day: 2007-01-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 415 Short loss at price: 643.703 On day: 2007-01-24 10:00:00 With loss: -13114.0
#
# 487 New Short trade at price: 644.146  On day: 2007-01-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 487 Moved SL to BE: 644.1458 On day: 2007-01-29 09:00:00
#
# 487 Trailing SL to first ATR: 643.0624 On day: 2007-01-29 09:00:00
#
# 487 Short loss at price: 644.551 On day: 2007-01-29 14:00:00 With loss: 10833.75
#
# 583 New Long trade at price: 655.906  On day: 2007-02-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 583 Long loss at price: 653.166 On day: 2007-02-02 09:00:00 With loss: -13294.75
#
# 607 New Short trade at price: 646.095  On day: 2007-02-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 607 Short loss at price: 647.917 On day: 2007-02-05 08:00:00 With loss: -13101.5
#
# 631 New Long trade at price: 650.21  On day: 2007-02-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 631 Moved SL to BE: 650.2102 On day: 2007-02-06 09:00:00
#
# 631 Long profit at price: 656.156 On day: 2007-02-06 13:00:00 With profit: 51499.25
#
# 679 New Short trade at price: 651.135  On day: 2007-02-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 679 Moved SL to BE: 651.1348 On day: 2007-02-08 08:00:00
#
# 679 Trailing SL to first ATR: 650.0769 On day: 2007-02-08 08:00:00
#
# 679 Short loss at price: 650.801 On day: 2007-02-08 13:00:00 With loss: 10579.0
#
# 703 New Long trade at price: 658.92  On day: 2007-02-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 703 Long loss at price: 656.518 On day: 2007-02-09 12:00:00 With loss: -12150.75
#
# 751 New Long trade at price: 663.656  On day: 2007-02-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 751 Moved SL to BE: 663.6562 On day: 2007-02-13 08:00:00
#
# 751 Long loss at price: 663.319 On day: 2007-02-13 15:00:00 With loss: -0.0
#
# 775 New Long trade at price: 668.147  On day: 2007-02-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 775 Long loss at price: 666.248 On day: 2007-02-14 14:00:00 With loss: -11803.5
#
# 823 New Short trade at price: 666.011  On day: 2007-02-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 823 Moved SL to BE: 666.0108 On day: 2007-02-16 09:00:00
#
# 823 Short loss at price: 666.841 On day: 2007-02-16 16:00:00 With loss: -0.0
#
# 871 New Short trade at price: 669.11  On day: 2007-02-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 871 Moved SL to BE: 669.1098 On day: 2007-02-20 10:00:00
#
# 871 Trailing SL to first ATR: 668.2632 On day: 2007-02-20 10:00:00
#
# 871 Short profit at price: 664.83 On day: 2007-02-20 11:00:00 With profit: 40778.0
#
# 943 New Long trade at price: 675.898  On day: 2007-02-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 943 Moved SL to BE: 675.8982 On day: 2007-02-23 11:00:00
#
# 943 Long profit at price: 682.74 On day: 2007-02-23 14:00:00 With profit: 62749.25
#
# 991 New Short trade at price: 682.451  On day: 2007-02-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 991 Short loss at price: 684.79 On day: 2007-02-27 08:00:00 With loss: -11575.75
#
# 1015 New Long trade at price: 672.183  On day: 2007-02-28 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1015 Moved SL to BE: 672.1832 On day: 2007-02-28 09:00:00
#
# 1015 Long loss at price: 668.998 On day: 2007-02-28 13:00:00 With loss: -0.0
#
# 1039 New Short trade at price: 670.431  On day: 2007-03-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1039 Short loss at price: 673.273 On day: 2007-03-01 09:00:00 With loss: -19463.75
#
# 1063 New Long trade at price: 661.616  On day: 2007-03-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1063 Long loss at price: 658.448 On day: 2007-03-02 12:00:00 With loss: -19198.5
#
# 1111 New Long trade at price: 644.112  On day: 2007-03-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1111 Long loss at price: 641.837 On day: 2007-03-06 15:00:00 With loss: -18809.75
#
# 1135 New Short trade at price: 642.912  On day: 2007-03-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1135 Short loss at price: 644.348 On day: 2007-03-07 09:00:00 With loss: -13690.25
#
# 1183 New Long trade at price: 652.698  On day: 2007-03-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1183 Moved SL to BE: 652.6982 On day: 2007-03-09 13:00:00
#
# 1183 Trailing SL to first ATR: 653.8288 On day: 2007-03-09 13:00:00
#
# 1183 Long loss at price: 652.319 On day: 2007-03-09 14:00:00 With loss: 11305.5
#
# 1208 New Long trade at price: 653.076  On day: 2007-03-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1208 Long loss at price: 651.128 On day: 2007-03-12 10:00:00 With loss: -13054.25
#
# 1256 New Long trade at price: 642.133  On day: 2007-03-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1256 Long loss at price: 638.766 On day: 2007-03-14 10:00:00 With loss: -13490.0
#
# 1328 New Long trade at price: 655.471  On day: 2007-03-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1328 Long loss at price: 652.97 On day: 2007-03-19 10:00:00 With loss: -12349.5
#
# 1352 New Short trade at price: 653.513  On day: 2007-03-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1352 Short loss at price: 659.748 On day: 2007-03-20 12:00:00 With loss: -10494.0
#
# 1376 New Long trade at price: 659.913  On day: 2007-03-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1376 Moved SL to BE: 659.9132 On day: 2007-03-21 10:00:00
#
# 1376 Long loss at price: 659.57 On day: 2007-03-21 12:00:00 With loss: -0.0
#
# 1400 New Long trade at price: 664.342  On day: 2007-03-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1400 Long loss at price: 662.305 On day: 2007-03-22 16:00:00 With loss: -11895.75
#
# 1448 New Short trade at price: 658.399  On day: 2007-03-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1448 Short loss at price: 659.659 On day: 2007-03-26 11:00:00 With loss: -10042.0
#
# 1520 New Short trade at price: 664.248  On day: 2007-03-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1520 Moved SL to BE: 664.2478 On day: 2007-03-29 12:00:00
#
# 1520 Trailing SL to first ATR: 663.3835 On day: 2007-03-29 12:00:00
#
# 1520 Trailing SL to first ATR: 662.519 On day: 2007-03-29 12:00:00
#
# 1520 Short profit at price: 659.645 On day: 2007-03-29 12:00:00 With profit: 43444.25
#
# 1616 New Long trade at price: 665.498  On day: 2007-04-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1616 Moved SL to BE: 665.4982 On day: 2007-04-04 12:00:00
#
# 1616 Trailing SL to first ATR: 666.365 On day: 2007-04-04 12:00:00
#
# 1616 Trailing SL to first ATR: 667.232 On day: 2007-04-04 12:00:00
#
# 1616 Long profit at price: 671.048 On day: 2007-04-04 13:00:00 With profit: 50649.25
#
# 1664 New Long trade at price: 673.57  On day: 2007-04-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1664 Long exited after 12 hours: 673.387 On day: 2007-04-06 19:00:00 With profit: -1832.0
#
# 1688 New Long trade at price: 672.053  On day: 2007-04-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1688 Moved SL to BE: 672.0532 On day: 2007-04-09 10:00:00
#
# 1688 Long profit at price: 675.212 On day: 2007-04-09 13:00:00 With profit: 21756.75
#
# 1712 New Long trade at price: 676.395  On day: 2007-04-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1712 Moved SL to BE: 676.3952 On day: 2007-04-10 12:00:00
#
# 1712 Trailing SL to first ATR: 677.3571 On day: 2007-04-10 12:00:00
#
# 1712 Trailing SL to first ATR: 678.3192 On day: 2007-04-10 12:00:00
#
# 1712 Long loss at price: 677.463 On day: 2007-04-10 13:00:00 With loss: 19240.0
#
# 1736 New Long trade at price: 676.833  On day: 2007-04-11 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1736 Moved SL to BE: 676.8332 On day: 2007-04-11 09:00:00
#
# 1736 Long loss at price: 676.073 On day: 2007-04-11 14:00:00 With loss: -0.0
#
# 1760 New Long trade at price: 678.895  On day: 2007-04-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1760 Long loss at price: 677.147 On day: 2007-04-12 10:00:00 With loss: -9821.75
#
# 1808 New Long trade at price: 687.491  On day: 2007-04-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1808 Long loss at price: 685.151 On day: 2007-04-16 13:00:00 With loss: -10880.75
#
# 1832 New Short trade at price: 687.22  On day: 2007-04-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1832 Moved SL to BE: 687.2198 On day: 2007-04-17 09:00:00
#
# 1832 Short loss at price: 687.822 On day: 2007-04-17 10:00:00 With loss: -0.0
#
# 1856 New Long trade at price: 690.122  On day: 2007-04-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1856 Long loss at price: 688.595 On day: 2007-04-18 10:00:00 With loss: -9367.75
#
# 1904 New Long trade at price: 685.095  On day: 2007-04-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1904 Moved SL to BE: 685.0952 On day: 2007-04-20 09:00:00
#
# 1904 Trailing SL to first ATR: 686.0698 On day: 2007-04-20 09:00:00
#
# 1904 Long profit at price: 692.42 On day: 2007-04-20 11:00:00 With profit: 55880.5
#
# 1952 New Long trade at price: 688.598  On day: 2007-04-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1952 Moved SL to BE: 688.5982 On day: 2007-04-24 09:00:00
#
# 1952 Long loss at price: 688.25 On day: 2007-04-24 13:00:00 With loss: -0.0
#
# 1976 New Long trade at price: 685.193  On day: 2007-04-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 1976 Long loss at price: 682.817 On day: 2007-04-25 15:00:00 With loss: -9647.75
#
# 2048 New Short trade at price: 677.054  On day: 2007-04-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2048 Short loss at price: 677.897 On day: 2007-04-30 10:00:00 With loss: -8052.0
#
# 2096 New Short trade at price: 671.787  On day: 2007-05-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2096 Short loss at price: 673.252 On day: 2007-05-02 08:00:00 With loss: -8518.75
#
# 2120 New Long trade at price: 674.58  On day: 2007-05-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2120 Moved SL to BE: 674.5802 On day: 2007-05-03 08:00:00
#
# 2120 Long loss at price: 673.893 On day: 2007-05-03 13:00:00 With loss: -0.0
#
# 2144 New Short trade at price: 680.582  On day: 2007-05-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2144 Short loss at price: 682.706 On day: 2007-05-04 11:00:00 With loss: -8078.5
#
# 2192 New Short trade at price: 686.588  On day: 2007-05-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2192 Moved SL to BE: 686.5878 On day: 2007-05-08 10:00:00
#
# 2192 Short exited after 12 hours: 684.174 On day: 2007-05-08 19:00:00 With profit: 24138.0
#
# 2240 New Short trade at price: 678.319  On day: 2007-05-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2240 Moved SL to BE: 678.3188 On day: 2007-05-10 09:00:00
#
# 2240 Short profit at price: 673.588 On day: 2007-05-10 12:00:00 With profit: 45511.75
#
# 2288 New Long trade at price: 673.903  On day: 2007-05-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2288 Long loss at price: 672.42 On day: 2007-05-14 09:00:00 With loss: -8835.75
#
# 2312 New Short trade at price: 667.703  On day: 2007-05-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2312 Moved SL to BE: 667.7028 On day: 2007-05-15 09:00:00
#
# 2312 Short loss at price: 670.324 On day: 2007-05-15 12:00:00 With loss: -0.0
#
# 2336 New Short trade at price: 671.229  On day: 2007-05-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2336 Moved SL to BE: 671.2288 On day: 2007-05-16 08:00:00
#
# 2336 Short profit at price: 665.931 On day: 2007-05-16 15:00:00 With profit: 44519.25
#
# 2384 New Long trade at price: 659.864  On day: 2007-05-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2384 Moved SL to BE: 659.8642 On day: 2007-05-18 08:00:00
#
# 2384 Long loss at price: 657.687 On day: 2007-05-18 10:00:00 With loss: -0.0
#
# 2408 New Short trade at price: 660.885  On day: 2007-05-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2408 Moved SL to BE: 660.8848 On day: 2007-05-21 10:00:00
#
# 2408 Trailing SL to first ATR: 660.175 On day: 2007-05-21 10:00:00
#
# 2408 Short loss at price: 660.869 On day: 2007-05-21 14:00:00 With loss: 7097.5
#
# 2432 New Long trade at price: 664.522  On day: 2007-05-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2432 Long loss at price: 662.787 On day: 2007-05-22 09:00:00 With loss: -8564.0
#
# 2480 New Short trade at price: 660.322  On day: 2007-05-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2480 Short loss at price: 661.287 On day: 2007-05-24 09:00:00 With loss: -9041.25
#
# 2504 New Short trade at price: 653.67  On day: 2007-05-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2504 Short loss at price: 655.113 On day: 2007-05-25 08:00:00 With loss: -10580.0
#
# 2552 New Short trade at price: 653.97  On day: 2007-05-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2552 Short loss at price: 656.913 On day: 2007-05-29 08:00:00 With loss: -5186.5
#
# 2576 New Short trade at price: 656.022  On day: 2007-05-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2576 Short loss at price: 657.195 On day: 2007-05-30 08:00:00 With loss: -10906.0
#
# 2696 New Short trade at price: 670.177  On day: 2007-06-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2696 Moved SL to BE: 670.1768 On day: 2007-06-06 09:00:00
#
# 2696 Trailing SL to first ATR: 669.4187 On day: 2007-06-06 09:00:00
#
# 2696 Short loss at price: 670.172 On day: 2007-06-06 13:00:00 With loss: 7581.25
#
# 2744 New Short trade at price: 657.27  On day: 2007-06-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2744 Moved SL to BE: 657.2698 On day: 2007-06-08 09:00:00
#
# 2744 Trailing SL to first ATR: 656.0444 On day: 2007-06-08 09:00:00
#
# 2744 Short profit at price: 650.797 On day: 2007-06-08 14:00:00 With profit: 61193.0
#
# 2768 New Long trade at price: 651.418  On day: 2007-06-11 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2768 Long loss at price: 649.938 On day: 2007-06-11 13:00:00 With loss: -11457.0
#
# 2792 New Short trade at price: 652.32  On day: 2007-06-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2792 Moved SL to BE: 652.3198 On day: 2007-06-12 10:00:00
#
# 2792 Short profit at price: 647.348 On day: 2007-06-12 13:00:00 With profit: 39878.0
#
# 2816 New Short trade at price: 645.397  On day: 2007-06-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2816 Moved SL to BE: 645.3968 On day: 2007-06-13 10:00:00
#
# 2816 Short loss at price: 646.787 On day: 2007-06-13 12:00:00 With loss: -0.0
#
# 2912 New Short trade at price: 655.172  On day: 2007-06-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2912 Moved SL to BE: 655.1718 On day: 2007-06-19 09:00:00
#
# 2912 Short loss at price: 657.413 On day: 2007-06-19 13:00:00 With loss: -0.0
#
# 2936 New Short trade at price: 659.347  On day: 2007-06-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2936 Short loss at price: 660.463 On day: 2007-06-20 11:00:00 With loss: -9068.0
#
# 2984 New Long trade at price: 651.67  On day: 2007-06-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 2984 Moved SL to BE: 651.6702 On day: 2007-06-22 10:00:00
#
# 2984 Long exited after 12 hours: 653.048 On day: 2007-06-22 19:00:00 With profit: 13778.0
#
# 3008 New Short trade at price: 651.502  On day: 2007-06-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3008 Moved SL to BE: 651.5018 On day: 2007-06-25 09:00:00
#
# 3008 Short loss at price: 651.712 On day: 2007-06-25 11:00:00 With loss: -0.0
#
# 3032 New Short trade at price: 648.62  On day: 2007-06-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3032 Moved SL to BE: 648.6198 On day: 2007-06-26 12:00:00
#
# 3032 Short profit at price: 643.797 On day: 2007-06-26 14:00:00 With profit: 39139.25
#
# 3056 New Short trade at price: 640.847  On day: 2007-06-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3056 Short loss at price: 642.223 On day: 2007-06-27 08:00:00 With loss: -11280.5
#
# 3128 New Long trade at price: 651.3  On day: 2007-07-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3128 Long loss at price: 650.429 On day: 2007-07-02 09:00:00 With loss: -8331.25
#
# 3200 New Long trade at price: 655.372  On day: 2007-07-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3200 Long loss at price: 651.913 On day: 2007-07-05 13:00:00 With loss: -4721.75
#
# 3224 New Short trade at price: 647.57  On day: 2007-07-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3224 Moved SL to BE: 647.5698 On day: 2007-07-06 10:00:00
#
# 3224 Short loss at price: 648.22 On day: 2007-07-06 11:00:00 With loss: -0.0
#
# 3272 New Long trade at price: 660.02  On day: 2007-07-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3272 Moved SL to BE: 660.0202 On day: 2007-07-10 08:00:00
#
# 3272 Long profit at price: 663.954 On day: 2007-07-10 14:00:00 With profit: 38183.0
#
# 3320 New Long trade at price: 663.27  On day: 2007-07-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3320 Moved SL to BE: 663.2702 On day: 2007-07-12 10:00:00
#
# 3320 Long profit at price: 668.197 On day: 2007-07-12 14:00:00 With profit: 39085.5
#
# 3344 New Long trade at price: 667.472  On day: 2007-07-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3344 Long loss at price: 666.637 On day: 2007-07-13 09:00:00 With loss: -7515.25
#
# 3368 New Long trade at price: 667.231  On day: 2007-07-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3368 Moved SL to BE: 667.2312 On day: 2007-07-16 11:00:00
#
# 3368 Long loss at price: 666.768 On day: 2007-07-16 12:00:00 With loss: -0.0
#
# 3392 New Short trade at price: 664.372  On day: 2007-07-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3392 Moved SL to BE: 664.3718 On day: 2007-07-17 09:00:00
#
# 3392 Trailing SL to first ATR: 663.7357 On day: 2007-07-17 09:00:00
#
# 3392 Short loss at price: 665.148 On day: 2007-07-17 12:00:00 With loss: 6361.25
#
# 3440 New Short trade at price: 670.722  On day: 2007-07-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3440 Short loss at price: 673.323 On day: 2007-07-19 08:00:00 With loss: -9143.75
#
# 3488 New Long trade at price: 683.922  On day: 2007-07-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3488 Long loss at price: 682.359 On day: 2007-07-23 08:00:00 With loss: -9049.25
#
# 3536 New Short trade at price: 677.897  On day: 2007-07-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3536 Moved SL to BE: 677.8968 On day: 2007-07-25 08:00:00
#
# 3536 Short profit at price: 671.598 On day: 2007-07-25 14:00:00 With profit: 47606.75
#
# 3584 New Short trade at price: 662.922  On day: 2007-07-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3584 Moved SL to BE: 662.9218 On day: 2007-07-27 11:00:00
#
# 3584 Trailing SL to first ATR: 661.7101 On day: 2007-07-27 11:00:00
#
# 3584 Trailing SL to first ATR: 660.4982 On day: 2007-07-27 11:00:00
#
# 3584 Short loss at price: 660.698 On day: 2007-07-27 12:00:00 With loss: 24235.5
#
# 3608 New Long trade at price: 661.868  On day: 2007-07-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3608 Long loss at price: 660.529 On day: 2007-07-30 13:00:00 With loss: -10147.25
#
# 3752 New Short trade at price: 669.62  On day: 2007-08-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3752 Moved SL to BE: 669.6198 On day: 2007-08-07 11:00:00
#
# 3752 Short loss at price: 669.797 On day: 2007-08-07 14:00:00 With loss: -0.0
#
# 3776 New Short trade at price: 669.797  On day: 2007-08-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3776 Moved SL to BE: 669.7968 On day: 2007-08-08 09:00:00
#
# 3776 Short loss at price: 670.822 On day: 2007-08-08 10:00:00 With loss: -0.0
#
# 3824 New Long trade at price: 664.122  On day: 2007-08-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3824 Long loss at price: 661.648 On day: 2007-08-10 10:00:00 With loss: -11214.25
#
# 3872 New Short trade at price: 667.522  On day: 2007-08-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3872 Moved SL to BE: 667.5218 On day: 2007-08-14 12:00:00
#
# 3872 Trailing SL to first ATR: 666.86 On day: 2007-08-14 12:00:00
#
# 3872 Short loss at price: 668.863 On day: 2007-08-14 13:00:00 With loss: 6618.0
#
# 3896 New Short trade at price: 664.744  On day: 2007-08-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3896 Moved SL to BE: 664.7438 On day: 2007-08-15 10:00:00
#
# 3896 Short loss at price: 666.997 On day: 2007-08-15 13:00:00 With loss: -0.0
#
# 3944 New Long trade at price: 649.97  On day: 2007-08-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3944 Moved SL to BE: 649.9702 On day: 2007-08-17 08:00:00
#
# 3944 Long exited after 12 hours: 657.045 On day: 2007-08-17 19:00:00 With profit: 70748.0
#
# 3968 New Long trade at price: 657.79  On day: 2007-08-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3968 Long loss at price: 656.387 On day: 2007-08-20 12:00:00 With loss: -12809.25
#
# 3992 New Short trade at price: 657.069  On day: 2007-08-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 3992 Moved SL to BE: 657.0688 On day: 2007-08-21 09:00:00
#
# 3992 Short loss at price: 658.89 On day: 2007-08-21 11:00:00 With loss: -0.0
#
# 4016 New Long trade at price: 656.913  On day: 2007-08-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4016 Moved SL to BE: 656.9132 On day: 2007-08-22 10:00:00
#
# 4016 Long profit at price: 661.255 On day: 2007-08-22 14:00:00 With profit: 43051.75
#
# 4208 New Long trade at price: 672.799  On day: 2007-09-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4208 Long loss at price: 672.076 On day: 2007-09-03 11:00:00 With loss: -6333.75
#
# 4256 New Short trade at price: 679.119  On day: 2007-09-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4256 Short loss at price: 681.404 On day: 2007-09-05 14:00:00 With loss: -8218.0
#
# 4280 New Long trade at price: 684.651  On day: 2007-09-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4280 Long loss at price: 683.738 On day: 2007-09-06 08:00:00 With loss: -7872.0
#
# 4304 New Short trade at price: 692.775  On day: 2007-09-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4304 Short loss at price: 694.394 On day: 2007-09-07 08:00:00 With loss: -10791.75
#
# 4328 New Long trade at price: 705.186  On day: 2007-09-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4328 Long loss at price: 703.254 On day: 2007-09-10 09:00:00 With loss: -12264.75
#
# 4400 New Short trade at price: 707.876  On day: 2007-09-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4400 Moved SL to BE: 707.8758 On day: 2007-09-13 10:00:00
#
# 4400 Trailing SL to first ATR: 707.0215 On day: 2007-09-13 10:00:00
#
# 4400 Trailing SL to first ATR: 706.1671 On day: 2007-09-13 10:00:00
#
# 4400 Short loss at price: 706.294 On day: 2007-09-13 11:00:00 With loss: 17087.0
#
# 4424 New Short trade at price: 704.14  On day: 2007-09-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4424 Short loss at price: 705.359 On day: 2007-09-14 09:00:00 With loss: -8886.75
#
# 4472 New Long trade at price: 716.617  On day: 2007-09-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4472 Moved SL to BE: 716.6172 On day: 2007-09-18 09:00:00
#
# 4472 Long loss at price: 715.493 On day: 2007-09-18 13:00:00 With loss: -0.0
#
# 4496 New Short trade at price: 721.742  On day: 2007-09-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4496 Short loss at price: 724.755 On day: 2007-09-19 08:00:00 With loss: -13483.75
#
# 4520 New Long trade at price: 726.499  On day: 2007-09-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4520 Moved SL to BE: 726.4992 On day: 2007-09-20 08:00:00
#
# 4520 Trailing SL to first ATR: 727.4772 On day: 2007-09-20 08:00:00
#
# 4520 Trailing SL to first ATR: 728.4554 On day: 2007-09-20 08:00:00
#
# 4520 Long loss at price: 726.999 On day: 2007-09-20 09:00:00 With loss: 19562.0
#
# 4592 New Short trade at price: 723.842  On day: 2007-09-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4592 Short loss at price: 727.038 On day: 2007-09-25 08:00:00 With loss: -13279.25
#
# 4712 New Short trade at price: 733.42  On day: 2007-10-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4712 Short loss at price: 735.063 On day: 2007-10-02 08:00:00 With loss: -12298.25
#
# 4784 New Short trade at price: 734.248  On day: 2007-10-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4784 Short loss at price: 735.948 On day: 2007-10-05 10:00:00 With loss: -13540.0
#
# 4808 New Short trade at price: 737.48  On day: 2007-10-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4808 Moved SL to BE: 737.4798 On day: 2007-10-08 08:00:00
#
# 4808 Short exited after 12 hours: 732.769 On day: 2007-10-08 19:00:00 With profit: 47108.0
#
# 4832 New Long trade at price: 731.889  On day: 2007-10-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4832 Long loss at price: 729.69 On day: 2007-10-09 08:00:00 With loss: -8662.0
#
# 4880 New Long trade at price: 745.406  On day: 2007-10-11 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4880 Moved SL to BE: 745.4062 On day: 2007-10-11 08:00:00
#
# 4880 Long profit at price: 750.521 On day: 2007-10-11 15:00:00 With profit: 45280.5
#
# 4904 New Long trade at price: 747.873  On day: 2007-10-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4904 Long loss at price: 746.545 On day: 2007-10-12 09:00:00 With loss: -12057.0
#
# 4928 New Long trade at price: 755.371  On day: 2007-10-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 4928 Moved SL to BE: 755.3712 On day: 2007-10-15 10:00:00
#
# 4928 Long exited after 12 hours: 759.254 On day: 2007-10-15 19:00:00 With profit: 38828.0
#
# 5024 New Short trade at price: 766.793  On day: 2007-10-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5024 Short loss at price: 768.24 On day: 2007-10-19 09:00:00 With loss: -12439.0
#
# 5096 New Short trade at price: 756.669  On day: 2007-10-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5096 Moved SL to BE: 756.6688 On day: 2007-10-24 10:00:00
#
# 5096 Trailing SL to first ATR: 755.9185 On day: 2007-10-24 10:00:00
#
# 5096 Trailing SL to first ATR: 755.168 On day: 2007-10-24 10:00:00
#
# 5096 Short loss at price: 755.763 On day: 2007-10-24 11:00:00 With loss: 15008.5
#
# 5120 New Short trade at price: 762.335  On day: 2007-10-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5120 Short loss at price: 763.966 On day: 2007-10-25 08:00:00 With loss: -8926.75
#
# 5216 New Long trade at price: 783.244  On day: 2007-10-31 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5216 Long loss at price: 780.938 On day: 2007-10-31 09:00:00 With loss: -11246.0
#
# 5240 New Short trade at price: 794.58  On day: 2007-11-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5240 Moved SL to BE: 794.5798 On day: 2007-11-01 09:00:00
#
# 5240 Trailing SL to first ATR: 792.9976 On day: 2007-11-01 09:00:00
#
# 5240 Short profit at price: 786.133 On day: 2007-11-01 13:00:00 With profit: 81060.5
#
# 5264 New Short trade at price: 788.552  On day: 2007-11-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5264 Short loss at price: 791.953 On day: 2007-11-02 10:00:00 With loss: -14195.5
#
# 5311 New Long trade at price: 814.457  On day: 2007-11-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5311 Moved SL to BE: 814.4572 On day: 2007-11-06 09:00:00
#
# 5311 Long profit at price: 822.463 On day: 2007-11-06 13:00:00 With profit: 62769.25
#
# 5335 New Long trade at price: 834.988  On day: 2007-11-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5335 Moved SL to BE: 834.9882 On day: 2007-11-07 08:00:00
#
# 5335 Trailing SL to first ATR: 836.611 On day: 2007-11-07 08:00:00
#
# 5335 Trailing SL to first ATR: 838.2339 On day: 2007-11-07 08:00:00
#
# 5335 Long loss at price: 835.89 On day: 2007-11-07 13:00:00 With loss: 32457.0
#
# 5431 New Long trade at price: 807.635  On day: 2007-11-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5431 Long loss at price: 801.653 On day: 2007-11-13 08:00:00 With loss: -22894.5
#
# 5455 New Long trade at price: 805.652  On day: 2007-11-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5455 Moved SL to BE: 805.6522 On day: 2007-11-14 10:00:00
#
# 5455 Trailing SL to first ATR: 807.2143 On day: 2007-11-14 10:00:00
#
# 5455 Long profit at price: 814.486 On day: 2007-11-14 13:00:00 With profit: 81395.5
#
# 5551 New Long trade at price: 785.29  On day: 2007-11-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5551 Moved SL to BE: 785.2902 On day: 2007-11-20 09:00:00
#
# 5551 Long profit at price: 794.766 On day: 2007-11-20 14:00:00 With profit: 91351.75
#
# 5575 New Long trade at price: 804.246  On day: 2007-11-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5575 Long loss at price: 802.173 On day: 2007-11-21 08:00:00 With loss: -18563.5
#
# 5623 New Long trade at price: 813.644  On day: 2007-11-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5623 Long loss at price: 811.631 On day: 2007-11-23 08:00:00 With loss: -9487.75
#
# 5671 New Short trade at price: 823.296  On day: 2007-11-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5671 Moved SL to BE: 823.2958 On day: 2007-11-27 09:00:00
#
# 5671 Short profit at price: 813.619 On day: 2007-11-27 12:00:00 With profit: 92089.25
#
# 5695 New Short trade at price: 801.712  On day: 2007-11-28 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5695 Moved SL to BE: 801.7118 On day: 2007-11-28 08:00:00
#
# 5695 Short loss at price: 805.105 On day: 2007-11-28 13:00:00 With loss: -0.0
#
# 5719 New Long trade at price: 806.404  On day: 2007-11-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5719 Long loss at price: 801.598 On day: 2007-11-29 12:00:00 With loss: -16771.5
#
# 5743 New Short trade at price: 794.313  On day: 2007-11-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5743 Short loss at price: 795.941 On day: 2007-11-30 08:00:00 With loss: -15711.75
#
# 5791 New Short trade at price: 788.879  On day: 2007-12-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5791 Moved SL to BE: 788.8788 On day: 2007-12-04 08:00:00
#
# 5791 Short loss at price: 789.815 On day: 2007-12-04 10:00:00 With loss: -0.0
#
# 5839 New Short trade at price: 788.538  On day: 2007-12-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5839 Moved SL to BE: 788.5378 On day: 2007-12-06 10:00:00
#
# 5839 Short loss at price: 789.807 On day: 2007-12-06 13:00:00 With loss: -0.0
#
# 5863 New Short trade at price: 797.701  On day: 2007-12-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5863 Short loss at price: 800.538 On day: 2007-12-07 11:00:00 With loss: -13996.25
#
# 5887 New Long trade at price: 798.199  On day: 2007-12-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5887 Moved SL to BE: 798.1992 On day: 2007-12-10 08:00:00
#
# 5887 Long profit at price: 809.804 On day: 2007-12-10 14:00:00 With profit: 70429.25
#
# 5911 New Long trade at price: 808.565  On day: 2007-12-11 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5911 Long loss at price: 806.168 On day: 2007-12-11 10:00:00 With loss: -12192.25
#
# 5983 New Short trade at price: 799.001  On day: 2007-12-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 5983 Moved SL to BE: 799.0008 On day: 2007-12-14 09:00:00
#
# 5983 Short profit at price: 789.623 On day: 2007-12-14 14:00:00 With profit: 79658.0
#
# 6007 New Short trade at price: 791.847  On day: 2007-12-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6007 Moved SL to BE: 791.8468 On day: 2007-12-17 08:00:00
#
# 6007 Short loss at price: 793.27 On day: 2007-12-17 15:00:00 With loss: -0.0
#
# 6103 New Long trade at price: 800.938  On day: 2007-12-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6103 Moved SL to BE: 800.9382 On day: 2007-12-21 10:00:00
#
# 6103 Long profit at price: 809.337 On day: 2007-12-21 13:00:00 With profit: 54543.0
#
# 6127 New Long trade at price: 809.591  On day: 2007-12-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6127 Moved SL to BE: 809.5912 On day: 2007-12-24 08:00:00
#
# 6127 Long loss at price: 809.465 On day: 2007-12-24 10:00:00 With loss: -0.0
#
# 6175 New Long trade at price: 812.913  On day: 2007-12-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6175 Moved SL to BE: 812.9132 On day: 2007-12-26 13:00:00
#
# 6175 Trailing SL to first ATR: 813.5798 On day: 2007-12-26 13:00:00
#
# 6175 Trailing SL to first ATR: 814.2466 On day: 2007-12-26 13:00:00
#
# 6175 Long profit at price: 817.151 On day: 2007-12-26 13:00:00 With profit: 21945.5
#
# 6271 New Long trade at price: 833.137  On day: 2008-01-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6271 Long exited after 12 hours: 833.038 On day: 2008-01-01 19:00:00 With profit: -992.0
#
# 6343 New Short trade at price: 861.51  On day: 2008-01-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6343 Moved SL to BE: 861.5098 On day: 2008-01-04 09:00:00
#
# 6343 Short loss at price: 861.729 On day: 2008-01-04 12:00:00 With loss: -0.0
#
# 6391 New Long trade at price: 866.481  On day: 2008-01-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6391 Moved SL to BE: 866.4812 On day: 2008-01-08 08:00:00
#
# 6391 Trailing SL to first ATR: 867.9272 On day: 2008-01-08 08:00:00
#
# 6391 Trailing SL to first ATR: 869.3734 On day: 2008-01-08 08:00:00
#
# 6391 Long profit at price: 873.584 On day: 2008-01-08 08:00:00 With profit: 64728.0
#
# 6415 New Short trade at price: 884.475  On day: 2008-01-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6415 Short loss at price: 887.346 On day: 2008-01-09 08:00:00 With loss: -17471.0
#
# 6439 New Short trade at price: 872.976  On day: 2008-01-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6439 Short loss at price: 876.572 On day: 2008-01-10 08:00:00 With loss: -18725.5
#
# 6487 New Long trade at price: 906.164  On day: 2008-01-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6487 Moved SL to BE: 906.1642 On day: 2008-01-14 09:00:00
#
# 6487 Trailing SL to first ATR: 907.8152 On day: 2008-01-14 09:00:00
#
# 6487 Trailing SL to first ATR: 909.4664 On day: 2008-01-14 09:00:00
#
# 6487 Long loss at price: 907.841 On day: 2008-01-14 12:00:00 With loss: 33021.5
#
# 6511 New Short trade at price: 906.334  On day: 2008-01-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6511 Moved SL to BE: 906.3338 On day: 2008-01-15 10:00:00
#
# 6511 Short loss at price: 910.845 On day: 2008-01-15 14:00:00 With loss: -0.0
#
# 6535 New Short trade at price: 884.457  On day: 2008-01-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6535 Moved SL to BE: 884.4568 On day: 2008-01-16 10:00:00
#
# 6535 Short loss at price: 885.763 On day: 2008-01-16 12:00:00 With loss: -0.0
#
# 6559 New Long trade at price: 883.78  On day: 2008-01-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6559 Long loss at price: 880.034 On day: 2008-01-17 09:00:00 With loss: -24430.75
#
# 6583 New Long trade at price: 877.373  On day: 2008-01-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6583 Long loss at price: 874.992 On day: 2008-01-18 08:00:00 With loss: -19203.25
#
# 6607 New Short trade at price: 876.549  On day: 2008-01-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6607 Moved SL to BE: 876.5488 On day: 2008-01-21 08:00:00
#
# 6607 Short profit at price: 863.65 On day: 2008-01-21 16:00:00 With profit: 95165.5
#
# 6631 New Short trade at price: 851.269  On day: 2008-01-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6631 Short loss at price: 860.109 On day: 2008-01-22 08:00:00 With loss: -20230.75
#
# 6655 New Long trade at price: 889.284  On day: 2008-01-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6655 Long loss at price: 885.51 On day: 2008-01-23 11:00:00 With loss: -23458.5
#
# 6751 New Short trade at price: 921.181  On day: 2008-01-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6751 Short loss at price: 923.142 On day: 2008-01-29 08:00:00 With loss: -15436.75
#
# 6871 New Short trade at price: 899.301  On day: 2008-02-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6871 Moved SL to BE: 899.3008 On day: 2008-02-05 08:00:00
#
# 6871 Trailing SL to first ATR: 897.5158 On day: 2008-02-05 08:00:00
#
# 6871 Short profit at price: 888.395 On day: 2008-02-05 09:00:00 With profit: 85794.25
#
# 6895 New Short trade at price: 886.877  On day: 2008-02-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6895 Short loss at price: 891.132 On day: 2008-02-06 09:00:00 With loss: -20427.0
#
# 6991 New Long trade at price: 923.403  On day: 2008-02-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 6991 Long loss at price: 920.936 On day: 2008-02-12 08:00:00 With loss: -14070.25
#
# 7015 New Short trade at price: 900.436  On day: 2008-02-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7015 Short loss at price: 902.918 On day: 2008-02-13 09:00:00 With loss: -20650.5
#
# 7039 New Long trade at price: 912.141  On day: 2008-02-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7039 Long loss at price: 910.625 On day: 2008-02-14 09:00:00 With loss: -14881.75
#
# 7111 New Long trade at price: 911.528  On day: 2008-02-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7111 Moved SL to BE: 911.5282 On day: 2008-02-19 10:00:00
#
# 7111 Trailing SL to first ATR: 912.5189 On day: 2008-02-19 10:00:00
#
# 7111 Trailing SL to first ATR: 913.5098 On day: 2008-02-19 10:00:00
#
# 7111 Long profit at price: 917.277 On day: 2008-02-19 10:00:00 With profit: 44754.25
#
# 7231 New Short trade at price: 928.564  On day: 2008-02-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7231 Short loss at price: 931.779 On day: 2008-02-26 09:00:00 With loss: -19865.5
#
# 7255 New Long trade at price: 956.322  On day: 2008-02-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7255 Moved SL to BE: 956.3222 On day: 2008-02-27 08:00:00
#
# 7255 Trailing SL to first ATR: 958.007 On day: 2008-02-27 08:00:00
#
# 7255 Long loss at price: 957.094 On day: 2008-02-27 10:00:00 With loss: 16847.75
#
# 7279 New Short trade at price: 953.003  On day: 2008-02-28 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7279 Short loss at price: 954.897 On day: 2008-02-28 08:00:00 With loss: -16689.25
#
# 7303 New Long trade at price: 974.282  On day: 2008-02-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7303 Long loss at price: 971.77 On day: 2008-02-29 08:00:00 With loss: -16800.25
#
# 7399 New Long trade at price: 988.218  On day: 2008-03-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7399 Moved SL to BE: 988.2182 On day: 2008-03-06 08:00:00
#
# 7399 Long loss at price: 985.982 On day: 2008-03-06 09:00:00 With loss: -0.0
#
# 7496 New Short trade at price: 971.368  On day: 2008-03-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7496 Moved SL to BE: 971.3678 On day: 2008-03-12 08:00:00
#
# 7496 Short loss at price: 972.742 On day: 2008-03-12 09:00:00 With loss: -0.0
#
# 7520 New Long trade at price: 988.161  On day: 2008-03-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7520 Moved SL to BE: 988.1612 On day: 2008-03-13 08:00:00
#
# 7520 Long profit at price: 995.441 On day: 2008-03-13 11:00:00 With profit: 71913.0
#
# 7616 New Long trade at price: 991.648  On day: 2008-03-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7616 Moved SL to BE: 991.6482 On day: 2008-03-19 08:00:00
#
# 7616 Long loss at price: 991.574 On day: 2008-03-19 10:00:00 With loss: -0.0
#
# 7688 New Long trade at price: 914.996  On day: 2008-03-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7688 Moved SL to BE: 914.9962 On day: 2008-03-24 08:00:00
#
# 7688 Long loss at price: 912.089 On day: 2008-03-24 11:00:00 With loss: -0.0
#
# 7712 New Long trade at price: 926.059  On day: 2008-03-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7712 Moved SL to BE: 926.0592 On day: 2008-03-25 08:00:00
#
# 7712 Trailing SL to first ATR: 928.184 On day: 2008-03-25 08:00:00
#
# 7712 Long loss at price: 927.956 On day: 2008-03-25 13:00:00 With loss: 21248.0
#
# 7736 New Short trade at price: 937.274  On day: 2008-03-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7736 Moved SL to BE: 937.2738 On day: 2008-03-26 08:00:00
#
# 7736 Short loss at price: 943.552 On day: 2008-03-26 09:00:00 With loss: -0.0
#
# 7760 New Short trade at price: 950.075  On day: 2008-03-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7760 Moved SL to BE: 950.0748 On day: 2008-03-27 08:00:00
#
# 7760 Trailing SL to first ATR: 948.5905 On day: 2008-03-27 08:00:00
#
# 7760 Short loss at price: 948.835 On day: 2008-03-27 10:00:00 With loss: 14843.0
#
# 7784 New Short trade at price: 943.017  On day: 2008-03-28 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7784 Short loss at price: 945.094 On day: 2008-03-28 09:00:00 With loss: -17580.0
#
# 7808 New Long trade at price: 936.955  On day: 2008-03-31 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7808 Long loss at price: 934.085 On day: 2008-03-31 10:00:00 With loss: -20846.5
#
# 7832 New Short trade at price: 894.58  On day: 2008-04-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7832 Moved SL to BE: 894.5798 On day: 2008-04-01 12:00:00
#
# 7832 Short profit at price: 876.881 On day: 2008-04-01 14:00:00 With profit: 132378.0
#
# 7880 New Short trade at price: 899.73  On day: 2008-04-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7880 Moved SL to BE: 899.7298 On day: 2008-04-03 09:00:00
#
# 7880 Short loss at price: 902.689 On day: 2008-04-03 14:00:00 With loss: -0.0
#
# 7904 New Long trade at price: 905.104  On day: 2008-04-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7904 Long loss at price: 902.641 On day: 2008-04-04 12:00:00 With loss: -16528.25
#
# 7928 New Short trade at price: 912.37  On day: 2008-04-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7928 Short loss at price: 915.344 On day: 2008-04-07 09:00:00 With loss: -15424.25
#
# 7976 New Short trade at price: 905.192  On day: 2008-04-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 7976 Short loss at price: 907.259 On day: 2008-04-09 09:00:00 With loss: -16954.0
#
# 8072 New Long trade at price: 933.526  On day: 2008-04-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8072 Long loss at price: 931.704 On day: 2008-04-15 08:00:00 With loss: -13731.25
#
# 8096 New Long trade at price: 929.246  On day: 2008-04-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8096 Moved SL to BE: 929.2462 On day: 2008-04-16 08:00:00
#
# 8096 Trailing SL to first ATR: 930.4311 On day: 2008-04-16 08:00:00
#
# 8096 Long profit at price: 938.739 On day: 2008-04-16 10:00:00 With profit: 60989.25
#
# 8120 New Long trade at price: 948.259  On day: 2008-04-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8120 Moved SL to BE: 948.2592 On day: 2008-04-17 09:00:00
#
# 8120 Long loss at price: 942.581 On day: 2008-04-17 11:00:00 With loss: -0.0
#
# 8144 New Long trade at price: 945.231  On day: 2008-04-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8144 Long loss at price: 943.535 On day: 2008-04-18 08:00:00 With loss: -13053.25
#
# 8168 New Long trade at price: 921.918  On day: 2008-04-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8168 Long loss at price: 919.011 On day: 2008-04-21 08:00:00 With loss: -18640.75
#
# 8192 New Long trade at price: 917.037  On day: 2008-04-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8192 Moved SL to BE: 917.0372 On day: 2008-04-22 08:00:00
#
# 8192 Long loss at price: 916.828 On day: 2008-04-22 18:00:00 With loss: -0.0
#
# 8216 New Long trade at price: 920.433  On day: 2008-04-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8216 Long loss at price: 914.712 On day: 2008-04-23 09:00:00 With loss: -14803.75
#
# 8264 New Short trade at price: 878.835  On day: 2008-04-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8264 Short loss at price: 882.501 On day: 2008-04-25 08:00:00 With loss: -20356.25
#
# 8312 New Short trade at price: 887.417  On day: 2008-04-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8312 Moved SL to BE: 887.4168 On day: 2008-04-29 09:00:00
#
# 8312 Short profit at price: 878.95 On day: 2008-04-29 12:00:00 With profit: 61443.0
#
# 8336 New Short trade at price: 870.623  On day: 2008-04-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8336 Moved SL to BE: 870.6228 On day: 2008-04-30 08:00:00
#
# 8336 Trailing SL to first ATR: 869.1227 On day: 2008-04-30 08:00:00
#
# 8336 Short loss at price: 872.77 On day: 2008-04-30 12:00:00 With loss: 15000.75
#
# 8360 New Short trade at price: 872.87  On day: 2008-05-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8360 Moved SL to BE: 872.8698 On day: 2008-05-01 08:00:00
#
# 8360 Trailing SL to first ATR: 870.7928 On day: 2008-05-01 08:00:00
#
# 8360 Trailing SL to first ATR: 868.7156 On day: 2008-05-01 08:00:00
#
# 8360 Short profit at price: 862.565 On day: 2008-05-01 10:00:00 With profit: 100509.25
#
# 8384 New Long trade at price: 852.576  On day: 2008-05-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8384 Moved SL to BE: 852.5762 On day: 2008-05-02 08:00:00
#
# 8384 Long loss at price: 851.115 On day: 2008-05-02 10:00:00 With loss: -0.0
#
# 8432 New Long trade at price: 878.032  On day: 2008-05-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8432 Long loss at price: 876.252 On day: 2008-05-06 10:00:00 With loss: -13163.75
#
# 8504 New Long trade at price: 887.37  On day: 2008-05-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8504 Long loss at price: 885.806 On day: 2008-05-09 11:00:00 With loss: -15381.5
#
# 8528 New Short trade at price: 879.79  On day: 2008-05-12 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8528 Short loss at price: 882.018 On day: 2008-05-12 09:00:00 With loss: -18405.5
#
# 8576 New Short trade at price: 861.571  On day: 2008-05-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8576 Short loss at price: 863.768 On day: 2008-05-14 11:00:00 With loss: -18785.75
#
# 8624 New Long trade at price: 883.176  On day: 2008-05-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8624 Moved SL to BE: 883.1762 On day: 2008-05-16 10:00:00
#
# 8624 Long profit at price: 893.607 On day: 2008-05-16 11:00:00 With profit: 91581.75
#
# 8648 New Long trade at price: 909.086  On day: 2008-05-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8648 Moved SL to BE: 909.0862 On day: 2008-05-19 11:00:00
#
# 8648 Trailing SL to first ATR: 910.396 On day: 2008-05-19 11:00:00
#
# 8648 Long loss at price: 908.966 On day: 2008-05-19 12:00:00 With loss: 13098.0
#
# 8720 New Short trade at price: 927.263  On day: 2008-05-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8720 Moved SL to BE: 927.2628 On day: 2008-05-22 10:00:00
#
# 8720 Trailing SL to first ATR: 925.6541 On day: 2008-05-22 10:00:00
#
# 8720 Short loss at price: 927.219 On day: 2008-05-22 13:00:00 With loss: 16086.75
#
# 8744 New Long trade at price: 922.191  On day: 2008-05-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8744 Moved SL to BE: 922.1912 On day: 2008-05-23 10:00:00
#
# 8744 Long exited after 12 hours: 924.325 On day: 2008-05-23 19:00:00 With profit: 21338.0
#
# 8768 New Short trade at price: 925.524  On day: 2008-05-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8768 Moved SL to BE: 925.5238 On day: 2008-05-26 08:00:00
#
# 8768 Short loss at price: 926.422 On day: 2008-05-26 10:00:00 With loss: -0.0
#
# 8792 New Short trade at price: 923.211  On day: 2008-05-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8792 Short loss at price: 924.489 On day: 2008-05-27 08:00:00 With loss: -7994.5
#
# 8888 New Short trade at price: 882.153  On day: 2008-06-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8888 Short loss at price: 884.726 On day: 2008-06-02 08:00:00 With loss: -13057.5
#
# 8912 New Long trade at price: 895.306  On day: 2008-06-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8912 Long loss at price: 893.696 On day: 2008-06-03 09:00:00 With loss: -15167.75
#
# 8936 New Short trade at price: 877.058  On day: 2008-06-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8936 Short loss at price: 879.045 On day: 2008-06-04 10:00:00 With loss: -15883.25
#
# 8960 New Short trade at price: 874.3  On day: 2008-06-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 8960 Moved SL to BE: 874.2998 On day: 2008-06-05 08:00:00
#
# 8960 Short loss at price: 877.153 On day: 2008-06-05 13:00:00 With loss: -0.0
#
# 9008 New Long trade at price: 906.865  On day: 2008-06-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 9008 Long loss at price: 904.149 On day: 2008-06-09 08:00:00 With loss: -17814.0
#
# ...
# 95036 Moved SL to BE: 1724.2582 On day: 2022-09-12 10:00:00
#
# 95036 Long exited after 12 hours: 1724.428 On day: 2022-09-12 19:00:00 With profit: 1698.0
#
# 95128 New Short trade at price: 1655.625  On day: 2022-09-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95128 Short loss at price: 1658.985 On day: 2022-09-16 08:00:00 With loss: -28718.25
#
# 95151 New Short trade at price: 1662.648  On day: 2022-09-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95151 Short loss at price: 1671.865 On day: 2022-09-19 14:00:00 With loss: -24140.75
#
# 95220 New Short trade at price: 1658.755  On day: 2022-09-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95220 Short loss at price: 1670.755 On day: 2022-09-22 08:00:00 With loss: -33102.0
#
# 95243 New Short trade at price: 1667.318  On day: 2022-09-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95243 Moved SL to BE: 1667.3178 On day: 2022-09-23 08:00:00
#
# 95243 Trailing SL to first ATR: 1665.0048 On day: 2022-09-23 08:00:00
#
# 95243 Short profit at price: 1643.405 On day: 2022-09-23 10:00:00 With profit: 116266.75
#
# 95266 New Long trade at price: 1643.955  On day: 2022-09-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95266 Long loss at price: 1639.358 On day: 2022-09-26 10:00:00 With loss: -35340.5
#
# 95289 New Long trade at price: 1637.188  On day: 2022-09-27 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95289 Long loss at price: 1632.915 On day: 2022-09-27 09:00:00 With loss: -25781.75
#
# 95358 New Long trade at price: 1672.997  On day: 2022-09-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95358 Long loss at price: 1667.465 On day: 2022-09-30 09:00:00 With loss: -24488.0
#
# 95404 New Long trade at price: 1708.038  On day: 2022-10-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95404 Moved SL to BE: 1708.0382 On day: 2022-10-04 12:00:00
#
# 95404 Long profit at price: 1725.608 On day: 2022-10-04 15:00:00 With profit: 148686.75
#
# 95427 New Short trade at price: 1716.294  On day: 2022-10-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95427 Moved SL to BE: 1716.2938 On day: 2022-10-05 09:00:00
#
# 95427 Trailing SL to first ATR: 1713.5296 On day: 2022-10-05 09:00:00
#
# 95427 Trailing SL to first ATR: 1710.7652 On day: 2022-10-05 09:00:00
#
# 95427 Short loss at price: 1712.588 On day: 2022-10-05 10:00:00 With loss: 55286.0
#
# 95450 New Long trade at price: 1724.607  On day: 2022-10-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95450 Long loss at price: 1714.024 On day: 2022-10-06 08:00:00 With loss: -23938.0
#
# 95496 New Short trade at price: 1682.718  On day: 2022-10-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95496 Moved SL to BE: 1682.7178 On day: 2022-10-10 10:00:00
#
# 95496 Short profit at price: 1667.478 On day: 2022-10-10 14:00:00 With profit: 143068.0
#
# 95611 New Long trade at price: 1655.848  On day: 2022-10-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95611 Moved SL to BE: 1655.8482 On day: 2022-10-17 12:00:00
#
# 95611 Trailing SL to first ATR: 1658.0434 On day: 2022-10-17 12:00:00
#
# 95611 Trailing SL to first ATR: 1660.2389 On day: 2022-10-17 12:00:00
#
# 95611 Long loss at price: 1657.308 On day: 2022-10-17 16:00:00 With loss: 43907.0
#
# 95724 New Short trade at price: 1649.118  On day: 2022-10-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95724 Short exited after 12 hours: 1650.248 On day: 2022-10-24 19:00:00 With profit: -11302.0
#
# 95747 New Short trade at price: 1645.017  On day: 2022-10-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95747 Moved SL to BE: 1645.0168 On day: 2022-10-25 09:00:00
#
# 95747 Trailing SL to first ATR: 1642.9404 On day: 2022-10-25 09:00:00
#
# 95747 Short loss at price: 1643.678 On day: 2022-10-25 11:00:00 With loss: 20764.0
#
# 95770 New Long trade at price: 1670.748  On day: 2022-10-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95770 Long loss at price: 1661.938 On day: 2022-10-26 12:00:00 With loss: -24834.0
#
# 95816 New Short trade at price: 1652.537  On day: 2022-10-28 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95816 Moved SL to BE: 1652.5368 On day: 2022-10-28 09:00:00
#
# 95816 Short profit at price: 1639.448 On day: 2022-10-28 15:00:00 With profit: 113854.25
#
# 95839 New Short trade at price: 1641.165  On day: 2022-10-31 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95839 Moved SL to BE: 1641.1648 On day: 2022-10-31 08:00:00
#
# 95839 Short exited after 12 hours: 1632.018 On day: 2022-10-31 19:00:00 With profit: 91468.0
#
# 95885 New Long trade at price: 1652.668  On day: 2022-11-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95885 Moved SL to BE: 1652.6682 On day: 2022-11-02 10:00:00
#
# 95885 Long loss at price: 1649.358 On day: 2022-11-02 14:00:00 With loss: -0.0
#
# 95908 New Short trade at price: 1629.798  On day: 2022-11-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95908 Moved SL to BE: 1629.7978 On day: 2022-11-03 08:00:00
#
# 95908 Short loss at price: 1631.058 On day: 2022-11-03 14:00:00 With loss: -0.0
#
# 95953 New Short trade at price: 1667.917  On day: 2022-11-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95953 Short loss at price: 1674.737 On day: 2022-11-07 08:00:00 With loss: -27658.0
#
# 95999 New Long trade at price: 1711.548  On day: 2022-11-09 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 95999 Long loss at price: 1707.818 On day: 2022-11-09 09:00:00 With loss: -26670.75
#
# 96022 New Short trade at price: 1705.748  On day: 2022-11-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96022 Short loss at price: 1708.138 On day: 2022-11-10 10:00:00 With loss: -21599.75
#
# 96045 New Long trade at price: 1760.938  On day: 2022-11-11 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96045 Moved SL to BE: 1760.9382 On day: 2022-11-11 08:00:00
#
# 96045 Long loss at price: 1758.098 On day: 2022-11-11 10:00:00 With loss: -0.0
#
# 96091 New Long trade at price: 1782.748  On day: 2022-11-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96091 Long loss at price: 1777.377 On day: 2022-11-15 08:00:00 With loss: -22156.75
#
# 96160 New Long trade at price: 1765.408  On day: 2022-11-18 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96160 Long loss at price: 1762.548 On day: 2022-11-18 08:00:00 With loss: -18590.5
#
# 96183 New Short trade at price: 1742.367  On day: 2022-11-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96183 Moved SL to BE: 1742.3668 On day: 2022-11-21 09:00:00
#
# 96183 Short loss at price: 1743.328 On day: 2022-11-21 13:00:00 With loss: -0.0
#
# 96229 New Long trade at price: 1744.098  On day: 2022-11-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96229 Long loss at price: 1739.227 On day: 2022-11-23 08:00:00 With loss: -17067.25
#
# 96273 New Short trade at price: 1751.468  On day: 2022-11-25 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96273 Moved SL to BE: 1751.4678 On day: 2022-11-25 13:00:00
#
# 96273 Trailing SL to first ATR: 1749.9134 On day: 2022-11-25 13:00:00
#
# 96273 Short loss at price: 1751.588 On day: 2022-11-25 14:00:00 With loss: 15543.75
#
# 96339 New Long trade at price: 1754.987  On day: 2022-11-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96339 Moved SL to BE: 1754.9872 On day: 2022-11-30 08:00:00
#
# 96339 Trailing SL to first ATR: 1756.748 On day: 2022-11-30 08:00:00
#
# 96339 Long loss at price: 1754.938 On day: 2022-11-30 13:00:00 With loss: 17608.5
#
# 96385 New Long trade at price: 1801.568  On day: 2022-12-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96385 Long loss at price: 1798.317 On day: 2022-12-02 11:00:00 With loss: -22220.75
#
# 96408 New Short trade at price: 1799.748  On day: 2022-12-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96408 Moved SL to BE: 1799.7478 On day: 2022-12-05 09:00:00
#
# 96408 Short profit at price: 1783.897 On day: 2022-12-05 14:00:00 With profit: 129404.25
#
# 96546 New Long trade at price: 1787.858  On day: 2022-12-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96546 Long loss at price: 1785.618 On day: 2022-12-13 08:00:00 With loss: -17340.75
#
# 96569 New Short trade at price: 1808.838  On day: 2022-12-14 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96569 Moved SL to BE: 1808.8378 On day: 2022-12-14 11:00:00
#
# 96569 Short loss at price: 1810.225 On day: 2022-12-14 14:00:00 With loss: -0.0
#
# 96592 New Short trade at price: 1788.825  On day: 2022-12-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96592 Moved SL to BE: 1788.8248 On day: 2022-12-15 08:00:00
#
# 96592 Trailing SL to first ATR: 1786.1256 On day: 2022-12-15 08:00:00
#
# 96592 Trailing SL to first ATR: 1783.4262 On day: 2022-12-15 08:00:00
#
# 96592 Short profit at price: 1776.325 On day: 2022-12-15 13:00:00 With profit: 119996.75
#
# 96615 New Short trade at price: 1777.265  On day: 2022-12-16 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96615 Short loss at price: 1780.875 On day: 2022-12-16 10:00:00 With loss: -22222.25
#
# 96661 New Long trade at price: 1794.025  On day: 2022-12-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96661 Moved SL to BE: 1794.0252 On day: 2022-12-20 08:00:00
#
# 96661 Trailing SL to first ATR: 1796.0989 On day: 2022-12-20 08:00:00
#
# 96661 Trailing SL to first ATR: 1798.1728 On day: 2022-12-20 08:00:00
#
# 96661 Long profit at price: 1807.145 On day: 2022-12-20 09:00:00 With profit: 92825.5
#
# 96730 New Long trade at price: 1797.555  On day: 2022-12-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96730 Long loss at price: 1794.165 On day: 2022-12-23 13:00:00 With loss: -21882.25
#
# 96799 New Short trade at price: 1806.265  On day: 2022-12-29 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96799 Short loss at price: 1809.765 On day: 2022-12-29 08:00:00 With loss: -17646.75
#
# 96845 New Long trade at price: 1847.435  On day: 2023-01-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96845 Long loss at price: 1836.025 On day: 2023-01-03 08:00:00 With loss: -25969.25
#
# 96868 New Long trade at price: 1858.175  On day: 2023-01-04 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96868 Long loss at price: 1853.515 On day: 2023-01-04 12:00:00 With loss: -25726.0
#
# 96891 New Short trade at price: 1849.265  On day: 2023-01-05 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 96891 Moved SL to BE: 1849.2648 On day: 2023-01-05 08:00:00
#
# 96891 Short profit at price: 1834.735 On day: 2023-01-05 13:00:00 With profit: 132676.75
#
# 97029 New Long trade at price: 1899.495  On day: 2023-01-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97029 Moved SL to BE: 1899.4952 On day: 2023-01-13 08:00:00
#
# 97029 Long loss at price: 1896.485 On day: 2023-01-13 12:00:00 With loss: -0.0
#
# 97117 New Long trade at price: 1911.295  On day: 2023-01-19 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97117 Long loss at price: 1908.045 On day: 2023-01-19 11:00:00 With loss: -23934.5
#
# 97140 New Long trade at price: 1932.975  On day: 2023-01-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97140 Long loss at price: 1928.485 On day: 2023-01-20 08:00:00 With loss: -23209.5
#
# 97163 New Short trade at price: 1920.185  On day: 2023-01-23 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97163 Short loss at price: 1923.798 On day: 2023-01-23 08:00:00 With loss: -20557.5
#
# 97186 New Long trade at price: 1940.295  On day: 2023-01-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97186 Long loss at price: 1936.078 On day: 2023-01-24 09:00:00 With loss: -23867.25
#
# 97232 New Short trade at price: 1942.835  On day: 2023-01-26 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97232 Moved SL to BE: 1942.8348 On day: 2023-01-26 09:00:00
#
# 97232 Trailing SL to first ATR: 1940.174 On day: 2023-01-26 09:00:00
#
# 97232 Short profit at price: 1924.667 On day: 2023-01-26 15:00:00 With profit: 125246.75
#
# 97278 New Short trade at price: 1924.455  On day: 2023-01-30 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97278 Short loss at price: 1930.485 On day: 2023-01-30 10:00:00 With loss: -25607.0
#
# 97301 New Short trade at price: 1914.345  On day: 2023-01-31 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97301 Moved SL to BE: 1914.3448 On day: 2023-01-31 08:00:00
#
# 97301 Trailing SL to first ATR: 1912.3803 On day: 2023-01-31 08:00:00
#
# 97301 Trailing SL to first ATR: 1910.4156 On day: 2023-01-31 08:00:00
#
# 97301 Short profit at price: 1903.685 On day: 2023-01-31 09:00:00 With profit: 96585.5
#
# 97324 New Short trade at price: 1924.835  On day: 2023-02-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97324 Short loss at price: 1928.695 On day: 2023-02-01 11:00:00 With loss: -21530.75
#
# 97347 New Long trade at price: 1955.435  On day: 2023-02-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97347 Long loss at price: 1944.205 On day: 2023-02-02 13:00:00 With loss: -31339.0
#
# 97370 New Short trade at price: 1913.555  On day: 2023-02-03 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97370 Moved SL to BE: 1913.5548 On day: 2023-02-03 13:00:00
#
# 97370 Trailing SL to first ATR: 1910.7586 On day: 2023-02-03 13:00:00
#
# 97370 Trailing SL to first ATR: 1907.9623 On day: 2023-02-03 13:00:00
#
# 97370 Short profit at price: 1886.675 On day: 2023-02-03 13:00:00 With profit: 153453.0
#
# 97416 New Long trade at price: 1876.048  On day: 2023-02-07 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97416 Long loss at price: 1872.275 On day: 2023-02-07 08:00:00 With loss: -20230.75
#
# 97439 New Long trade at price: 1886.197  On day: 2023-02-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97439 Long loss at price: 1880.625 On day: 2023-02-08 10:00:00 With loss: -31979.5
#
# 97485 New Long trade at price: 1866.095  On day: 2023-02-10 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97485 Long loss at price: 1862.875 On day: 2023-02-10 10:00:00 With loss: -31669.0
#
# 97508 New Long trade at price: 1863.835  On day: 2023-02-13 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97508 Long loss at price: 1856.968 On day: 2023-02-13 09:00:00 With loss: -21462.75
#
# 97554 New Short trade at price: 1835.575  On day: 2023-02-15 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97554 Short exited after 12 hours: 1835.315 On day: 2023-02-15 19:00:00 With profit: 2598.0
#
# 97600 New Short trade at price: 1823.975  On day: 2023-02-17 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97600 Short loss at price: 1827.495 On day: 2023-02-17 13:00:00 With loss: -26742.25
#
# 97623 New Long trade at price: 1845.955  On day: 2023-02-20 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97623 Long loss at price: 1843.585 On day: 2023-02-20 08:00:00 With loss: -19715.5
#
# 97644 New Short trade at price: 1834.675  On day: 2023-02-21 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97644 Moved SL to BE: 1834.6748 On day: 2023-02-21 10:00:00
#
# 97644 Short loss at price: 1836.574 On day: 2023-02-21 13:00:00 With loss: -0.0
#
# 97667 New Long trade at price: 1839.734  On day: 2023-02-22 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97667 Long loss at price: 1834.685 On day: 2023-02-22 08:00:00 With loss: -18964.0
#
# 97713 New Short trade at price: 1821.995  On day: 2023-02-24 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97713 Moved SL to BE: 1821.9948 On day: 2023-02-24 11:00:00
#
# 97713 Short profit at price: 1810.518 On day: 2023-02-24 15:00:00 With profit: 95213.0
#
# 97759 New Short trade at price: 1810.355  On day: 2023-02-28 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97759 Short loss at price: 1813.804 On day: 2023-02-28 13:00:00 With loss: -16411.25
#
# 97782 New Long trade at price: 1835.445  On day: 2023-03-01 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97782 Long loss at price: 1831.645 On day: 2023-03-01 09:00:00 With loss: -19246.0
#
# 97805 New Short trade at price: 1831.565  On day: 2023-03-02 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97805 Short loss at price: 1833.825 On day: 2023-03-02 08:00:00 With loss: -20004.5
#
# 97851 New Long trade at price: 1856.155  On day: 2023-03-06 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97851 Long loss at price: 1853.325 On day: 2023-03-06 08:00:00 With loss: -18213.0
#
# 97897 New Long trade at price: 1814.135  On day: 2023-03-08 07:00:00 Pair: XAUUSD/XAUUSD_H1 - XAUUSD_H1
# 97897 Moved SL to BE: 1814.1352 On day: 2023-03-08 14:00:00
#
# 97897 Trailing SL to first ATR: 1815.5371 On day: 2023-03-08 14:00:00
#
# 97897 Trailing SL to first ATR: 1816.9392 On day: 2023-03-08 14:00:00
#
# 97897 Long loss at price: 1815.498 On day: 2023-03-08 17:00:00 With loss: 28040.0

# %%
pairs_results = {}
profits = {}
losses = {}
be = {}

for pair in range(len(pairs_list)):
    profits[pair] = []
    losses[pair] = []
    be[pair] = []
    
    pairs_results[pair] = pd.DataFrame.from_dict({(i, j): trade[pair][j] for j in trade[pair].keys()}, orient = 'index')
    pairs_results[pair] = pairs_results[pair].drop(['signal', 'ID', 'TP', 'SL'], axis = 1)
    pairs_results[pair].set_index('date_of_trade', inplace = True)
    pairs_results[pair]['cum_res'] = pairs_results[pair]['result'].cumsum() + account_size
    
    for t in trade[pair]:
        profits[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] > 0.1 else ''
        losses[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] < -0.1 else ''
        be[pair].append(trade[pair][t]['result']) if -0.1 <= trade[pair][t]['result'] <= 0.1 else ''
        
my_reduce = partial(pd.merge, on = 'date_of_trade', how = 'outer')
strategy_results = reduce(my_reduce, pairs_results.values())
strategy_results = strategy_results.sort_index()
strategy_results['final_res'] = strategy_results.filter(like = 'result', axis = 1).sum(axis = 1)
strategy_results['cum_res'] = strategy_results['final_res'].cumsum() + account_size

profits_keys = list(profits.keys())
profits_values = [profits[x] for x in profits_keys]
str_profits = list(flatten(profits_values))

losses_keys = list(losses.keys())
losses_values = [losses[x] for x in losses_keys]
str_losses = list(flatten(losses_values))

be_keys = list(be.keys())
be_values = [be[x] for x in be_keys]
str_be = list(flatten(be_values))

# %%
plt.figure(figsize = (26, 10))
for pair in range(len(pairs_list)):
    plt.plot(pairs_results[pair]['cum_res'], label = pairs_list[pair])
plt.legend()
plt.title('Returns of each pair', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Returns of each pair')

# %%
#Strategy performance
print('***** STRATEGY PERFORMANCE *****')
print('--------------------------------')
print('CAGR:', CAGR(strategy_results, df[0]), '%')
print('Sharpe ratio:', sharpe_ratio(strategy_results))
print('Maximum drawdown', max_drawdown(strategy_results), '% \n')
print('Number of trades:', len(str_profits + str_losses + str_be))
print('Number of profits:', len(str_profits))
print('Number of losses:', len(str_losses))
print('Number of breakevens:', len(str_be), '\n')
print('Winning percentage', (round(len(str_profits) / (len(str_profits) + len(str_losses)) * 100, 2)), '%')
print('ROI:', round(strategy_results['cum_res'][-1]) - account_size)
print('--------------------------------')
print('Average profitable trade:', round(sum(str_profits) / len(str_profits), 2))
print('Average lossing trade:', round(sum(str_losses) / len(str_losses), 2))
print('Max profitable trade:', round(max(str_profits), 2))
print('Max lossing trade:', round(min(str_losses), 2))

plt.figure(figsize = (26, 6))
plt.plot(strategy_results['cum_res'])
plt.title('return of strategy', fontsize = 18)
# Out:
# ***** STRATEGY PERFORMANCE *****
# --------------------------------
# CAGR: 84.7 %
# Sharpe ratio: -0.0
# Maximum drawdown 4569.28 %
#
# Number of trades: 2012
# Number of profits: 633
# Number of losses: 1001
# Number of breakevens: 378
#
# Winning percentage 38.74 %
# ROI: 20707018
# --------------------------------
# Average profitable trade: 62105.55
# Average lossing trade: -18587.21
# Max profitable trade: 514009.25
# Max lossing trade: -88750.0
# c:\Users\Win10\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Text(0.5, 1.0, 'return of strategy')

# %%
#performance for each pair
for pair in range(len(pairs_list)):
    print(pairs_list[pair], '- PERFORMANCE')
    print('--------------------------------')
    print('Number of trades:', len(profits[pair] + losses[pair] + be[pair]))
    print('Number of profits:', len(profits[pair]))
    print('Number of losses:', len(losses[pair]))
    print('Number of breakevens:', len(be[pair]), '\n')
    print('Winning percentage', (round(len(profits[pair]) / (len(profits[pair]) + len(losses[pair])) * 100, 2)), '%')
    print('ROI:', round(pairs_results[pair]['cum_res'][-1] - account_size, 2))
    print('--------------------------------')
    print('Average profitable trade:', round(sum(profits[pair]) / len(profits[pair]), 2))
    print('Average lossing trade:', round(sum(losses[pair]) / len(losses[pair]), 2))
    print('Max profitable trade:', round(max(profits[pair]), 2))
    print('Max lossing trade:', round(min(losses[pair]), 2))
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx \n')
    
    trades_per_day = pairs_results[pair].groupby('day_of_trade').count()['result']
    day_return = pairs_results[pair].groupby('day_of_trade').sum()['result']
    day_return_positive = day_return > 0
    
    print('Number of trades per day \n', trades_per_day)
    
    fig, axes = plt.subplots(4, 1, figsize = (26, 26))
    fig.tight_layout(pad = 4)
    
    axes[0].plot(pairs_results[pair]['cum_res'], color = 'dodgerblue')
    axes[0].set_title(pairs_list[pair], fontsize = 14)
    axes[0].set_xlabel('Days')
    axes[0].set_ylabel('Return')
    
    axes[1].bar(day_return.keys(), height = day_return, color = day_return_positive.map({True: 'limegreen', False: 'coral'}))
    axes[1].set_title('Returns per day', fontsize = 14)
    axes[1].set_xlabel('Days')
    axes[1].set_ylabel('Return')
    
    axes[2].hist(pairs_results[pair]['result'], bins = 500, color = 'purple')
    axes[2].set_title('Distribution of results', fontsize = 14)
    axes[2].set_xlabel('Size of returns')
    axes[2].set_ylabel('Number of returns')
    
    axes[3].plot(df[pair]['Close'], color = 'black', alpha = 0.5)
    axes[3].scatter(pairs_results[pair].index, pairs_results[pair]['entry_price'], s = 70, color = 'red', alpha = 0.5)
    axes[3].set_title('Entries', fontsize = 14)
    axes[3].set_xlabel('Date')
    axes[3].set_ylabel('price')
    
    plt.show()
# Out:
# XAUUSD/XAUUSD_H1 - XAUUSD_H1 - PERFORMANCE
# --------------------------------
# Number of trades: 2012
# Number of profits: 633
# Number of losses: 1001
# Number of breakevens: 378
#
# Winning percentage 38.74 %
# ROI: 20707018.0
# --------------------------------
# Average profitable trade: 62105.55
# Average lossing trade: -18587.21
# Max profitable trade: 514009.25
# Max lossing trade: -88750.0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# Number of trades per day
#  day_of_trade
# Fri    391
# Mon    391
# Thu    399
# Tue    443
# Wed    388
# Name: result, dtype: int64
