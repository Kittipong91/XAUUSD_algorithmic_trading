# %% [markdown]
# # Compare Result Equity

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt
from util.load_data import load_data

# %% [markdown]
# ## Load result strategy

# %%
strategy = {}

# %%
XAUUSD = load_data()

# %% [markdown]
# ### Buy and Hold

# %%
benchmark = {}

# %%
benchmark['D1'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
benchmark['H4'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
benchmark['H1'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
benchmark['M30'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
benchmark['D1']
# Out:
#                Equity  DrawdownPct DrawdownDuration   returns
# Time
# 2007-01-01  10000.000     0.000000              NaN  0.000000
# 2007-01-02  10000.000     0.000000              NaN  0.000000
# 2007-01-03   9987.573     0.001243              NaN -0.001243
# 2007-01-04   9983.504     0.001650              NaN -0.000407
# 2007-01-05   9967.812     0.003219              NaN -0.001572
# ...               ...          ...              ...       ...
# 2023-03-06  11207.226     0.019503              NaN -0.000535
# 2023-03-07  11174.836     0.022337              NaN -0.002890
# 2023-03-08  11176.146     0.022222              NaN  0.000117
# 2023-03-09  11192.386     0.020801              NaN  0.001453
# 2023-03-10  11192.399     0.020800         946 days  0.000001
#
# [5043 rows x 4 columns]

# %%
strategy['Buy and Hold'] = benchmark

# %% [markdown]
# ###  Simple moving average crossover

# %%
SMA_crossover = {}
folder = 'SMA_crossover'

# %%
SMA_crossover['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
SMA_crossover['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
SMA_crossover['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
SMA_crossover['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_19156\2852898199.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   SMA_crossover['M30'] = pd.read_csv(

# %%
strategy['Simple moving average crossover'] = SMA_crossover

# %% [markdown]
# ###  Short term breakout with RSI

# %%
Breakout_RSI = {}
folder = 'Breakout_RSI'

# %%
Breakout_RSI['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Breakout_RSI['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Breakout_RSI['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Breakout_RSI['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Short term breakout with RSI'] = Breakout_RSI

# %% [markdown]
# ###  Inside bar

# %%
Inside_Bar = {}
folder = 'Inside_Bar'

# %%
Inside_Bar['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Inside_Bar['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Inside_Bar['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Inside_Bar['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Inside Bar'] = Inside_Bar

# %% [markdown]
# ###  Long bar with small wicks

# %%
Long_Bar_Small_Wicks = {}
folder = 'Long_Bar_Small_Wicks'

# %%
Long_Bar_Small_Wicks['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Long_Bar_Small_Wicks['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Long_Bar_Small_Wicks['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Long_Bar_Small_Wicks['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Long bar with small wicks'] = Long_Bar_Small_Wicks

# %% [markdown]
# ###  Long bar with small wicks Trailing SL

# %%
Long_Bar_Small_Wicks_TrailingSL = {}
folder = 'Long_Bar_Small_Wicks_TrailingSL'

# %%
Long_Bar_Small_Wicks_TrailingSL['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Long_Bar_Small_Wicks_TrailingSL['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Long_Bar_Small_Wicks_TrailingSL['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Long_Bar_Small_Wicks_TrailingSL['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Long bar with small wicks Trailing SL'] = Long_Bar_Small_Wicks_TrailingSL

# %% [markdown]
# ###  Bolinger bands

# %%
Bolinger_bands = {}
folder = 'Bolinger_bands'

# %%
Bolinger_bands['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Bolinger_bands['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Bolinger_bands['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Bolinger_bands['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Bolinger bands'] = Bolinger_bands

# %% [markdown]
# ###  London breakout

# %%
London_breakout = {}
folder = 'London_breakout'

# %%
London_breakout['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
London_breakout['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
London_breakout['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
London_breakout['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['London breakout'] = London_breakout

# %% [markdown]
# ### Momentum

# %%
Momentum = {}
folder = 'Momentum'

# %%
Momentum['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Momentum['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Momentum['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Momentum['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Momentum'] = Momentum

# %% [markdown]
# ### Peak levels

# %%
Peak_Levels = {}
folder = 'Peak_Levels'

# %%
Peak_Levels['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Peak_Levels['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Peak_Levels['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Peak_Levels['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Peak levels'] = Peak_Levels

# %% [markdown]
# ### Martingale

# %%
Martingale = {}
folder = 'Martingale'

# %%
Martingale['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Martingale['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Martingale['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Martingale['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Martingale'] = Martingale

# %% [markdown]
# ### MACD

# %%
MACD = {}
folder = 'MACD'

# %%
MACD['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
MACD['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
MACD['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
MACD['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['MACD'] = MACD

# %% [markdown]
# ### Stochastic Oscilator Strategies

# %%
StochaticOSC = {}
folder = 'StochaticOSC'

# %%
StochaticOSC['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
StochaticOSC['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
StochaticOSC['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
StochaticOSC['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Stochastic Oscilator'] = StochaticOSC

# %% [markdown]
# ### Pivot Point

# %%
Pivot_Point = {}
folder = 'Pivot_Point'

# %%
Pivot_Point['D1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
Pivot_Point['H4'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
Pivot_Point['H1'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
Pivot_Point['M30'] = pd.read_csv(
    f'../../out/Technical_Strategy/{folder}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
Pivot_Point['D1'] = Pivot_Point['D1'].resample('D').last()

# %%
Pivot_Point['D1'] = Pivot_Point['D1'].reindex(
    benchmark['D1'].index, method='ffill')  # fill forward
Pivot_Point['H4'] = Pivot_Point['H4'].reindex(
    benchmark['H4'].index, method='ffill')  # fill forward
Pivot_Point['H1'] = Pivot_Point['H1'].reindex(
    benchmark['H1'].index, method='ffill')  # fill forward
Pivot_Point['M30'] = Pivot_Point['M30'].reindex(
    benchmark['M30'].index, method='ffill')  # fill forward

# %%
Pivot_Point['H4']
# Out:
#                            Equity  DrawdownPct DrawdownDuration   returns
# Time
# 2007-01-01 00:00:00           NaN          NaN              NaN       NaN
# 2007-01-01 04:00:00           NaN          NaN              NaN       NaN
# 2007-01-01 08:00:00           NaN          NaN              NaN       NaN
# 2007-01-01 12:00:00           NaN          NaN              NaN       NaN
# 2007-01-01 16:00:00  10000.000000     0.000000              NaN  0.000000
# ...                           ...          ...              ...       ...
# 2023-03-10 00:00:00  19513.427265     0.009665              NaN -0.000497
# 2023-03-10 04:00:00  19534.661448     0.008587              NaN  0.001088
# 2023-03-10 08:00:00  19543.044765     0.008162              NaN  0.000429
# 2023-03-10 12:00:00  19739.427788     0.000000  7 days 00:00:00  0.010049
# 2023-03-10 16:00:00  19739.865594     0.000000              NaN  0.000022
#
# [25976 rows x 4 columns]

# %%
benchmark['H4']
# Out:
#                         Equity  DrawdownPct   DrawdownDuration       returns
# Time
# 2007-01-01 00:00:00  10000.000     0.000000                NaN  0.000000e+00
# 2007-01-01 04:00:00  10000.000     0.000000                NaN  0.000000e+00
# 2007-01-01 08:00:00  10000.213     0.000000                NaN  2.130000e-05
# 2007-01-01 12:00:00  10000.226     0.000000                NaN  1.299972e-06
# 2007-01-01 16:00:00  10000.209     0.000002                NaN -1.699962e-06
# ...                        ...          ...                ...           ...
# 2023-03-10 00:00:00  11193.305     0.020999                NaN -2.081168e-04
# 2023-03-10 04:00:00  11197.625     0.020621                NaN  3.859450e-04
# 2023-03-10 08:00:00  11199.085     0.020494                NaN  1.303848e-04
# 2023-03-10 12:00:00  11227.195     0.018035                NaN  2.510026e-03
# 2023-03-10 16:00:00  11227.205     0.018034  945 days 20:00:00  8.906944e-07
#
# [25976 rows x 4 columns]

# %%
Pivot_Point['D1']
# Out:
#                   Equity  DrawdownPct    DrawdownDuration   returns
# Time
# 2007-01-01  10000.000000     0.000000                None  0.000000
# 2007-01-02  10000.000000     0.000000                None  0.000000
# 2007-01-03   9987.317388     0.002495                None -0.002495
# 2007-01-04   9978.957049     0.003330                None  0.000000
# 2007-01-05   9932.021595     0.008018                None -0.004703
# ...                  ...          ...                 ...       ...
# 2023-03-06   7856.861604     0.311816                None  0.000000
# 2023-03-07   7824.162359     0.314680                None  0.000000
# 2023-03-08   7822.469588     0.314828                None  0.000000
# 2023-03-09   7806.229588     0.316251                None  0.000000
# 2023-03-10   7838.154016     0.313455  4203 days 08:00:00  0.004090
#
# [5043 rows x 4 columns]

# %%
strategy['Pivot Point'] = Pivot_Point

# %% [markdown]
# ## Shown Result

# %% [markdown]
# ### TF D1

# %%
TF = 'D1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        y = strategy[f'{data}'][TF]['Equity']
        if data == 'Buy and Hold':
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        else:
            plt.plot(x, y, label=f'{data}')

    # Number of accent colors in the color scheme
    plt.title(f'Technical Strategy Time frame {TF}')
    plt.xlabel('Date 2007 - 2023', fontsize=14)
    plt.ylabel('Equity', fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### TF H4

# %%
TF = 'H4'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        y = strategy[f'{data}'][TF]['Equity']
        if data == 'Buy and Hold':
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        else:
            plt.plot(x, y, label=f'{data}')

    # Number of accent colors in the color scheme
    plt.title(f'Technical Strategy Time frame {TF}')
    plt.xlabel('Date 2007 - 2023', fontsize=14)
    plt.ylabel('Equity', fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### TF H1

# %%
TF = 'H1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        y = strategy[f'{data}'][TF]['Equity']
        if data == 'Buy and Hold':
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        else:
            plt.plot(x, y, label=f'{data}')

    # Number of accent colors in the color scheme
    plt.title(f'Technical Strategy Time frame {TF}')
    plt.xlabel('Date 2007 - 2023', fontsize=14)
    plt.ylabel('Equity', fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### TF M30

# %%
TF = 'M30'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        y = strategy[f'{data}'][TF]['Equity']
        if data == 'Buy and Hold':
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        else:
            plt.plot(x, y, label=f'{data}')

    # Number of accent colors in the color scheme
    plt.title(f'Technical Strategy Time frame {TF}')
    plt.xlabel('Date 2007 - 2023', fontsize=14)
    plt.ylabel('Equity', fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
