# %% [markdown]
# # Buy and Hold

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
from config.constants import *
from backtesting import Backtest ,Strategy
from util.plot_equity import plot_equity_trades
from util.load_data import load_data
# from BuyAndHold import BuyAndHold
import pandas as pd
from util.Save_result_return import save_to_csv

# %% [markdown]
# ## Get Data

# %%
XAUUSD = load_data()

# %%
XAUUSD['D1'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5043 entries, 2007-01-01 to 2023-03-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5043 non-null   float64
#  1   High    5043 non-null   float64
#  2   Low     5043 non-null   float64
#  3   Close   5043 non-null   float64
#  4   Volume  5043 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 236.4 KB

# %% [markdown]
# ## Define Strategy

# %%
account_size = 10000

# %%
class BuyAndHold(Strategy):

    def init(self):
        pass

    def next(self):
        if not self.position:
            self.buy(size=1)

# %%
strategy = BuyAndHold

# %% [markdown]
# # Backtest each time frame

# %% [markdown]
# ## TF D1

# %%
Backtest_D1 = Backtest(XAUUSD['D1'].loc['2020': '2023'], strategy, cash=account_size,  )
result_D1 = Backtest_D1.run()
result_D1
# Out:
# Start                     2020-01-01 00:00:00
# End                       2023-03-10 00:00:00
# Duration                   1164 days 00:00:00
# Exposure Time [%]                   99.798184
# Equity Final [$]                      10302.7
# Equity Peak [$]                      10540.45
# Return [%]                              3.027
# Buy & Hold Return [%]               22.776554
# Return (Ann.) [%]                    0.761194
# Volatility (Ann.) [%]                2.594984
# Sharpe Ratio                         0.293333
# Sortino Ratio                        0.400132
# Calmar Ratio                          0.18138
# Max. Drawdown [%]                    -4.19669
# Avg. Drawdown [%]                    -0.63349
# Max. Drawdown Duration      946 days 00:00:00
# Avg. Drawdown Duration       71 days 00:00:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      19.800776
# ...

# %%
plot_equity_trades(result_D1['_equity_curve'], 'Buy and Hold_D1' , account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_D1, '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1_OOS.csv')

# %% [markdown]
# ## TF H4

# %%
Backtest_H4 = Backtest(XAUUSD['H4'].loc['2020': '2023'], strategy,
                       cash=account_size,  )
result_H4 = Backtest_H4.run()
result_H4
# Out:
# Start                     2020-01-01 20:00:00
# End                       2023-03-10 16:00:00
# Duration                   1163 days 20:00:00
# Exposure Time [%]                   99.960823
# Equity Final [$]                     10342.71
# Equity Peak [$]                     10548.903
# Return [%]                             3.4271
# Buy & Hold Return [%]               22.776554
# Return (Ann.) [%]                    0.860554
# Volatility (Ann.) [%]                2.600302
# Sharpe Ratio                         0.330944
# Sortino Ratio                        0.452733
# Calmar Ratio                          0.20195
# Max. Drawdown [%]                   -4.261211
# Avg. Drawdown [%]                   -0.298952
# Max. Drawdown Duration      945 days 20:00:00
# Avg. Drawdown Duration       26 days 20:00:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      22.542632
# ...

# %%
plot_equity_trades(result_H4['_equity_curve'], 'Buy and Hold_H4', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_H4,'../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4_OOS.csv')

# %% [markdown]
# ## TF H1

# %%
Backtest_H1 = Backtest(XAUUSD['H1'].loc['2020': '2023'], strategy,
                       cash=account_size,  )
result_H1 = Backtest_H1.run()
result_H1
# Out:
# Start                     2020-01-01 23:00:00
# End                       2023-03-10 17:00:00
# Duration                   1163 days 18:00:00
# Exposure Time [%]                   99.989397
# Equity Final [$]                     10336.62
# Equity Peak [$]                     10551.523
# Return [%]                             3.3662
# Buy & Hold Return [%]               22.776554
# Return (Ann.) [%]                    0.845448
# Volatility (Ann.) [%]                2.597651
# Sharpe Ratio                         0.325466
# Sortino Ratio                        0.444858
# Calmar Ratio                         0.196685
# Max. Drawdown [%]                   -4.298488
# Avg. Drawdown [%]                   -0.180836
# Max. Drawdown Duration      945 days 19:00:00
# Avg. Drawdown Duration       14 days 07:00:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      22.166396
# ...

# %%
plot_equity_trades(result_H1['_equity_curve'], 'Buy and Hold_H1', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_H1,'../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1_OOS.csv')

# %% [markdown]
# ## TF M30

# %%
Backtest_M30 = Backtest(XAUUSD['M30'].loc['2020': '2023'], strategy,
                       cash=account_size,  )
result_M30 = Backtest_M30.run()
result_M30
# Out:
# Start                     2020-01-01 23:00:00
# End                       2023-03-10 17:30:00
# Duration                   1163 days 18:30:00
# Exposure Time [%]                   99.994697
# Equity Final [$]                    10344.243
# Equity Peak [$]                     10551.823
# Return [%]                            3.44243
# Buy & Hold Return [%]               22.670469
# Return (Ann.) [%]                    0.864355
# Volatility (Ann.) [%]                2.599953
# Sharpe Ratio                          0.33245
# Sortino Ratio                        0.454819
# Calmar Ratio                         0.201089
# Max. Drawdown [%]                   -4.298366
# Avg. Drawdown [%]                   -0.146797
# Max. Drawdown Duration      945 days 19:00:00
# Avg. Drawdown Duration       10 days 22:27:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      22.672849
# ...

# %%
plot_equity_trades(result_M30['_equity_curve'],
                   'Buy and Hold_M30', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_M30,'../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30_OOS.csv')

# %% [markdown]
# ## TF M15

# %%
Backtest_M15 = Backtest(XAUUSD['M15'].loc['2020': '2023'], strategy,
                       cash=account_size,  )
result_M15 = Backtest_M15.run()
result_M15
# Out:
# Start                     2020-01-01 23:00:00
# End                       2023-03-10 17:45:00
# Duration                   1163 days 18:45:00
# Exposure Time [%]                   99.997348
# Equity Final [$]                    10344.646
# Equity Peak [$]                      10550.54
# Return [%]                            3.44646
# Buy & Hold Return [%]               22.657555
# Return (Ann.) [%]                    0.868696
# Volatility (Ann.) [%]                2.600891
# Sharpe Ratio                            0.334
# Sortino Ratio                        0.457047
# Calmar Ratio                         0.202075
# Max. Drawdown [%]                   -4.298889
# Avg. Drawdown [%]                   -0.123124
# Max. Drawdown Duration      945 days 19:00:00
# Avg. Drawdown Duration        8 days 05:27:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      22.680226
# ...

# %%
plot_equity_trades(result_M15['_equity_curve'],
                   'Buy and Hold_M15', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_M15,'../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M15_OOS.csv')

# %% [markdown]
# ## TF M5

# %%
Backtest_M5 = Backtest(XAUUSD['M5'].loc['2020': '2023'], strategy,
                       cash=account_size,  )
result_M5 = Backtest_M5.run()
result_M5
# Out:
# Start                     2020-05-15 11:10:00
# End                       2023-03-10 17:55:00
# Duration                   1029 days 06:45:00
# Exposure Time [%]                      99.999
# Equity Final [$]                    10131.107
# Equity Peak [$]                     10337.787
# Return [%]                            1.31107
# Buy & Hold Return [%]                7.487395
# Return (Ann.) [%]                    0.352032
# Volatility (Ann.) [%]                2.512555
# Sharpe Ratio                         0.140109
# Sortino Ratio                         0.18697
# Calmar Ratio                          0.07988
# Max. Drawdown [%]                   -4.407007
# Avg. Drawdown [%]                   -0.082214
# Max. Drawdown Duration      945 days 19:05:00
# Avg. Drawdown Duration        7 days 02:17:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                       7.563016
# ...

# %%
plot_equity_trades(result_M5['_equity_curve'], 'Buy and Hold_M5', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_M5,'../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M5_OOS.csv')

# %% [markdown]
# ## TF M1

# %%
Backtest_M1 = Backtest(XAUUSD['M1'].loc['2020': '2023'], strategy,
                       cash=account_size,  )
result_M1 = Backtest_M1.run()
result_M1
# Out:
# Start                     2022-08-16 23:13:00
# End                       2023-03-10 17:59:00
# Duration                    205 days 18:46:00
# Exposure Time [%]                      99.999
# Equity Final [$]                     10088.37
# Equity Peak [$]                     10183.767
# Return [%]                             0.8837
# Buy & Hold Return [%]                4.977319
# Return (Ann.) [%]                    1.270608
# Volatility (Ann.) [%]                2.434686
# Sharpe Ratio                         0.521877
# Sortino Ratio                        0.793363
# Calmar Ratio                         0.761088
# Max. Drawdown [%]                   -1.669462
# Avg. Drawdown [%]                   -0.046827
# Max. Drawdown Duration       90 days 01:47:00
# Avg. Drawdown Duration        0 days 22:26:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                       4.976663
# ...

# %%
plot_equity_trades(result_M1['_equity_curve'], 'Buy and Hold_M1', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_M1,'../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M1_OOS.csv')
