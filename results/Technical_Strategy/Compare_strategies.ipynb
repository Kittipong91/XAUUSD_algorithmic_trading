# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load result strategy

# %%
folder_strategy = 'Momentum'

# %%
result_D1 = pd.read_csv(f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
result_H4 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
result_H1 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
result_M30 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
benchmark_D1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
benchmark_H4 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
benckmark_H1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
benckmark_M30 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
result_D1['benchmark'] = benchmark_D1['returns']

# %%
qs.reports.ful(result_D1['returns'],)

# %%
qs.reports.full(result_D1['returns'])
# Out:
# <h4>Performance Metrics</h4>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 qs.reports.full(result_D1['returns'],result_D1['benchmark'],benchmark_D1['returns'])
#
# File c:\Users\Win10\anaconda3\lib\site-packages\quantstats\reports.py:554, in full(returns, benchmark, rf, grayscale, figsize, display, compounded, periods_per_year, match_dates, **kwargs)
#     551 if _utils._in_notebook():
#     552     iDisplay(iHTML("<h4>Performance Metrics</h4>"))
#     553     iDisplay(
# --> 554         metrics(
#     555             returns=returns,
#     556             benchmark=benchmark,
#     557             rf=rf,
#     558             display=display,
#     559             mode="full",
#     560             compounded=compounded,
#     561             periods_per_year=periods_per_year,
#     562             prepare_returns=False,
#     563             benchmark_title=benchmark_title,
#     564             strategy_title=strategy_title,
#     565         )
#     566     )
#     568     if isinstance(dd, _pd.Series):
#     569         iDisplay(iHTML('<h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>'))
#
# File c:\Users\Win10\anaconda3\lib\site-packages\quantstats\reports.py:843, in metrics(returns, benchmark, rf, display, mode, sep, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#     839 metrics["CAGR﹪%"] = _stats.cagr(df, rf, compounded) * pct
#     841 metrics["~~~~~~~~~~~~~~"] = blank
# --> 843 metrics["Sharpe"] = _stats.sharpe(df, rf, win_year, True)
#     844 metrics["Prob. Sharpe Ratio %"] = (
#     845     _stats.probabilistic_sharpe_ratio(df, rf, win_year, False) * pct
#     846 )
#     847 if mode.lower() == "full":
#
# File c:\Users\Win10\anaconda3\lib\site-packages\quantstats\stats.py:286, in sharpe(returns, rf, periods, annualize, smart)
#     272 def sharpe(returns, rf=0.0, periods=252, annualize=True, smart=False):
#     273     """
#     274     Calculates the sharpe ratio of access returns
#     275
#    (...)
#     284         * smart: return smart sharpe ratio
#     285     """
# --> 286     if rf != 0 and periods is None:
#     287         raise Exception("Must provide periods if rf != 0")
#     289     returns = _utils._prepare_returns(returns, rf, periods)
#
# File c:\Users\Win10\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
