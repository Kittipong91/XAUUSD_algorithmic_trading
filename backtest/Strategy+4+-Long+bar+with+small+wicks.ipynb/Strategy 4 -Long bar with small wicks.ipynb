# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
import os
import matplotlib.style
from pandas.core.common import flatten
from functools import partial, reduce

# %%
plt.style.use('ggplot')

# %%
pairs_list = [
    'EURUSD/EURUSD_H4 - EURUSD_H4',
    'AUDUSD/AUDUSD_H4 - AUDUSD_H4',
    'GBPUSD/GBPUSD_H4 - GBPUSD_H4',
    'NZDUSD/NZDUSD_H4 - NZDUSD_H4',
    'USDCAD/USDCAD_H4 - USDCAD_H4',
    'USDCHF/USDCHF_H4 - USDCHF_H4',
    'USDJPY/USDJPY_H4 - USDJPY_H4',
    'XAUUSD/XAUUSD_H4 - XAUUSD_H4',
]

# %%
df ={}
for pair in range(len(pairs_list)) :
    df[pair] = pd.read_csv('../../Data_Forex/'+pairs_list[pair]+'.csv',index_col=0,parse_dates=True)

# %%
#Strategy parameters
account_size = 1000
slippage = 2
size = 1
ATR_SL = 0.5

# %%
def average_bar_size(df):
    df = df.copy()
    df['candle_size'] = df['High'] - df['Low']
    df['average_bar'] = df['candle_size'].rolling(20).mean()
    return df

def small_wick(df, wick_size):
    df = df.copy()
    df['small_wick'] = np.where((df['Close'] > df['Open']) \
                               & ((df['High'] - df['Close']) <= ((df['High'] - df['Low']) * wick_size)) \
                               & ((df['Open'] - df['Low']) <= ((df['High'] - df['Low']) * wick_size)) \
                               | (df['Close'] < df['Open']) \
                               & ((df['High'] - df['Open']) <= ((df['High'] - df['Low']) * wick_size)) \
                               & ((df['Close'] - df['Low']) <= ((df['High'] - df['Low']) * wick_size)), True, False)
    return df

def ATR(df, n):
    df = df.copy()
    df['High-Low'] = abs(df['High'] - df['Low'])
    df['High-PrevClose'] = abs(df['High'] - df['Close'].shift(1))
    df['Low-PrevClose'] = abs(df['Low'] - df['Close'].shift(1))
    df['TR'] = df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis = 1, skipna = False)
    df['ATR'] = df['TR'].rolling(n).mean()
    df = df.drop(['High-Low', 'High-PrevClose', 'Low-PrevClose'], axis = 1)
    return df

def CAGR(df, source_df):
    df = df.copy()
    n = len(source_df) / (252*24)
    return round((((df['cum_res'][-1] / account_size)**(1/n)) - 1) * 100, 1)

def sharpe_ratio(df):
    df = df.copy()
    returns = df['cum_res'].pct_change()
    volatility = returns.std() * np.sqrt(252)
    return round((returns.mean() - 0.02) / volatility, 2)

def max_drawdown(df):
    df = df.copy()
    cum_returns = (1 + df['cum_res']).cumprod()
    drawdown = 1 - df['cum_res'].div(df['cum_res'].cummax())
    return round(max(drawdown.expanding().max() * 100), 2)

# %%
for pair in range(len(pairs_list)):
    df[pair]['ATR'] = ATR(df[pair], 20)['ATR']
    df[pair]['average_bar'] = average_bar_size(df[pair])['average_bar']
    df[pair]['small_wick'] = small_wick(df[pair], 0.2)['small_wick']
    if 'USDJPY/USDJPY_H4 - USDJPY_H4'  not in pairs_list[pair] and 'XAUUSD/XAUUSD_H4 - XAUUSD_H4'  not in pairs_list[pair] :
        df[pair]['spread'] = float(slippage) / float(10000)
        df[pair]['size'] = float(size) * float(10000)
        print('Pair: ', pairs_list[pair], 'a')
    else:
        df[pair]['spread'] = float(slippage) / float(100)
        df[pair]['size'] = float(size) * float(100)
        print('Pair: ', pairs_list[pair], 'b')
# Out:
# Pair:  EURUSD/EURUSD_H4 - EURUSD_H4 a
# Pair:  AUDUSD/AUDUSD_H4 - AUDUSD_H4 a
# Pair:  GBPUSD/GBPUSD_H4 - GBPUSD_H4 a
# Pair:  NZDUSD/NZDUSD_H4 - NZDUSD_H4 a
# Pair:  USDCAD/USDCAD_H4 - USDCAD_H4 a
# Pair:  USDCHF/USDCHF_H4 - USDCHF_H4 a
# Pair:  USDJPY/USDJPY_H4 - USDJPY_H4 b
# Pair:  XAUUSD/XAUUSD_H4 - XAUUSD_H4 b

# %%
df[0].tail(20)
# Out:
#                         Open     High      Low    Close  Volume       ATR  \
# Time
# 2023-03-07 12:00:00  1.06564  1.06719  1.05737  1.05854  149095  0.003098
# 2023-03-07 16:00:00  1.05853  1.05959  1.05460  1.05514  129712  0.003102
# 2023-03-07 20:00:00  1.05516  1.05571  1.05471  1.05481   17946  0.002971
# 2023-03-08 00:00:00  1.05482  1.05504  1.05274  1.05292   45713  0.002984
# 2023-03-08 04:00:00  1.05292  1.05469  1.05241  1.05434   45939  0.003007
# 2023-03-08 08:00:00  1.05434  1.05484  1.05339  1.05377   61990  0.002989
# 2023-03-08 12:00:00  1.05376  1.05738  1.05291  1.05524  147689  0.003069
# 2023-03-08 16:00:00  1.05525  1.05676  1.05397  1.05456   83087  0.003002
# 2023-03-08 20:00:00  1.05457  1.05499  1.05410  1.05488   17148  0.002831
# 2023-03-09 00:00:00  1.05488  1.05532  1.05378  1.05491   31723  0.002867
# 2023-03-09 04:00:00  1.05492  1.05596  1.05457  1.05562   31799  0.002882
# 2023-03-09 08:00:00  1.05562  1.05812  1.05480  1.05709   62306  0.002919
# 2023-03-09 12:00:00  1.05710  1.05862  1.05524  1.05686  106217  0.002989
# 2023-03-09 16:00:00  1.05686  1.05910  1.05635  1.05755   88804  0.002950
# 2023-03-09 20:00:00  1.05755  1.05856  1.05723  1.05856   33262  0.002730
# 2023-03-10 00:00:00  1.05855  1.05993  1.05791  1.05967   62976  0.002701
# 2023-03-10 04:00:00  1.05967  1.06066  1.05809  1.05948   58412  0.002755
# 2023-03-10 08:00:00  1.05946  1.06036  1.05738  1.05894   86765  0.002823
# 2023-03-10 12:00:00  1.05896  1.07004  1.05806  1.06872  219311  0.003322
# 2023-03-10 16:00:00  1.06873  1.06873  1.06551  1.06585   43114  0.003324
#
#                      average_bar  small_wick  spread     size
# Time
# 2023-03-07 12:00:00     0.003074        True  0.0002  10000.0
# 2023-03-07 16:00:00     0.003078       False  0.0002  10000.0
# 2023-03-07 20:00:00     0.002946       False  0.0002  10000.0
# 2023-03-08 00:00:00     0.002959        True  0.0002  10000.0
# 2023-03-08 04:00:00     0.002982       False  0.0002  10000.0
# 2023-03-08 08:00:00     0.002965       False  0.0002  10000.0
# 2023-03-08 12:00:00     0.003045       False  0.0002  10000.0
# 2023-03-08 16:00:00     0.002978       False  0.0002  10000.0
# 2023-03-08 20:00:00     0.002807       False  0.0002  10000.0
# 2023-03-09 00:00:00     0.002842       False  0.0002  10000.0
# 2023-03-09 04:00:00     0.002882       False  0.0002  10000.0
# 2023-03-09 08:00:00     0.002919       False  0.0002  10000.0
# 2023-03-09 12:00:00     0.002989       False  0.0002  10000.0
# 2023-03-09 16:00:00     0.002950       False  0.0002  10000.0
# 2023-03-09 20:00:00     0.002730       False  0.0002  10000.0
# 2023-03-10 00:00:00     0.002701       False  0.0002  10000.0
# 2023-03-10 04:00:00     0.002755       False  0.0002  10000.0
# 2023-03-10 08:00:00     0.002823       False  0.0002  10000.0
# 2023-03-10 12:00:00     0.003322        True  0.0002  10000.0
# 2023-03-10 16:00:00     0.003324        True  0.0002  10000.0

# %%
open_trade = {}
trade = {}
long_take_profit = {}
short_take_profit = {}
long_stop_loss = {}
short_stop_loss = {}
long_entry_price = {}
short_entry_price = {}

for pair in range(len(pairs_list)):
    open_trade[pair] = []
    trade[pair] = {}
    long_take_profit[pair] = []
    short_take_profit[pair] = []
    long_stop_loss[pair] = []
    short_stop_loss[pair] = []
    long_entry_price[pair] = []
    short_entry_price[pair] = []
    
    for i in range(50, len(df[pair])):
        #Buy
        if (df[pair]['High'][i - 1] - df[pair]['Low'][i - 1]) >= 4 * df[pair]['average_bar'][i - 1] and df[pair]['small_wick'][i - 1] == True \
            and df[pair]['Close'][i - 1] > df[pair]['Open'][i - 1] and len(open_trade[pair]) == 0:
            print(i, 'New Long trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                             'date_of_trade': df[pair].index[i],
                             'entry_price': df[pair]['Close'][i],
                             'signal': 'Buy',
                             'result': 0, 
                             'TP': df[pair]['Close'][i] + df[pair]['ATR'][i] * 4 * ATR_SL,
                             'SL': df[pair]['Close'][i] - df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            long_take_profit[pair].append(trade[pair][i]['TP'])
            long_stop_loss[pair].append(trade[pair][i]['SL'])
            long_entry_price[pair].append(trade[pair][i]['entry_price'])
        
        #Sell
        if (df[pair]['High'][i - 1] - df[pair]['Low'][i - 1]) >= 4 * df[pair]['average_bar'][i - 1] and df[pair]['small_wick'][i - 1] == True \
            and df[pair]['Close'][i - 1] < df[pair]['Open'][i - 1] and len(open_trade[pair]) == 0:
            print(i, 'New Short trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                             'date_of_trade': df[pair].index[i],
                             'entry_price': df[pair]['Close'][i],
                             'signal': 'Sell',
                             'result': 0, 
                             'TP': df[pair]['Close'][i] - df[pair]['ATR'][i] * 4 * ATR_SL,
                             'SL': df[pair]['Close'][i] + df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            short_take_profit[pair].append(trade[pair][i]['TP'])
            short_stop_loss[pair].append(trade[pair][i]['SL'])
            short_entry_price[pair].append(trade[pair][i]['entry_price'])
            
        #Exit trades---------------------------------------------------------------------------
        #Buy profit
        if any(y <= df[pair]['Close'][i] for y in long_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] >= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['TP'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Buy loss
        if any(y >= df[pair]['Close'][i] for y in long_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] <= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['SL'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
                        
        #Sell profit
        if any(y >= df[pair]['Close'][i] for y in short_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] <= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['TP'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Sell loss
        if any(y <= df[pair]['Close'][i] for y in short_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] >= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['SL'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Exit after time
        if len(open_trade[pair]) != 0:
            for j in open_trade[pair]:
                if (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    trade[pair][j].update({'result' : (df[pair]['Close'][i] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Long exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    long_take_profit[pair].remove(trade[pair][j]['TP'])
                    long_stop_loss[pair].remove(trade[pair][j]['SL'])
                elif (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - df[pair]['Close'][i] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Short exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    short_take_profit[pair].remove(trade[pair][j]['TP'])
                    short_stop_loss[pair].remove(trade[pair][j]['SL'])
# Out:
# 1023 New Short trade at price: 1.4135  On day: 2007-10-22 12:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 1023 Short loss at price: 1.4164 On day: 2007-10-22 16:00:00 With loss: -25.82
#
# 3300 New Long trade at price: 1.3487  On day: 2009-03-18 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 3300 Long profit at price: 1.3729 On day: 2009-03-19 12:00:00 With profit: 165.45
#
# 3764 New Long trade at price: 1.414  On day: 2009-07-01 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 3764 Long loss at price: 1.411 On day: 2009-07-02 00:00:00 With loss: -15.85
#
# 7794 New Short trade at price: 1.2939  On day: 2011-12-28 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 7794 Short profit at price: 1.2866 On day: 2011-12-29 08:00:00 With profit: 49.81
#
# 8609 New Long trade at price: 1.2569  On day: 2012-06-29 04:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 8609 Long profit at price: 1.2667 On day: 2012-06-29 12:00:00 With profit: 84.19
#
# 9966 New Short trade at price: 1.3066  On day: 2013-05-02 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 9966 Short loss at price: 1.3106 On day: 2013-05-03 04:00:00 With loss: -23.475
#
# 10121 New Long trade at price: 1.3245  On day: 2013-06-06 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 10121 Long loss at price: 1.3218 On day: 2013-06-07 16:00:00 With loss: -25.175
#
# 10178 New Short trade at price: 1.3282  On day: 2013-06-19 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 10178 Short profit at price: 1.3212 On day: 2013-06-20 08:00:00 With profit: 66.44
#
# 10581 New Long trade at price: 1.3524  On day: 2013-09-18 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 10581 Long exited after 12 hours: 1.3522 On day: 2013-09-20 20:00:00 With profit: -3.6
#
# 10729 New Long trade at price: 1.3781  On day: 2013-10-22 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 10729 Long loss at price: 1.3754 On day: 2013-10-23 04:00:00 With loss: -13.53
#
# 11322 New Long trade at price: 1.386  On day: 2014-03-06 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 11322 Long exited after 12 hours: 1.3879 On day: 2014-03-10 12:00:00 With profit: 17.1
#
# 11379 New Short trade at price: 1.3818  On day: 2014-03-19 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 11379 Short loss at price: 1.3839 On day: 2014-03-20 04:00:00 With loss: -16.015
#
# 12127 New Short trade at price: 1.2926  On day: 2014-09-04 12:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12127 Short loss at price: 1.2948 On day: 2014-09-04 16:00:00 With loss: -15.055
#
# 12185 New Short trade at price: 1.2849  On day: 2014-09-17 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12185 Short loss at price: 1.2865 On day: 2014-09-18 00:00:00 With loss: -17.245
#
# 12371 New Short trade at price: 1.2632  On day: 2014-10-29 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12371 Short profit at price: 1.2569 On day: 2014-10-31 04:00:00 With profit: 58.39
#
# 12531 New Long trade at price: 1.2368  On day: 2014-12-04 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12531 Long loss at price: 1.2296 On day: 2014-12-05 12:00:00 With loss: -19.7525
#
# 12740 New Short trade at price: 1.1379  On day: 2015-01-22 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12740 Short profit at price: 1.1173 On day: 2015-01-23 08:00:00 With profit: 103.74
#
# 12895 New Short trade at price: 1.1195  On day: 2015-02-26 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12895 Short loss at price: 1.1215 On day: 2015-02-27 04:00:00 With loss: -20.4775
#
# 12983 New Long trade at price: 1.0849  On day: 2015-03-18 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 12983 Long loss at price: 1.0769 On day: 2015-03-19 00:00:00 With loss: -31.28
#
# 13949 New Short trade at price: 1.1108  On day: 2015-10-22 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 13949 Short profit at price: 1.1016 On day: 2015-10-23 12:00:00 With profit: 66.69
#
# 13975 New Short trade at price: 1.0924  On day: 2015-10-28 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 13975 Short loss at price: 1.0961 On day: 2015-10-29 08:00:00 With loss: -19.6975
#
# 14135 New Long trade at price: 1.0977  On day: 2015-12-03 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 14135 Long loss at price: 1.0918 On day: 2015-12-03 20:00:00 With loss: -28.255
#
# 14398 New Long trade at price: 1.1094  On day: 2016-02-03 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 14398 Long profit at price: 1.1172 On day: 2016-02-04 08:00:00 With profit: 71.5
#
# 14585 New Long trade at price: 1.1216  On day: 2016-03-16 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 14585 Long profit at price: 1.1326 On day: 2016-03-17 08:00:00 With profit: 71.6
#
# 14641 New Long trade at price: 1.1289  On day: 2016-03-29 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 14641 Long profit at price: 1.1344 On day: 2016-03-31 04:00:00 With profit: 47.62
#
# 14937 New Long trade at price: 1.1356  On day: 2016-06-03 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 14937 Long exited after 12 hours: 1.1349 On day: 2016-06-07 12:00:00 With profit: -8.2
#
# 15027 New Short trade at price: 1.1156  On day: 2016-06-24 04:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 15027 Short profit at price: 1.0993 On day: 2016-06-27 08:00:00 With profit: 154.23
#
# 15635 New Long trade at price: 1.1117  On day: 2016-11-09 04:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 15635 Long loss at price: 1.1091 On day: 2016-11-09 08:00:00 With loss: -25.98
#
# 16760 New Long trade at price: 1.1628  On day: 2017-07-20 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 16760 Long exited after 12 hours: 1.1642 On day: 2017-07-24 12:00:00 With profit: 12.0
#
# 16828 New Short trade at price: 1.1781  On day: 2017-08-04 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 16828 Short loss at price: 1.181 On day: 2017-08-07 04:00:00 With loss: -20.735
#
# 18947 New Long trade at price: 1.1367  On day: 2018-11-28 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 18947 Long loss at price: 1.1324 On day: 2018-11-30 12:00:00 With loss: -15.36
#
# 19435 New Long trade at price: 1.1428  On day: 2019-03-20 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 19435 Long loss at price: 1.1413 On day: 2019-03-21 04:00:00 With loss: -12.4175
#
# 20024 New Short trade at price: 1.1071  On day: 2019-07-31 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 20024 Short profit at price: 1.1033 On day: 2019-08-01 04:00:00 With profit: 32.26
#
# 20128 New Long trade at price: 1.1142  On day: 2019-08-23 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 20128 Long loss at price: 1.1121 On day: 2019-08-26 04:00:00 With loss: -13.4375
#
# 20569 New Long trade at price: 1.1078  On day: 2019-12-02 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 20569 Long loss at price: 1.1069 On day: 2019-12-04 08:00:00 With loss: -9.725
#
# 20613 New Long trade at price: 1.1132  On day: 2019-12-11 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 20613 Long loss at price: 1.1117 On day: 2019-12-12 12:00:00 With loss: -8.94
#
# 20620 New Long trade at price: 1.1178  On day: 2019-12-13 00:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 20620 Long loss at price: 1.1165 On day: 2019-12-13 04:00:00 With loss: -12.225
#
# 22869 New Long trade at price: 1.2168  On day: 2021-05-07 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 22869 Long loss at price: 1.2148 On day: 2021-05-10 04:00:00 With loss: -15.36
#
# 23044 New Short trade at price: 1.1995  On day: 2021-06-16 20:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 23044 Short profit at price: 1.1936 On day: 2021-06-17 08:00:00 With profit: 42.22
#
# 23638 New Long trade at price: 1.168  On day: 2021-10-28 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 23638 Long loss at price: 1.1647 On day: 2021-10-29 08:00:00 With loss: -13.935
#
# 24072 New Long trade at price: 1.1433  On day: 2022-02-03 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 24072 Long exited after 12 hours: 1.1443 On day: 2022-02-07 12:00:00 With profit: 8.2
#
# 25312 New Long trade at price: 1.0181  On day: 2022-11-10 16:00:00 Pair: EURUSD/EURUSD_H4 - EURUSD_H4
# 25312 Long profit at price: 1.0291 On day: 2022-11-11 08:00:00 With profit: 101.16
#
# 939 New Short trade at price: 0.8047  On day: 2007-08-16 00:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 939 Short profit at price: 0.7853 On day: 2007-08-16 04:00:00 With profit: 106.8
#
# 1424 New Short trade at price: 0.8769  On day: 2007-12-11 16:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 1424 Short loss at price: 0.8807 On day: 2007-12-12 00:00:00 With loss: -23.735
#
# 3377 New Long trade at price: 0.6781  On day: 2009-03-18 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 3377 Long loss at price: 0.6754 On day: 2009-03-19 00:00:00 With loss: -24.9025
#
# 7829 New Short trade at price: 1.0093  On day: 2011-12-28 16:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 7829 Short loss at price: 1.0115 On day: 2011-12-29 12:00:00 With loss: -15.2225
#
# 10210 New Short trade at price: 0.9279  On day: 2013-06-19 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 10210 Short exited after 12 hours: 0.9213 On day: 2013-06-21 20:00:00 With profit: 64.1
#
# 10613 New Long trade at price: 0.9494  On day: 2013-09-18 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 10613 Long loss at price: 0.9443 On day: 2013-09-19 12:00:00 With loss: -21.8825
#
# 11562 New Short trade at price: 0.9277  On day: 2014-04-23 04:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 11562 Short loss at price: 0.9288 On day: 2014-04-23 08:00:00 With loss: -11.6975
#
# 12403 New Short trade at price: 0.8768  On day: 2014-10-29 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 12403 Short loss at price: 0.8785 On day: 2014-10-30 08:00:00 With loss: -15.9875
#
# 13015 New Long trade at price: 0.7778  On day: 2015-03-18 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 13015 Long loss at price: 0.7735 On day: 2015-03-19 00:00:00 With loss: -21.8475
#
# 14799 New Short trade at price: 0.762  On day: 2016-04-27 04:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 14799 Short loss at price: 0.7643 On day: 2016-04-28 04:00:00 With loss: -18.08
#
# 15059 New Short trade at price: 0.7393  On day: 2016-06-24 04:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 15059 Short loss at price: 0.7421 On day: 2016-06-24 08:00:00 With loss: -28.1425
#
# 15667 New Short trade at price: 0.7678  On day: 2016-11-09 04:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 15667 Short profit at price: 0.7572 On day: 2016-11-10 12:00:00 With profit: 70.15
#
# 15826 New Short trade at price: 0.7409  On day: 2016-12-14 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 15826 Short loss at price: 0.7423 On day: 2016-12-15 00:00:00 With loss: -15.06
#
# 16229 New Long trade at price: 0.7706  On day: 2017-03-15 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 16229 Long loss at price: 0.768 On day: 2017-03-16 00:00:00 With loss: -14.535
#
# 16777 New Long trade at price: 0.7911  On day: 2017-07-18 04:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 16777 Long exited after 12 hours: 0.7919 On day: 2017-07-20 04:00:00 With profit: 5.8
#
# 18979 New Long trade at price: 0.73  On day: 2018-11-28 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 18979 Long exited after 12 hours: 0.7312 On day: 2018-11-30 20:00:00 With profit: 9.4
#
# 19072 New Short trade at price: 0.7112  On day: 2018-12-19 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 19072 Short loss at price: 0.7143 On day: 2018-12-20 08:00:00 With loss: -11.5675
#
# 19618 New Short trade at price: 0.7044  On day: 2019-04-24 04:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 19618 Short profit at price: 0.7013 On day: 2019-04-24 16:00:00 With profit: 26.73
#
# 20055 New Short trade at price: 0.6846  On day: 2019-07-31 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 20055 Short loss at price: 0.6857 On day: 2019-08-01 12:00:00 With loss: -9.2425
#
# 23075 New Short trade at price: 0.7614  On day: 2021-06-16 20:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 23075 Short loss at price: 0.7626 On day: 2021-06-17 00:00:00 With loss: -11.34
#
# 24932 New Long trade at price: 0.708  On day: 2022-08-10 16:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 24932 Long exited after 12 hours: 0.7124 On day: 2022-08-12 16:00:00 With profit: 41.7
#
# 25341 New Long trade at price: 0.6591  On day: 2022-11-10 16:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 25341 Long profit at price: 0.6698 On day: 2022-11-11 12:00:00 With profit: 92.8
#
# 25484 New Long trade at price: 0.6857  On day: 2022-12-13 16:00:00 Pair: AUDUSD/AUDUSD_H4 - AUDUSD_H4
# 25484 Long loss at price: 0.6829 On day: 2022-12-14 00:00:00 With loss: -18.855
#
# 355 New Long trade at price: 1.9877  On day: 2007-05-23 12:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 355 Long loss at price: 1.9857 On day: 2007-05-24 00:00:00 With loss: -19.515
#
# 5136 New Short trade at price: 1.485  On day: 2010-05-06 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 5136 Short loss at price: 1.4899 On day: 2010-05-06 20:00:00 With loss: -39.4875
#
# 7796 New Short trade at price: 1.5453  On day: 2011-12-28 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 7796 Short loss at price: 1.5536 On day: 2011-12-30 12:00:00 With loss: -23.455
#
# 9935 New Long trade at price: 1.5433  On day: 2013-04-25 12:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 9935 Long profit at price: 1.5532 On day: 2013-04-29 04:00:00 With profit: 86.74
#
# 10179 New Short trade at price: 1.5473  On day: 2013-06-19 20:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 10179 Short loss at price: 1.5512 On day: 2013-06-20 20:00:00 With loss: -26.245
#
# 10582 New Long trade at price: 1.6132  On day: 2013-09-18 20:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 10582 Long loss at price: 1.6079 On day: 2013-09-19 08:00:00 With loss: -20.775
#
# 11759 New Long trade at price: 1.6964  On day: 2014-06-13 00:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 11759 Long exited after 12 hours: 1.6977 On day: 2014-06-16 20:00:00 With profit: 11.0
#
# 12029 New Short trade at price: 1.6695  On day: 2014-08-13 12:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 12029 Short exited after 12 hours: 1.6685 On day: 2014-08-15 12:00:00 With profit: 7.8
#
# 12372 New Short trade at price: 1.6002  On day: 2014-10-29 20:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 12372 Short loss at price: 1.6022 On day: 2014-10-30 12:00:00 With loss: -18.66
#
# 12984 New Long trade at price: 1.496  On day: 2015-03-18 20:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 12984 Long loss at price: 1.4888 On day: 2015-03-19 00:00:00 With loss: -32.515
#
# 14012 New Short trade at price: 1.5209  On day: 2015-11-05 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 14012 Short profit at price: 1.5077 On day: 2015-11-06 12:00:00 With profit: 75.87
#
# 15028 New Short trade at price: 1.381  On day: 2016-06-24 04:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 15028 Short profit at price: 1.3162 On day: 2016-06-27 08:00:00 With profit: 422.02
#
# 16577 New Short trade at price: 1.275  On day: 2017-06-09 00:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 16577 Short exited after 12 hours: 1.2669 On day: 2017-06-12 20:00:00 With profit: 78.6
#
# 17339 New Long trade at price: 1.3364  On day: 2017-11-28 20:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 17339 Long profit at price: 1.3472 On day: 2017-11-30 00:00:00 With profit: 76.41
#
# 18315 New Short trade at price: 1.325  On day: 2018-07-09 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 18315 Short loss at price: 1.3288 On day: 2018-07-10 04:00:00 With loss: -22.6975
#
# 18544 New Long trade at price: 1.3027  On day: 2018-08-29 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 18544 Long loss at price: 1.2996 On day: 2018-08-30 12:00:00 With loss: -19.5875
#
# 19584 New Short trade at price: 1.2943  On day: 2019-04-23 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 19584 Short loss at price: 1.2953 On day: 2019-04-24 08:00:00 With loss: -11.11
#
# 20339 New Long trade at price: 1.2455  On day: 2019-10-10 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 20339 Long loss at price: 1.243 On day: 2019-10-10 20:00:00 With loss: -23.3925
#
# 20620 New Long trade at price: 1.3478  On day: 2019-12-13 00:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 20620 Long loss at price: 1.3416 On day: 2019-12-13 04:00:00 With loss: -32.4175
#
# 23669 New Short trade at price: 1.3503  On day: 2021-11-04 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 23669 Short loss at price: 1.3562 On day: 2021-11-08 12:00:00 With loss: -20.085
#
# 23781 New Short trade at price: 1.3284  On day: 2021-11-30 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 23781 Short loss at price: 1.3313 On day: 2021-12-01 00:00:00 With loss: -20.9525
#
# 24903 New Long trade at price: 1.2218  On day: 2022-08-10 16:00:00 Pair: GBPUSD/GBPUSD_H4 - GBPUSD_H4
# 24903 Long loss at price: 1.2192 On day: 2022-08-11 00:00:00 With loss: -21.765
#
# 3312 New Long trade at price: 0.5445  On day: 2009-03-18 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 3312 Long loss at price: 0.5411 On day: 2009-03-19 00:00:00 With loss: -24.46
#
# 9435 New Long trade at price: 0.8359  On day: 2013-01-02 04:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 9435 Long loss at price: 0.8334 On day: 2013-01-02 12:00:00 With loss: -17.5775
#
# 10183 New Short trade at price: 0.7869  On day: 2013-06-19 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 10183 Short profit at price: 0.7725 On day: 2013-06-20 12:00:00 With profit: 90.83
#
# 10586 New Long trade at price: 0.8385  On day: 2013-09-18 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 10586 Long loss at price: 0.836 On day: 2013-09-19 12:00:00 With loss: -20.68
#
# 11943 New Short trade at price: 0.8599  On day: 2014-07-24 00:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 11943 Short profit at price: 0.8548 On day: 2014-07-25 08:00:00 With profit: 43.53
#
# 12376 New Short trade at price: 0.7781  On day: 2014-10-29 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 12376 Short loss at price: 0.7839 On day: 2014-10-30 12:00:00 With loss: -18.045
#
# 13361 New Short trade at price: 0.7028  On day: 2015-06-11 00:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 13361 Short exited after 12 hours: 0.6988 On day: 2015-06-14 20:00:00 With profit: 38.6
#
# 13764 New Short trade at price: 0.6282  On day: 2015-09-10 00:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 13764 Short loss at price: 0.6321 On day: 2015-09-10 04:00:00 With loss: -19.9875
#
# 14560 New Short trade at price: 0.6633  On day: 2016-03-10 00:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 14560 Short loss at price: 0.6657 On day: 2016-03-10 04:00:00 With loss: -21.4475
#
# 14590 New Long trade at price: 0.6736  On day: 2016-03-16 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 14590 Long profit at price: 0.682 On day: 2016-03-17 08:00:00 With profit: 75.25
#
# 14963 New Long trade at price: 0.7132  On day: 2016-06-09 00:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 14963 Long loss at price: 0.7106 On day: 2016-06-09 08:00:00 With loss: -19.425
#
# 15032 New Short trade at price: 0.7055  On day: 2016-06-24 04:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 15032 Short loss at price: 0.7104 On day: 2016-06-24 12:00:00 With loss: -26.0175
#
# 16450 New Short trade at price: 0.6839  On day: 2017-05-11 00:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 16450 Short loss at price: 0.6855 On day: 2017-05-11 16:00:00 With loss: -15.895
#
# 17165 New Short trade at price: 0.7019  On day: 2017-10-19 08:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 17165 Short profit at price: 0.6957 On day: 2017-10-20 12:00:00 With profit: 53.48
#
# 18951 New Long trade at price: 0.6867  On day: 2018-11-28 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 18951 Long loss at price: 0.6851 On day: 2018-11-29 00:00:00 With loss: -13.6475
#
# 19280 New Long trade at price: 0.6833  On day: 2019-02-13 04:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 19280 Long loss at price: 0.6821 On day: 2019-02-13 08:00:00 With loss: -12.53
#
# 19466 New Short trade at price: 0.6798  On day: 2019-03-27 04:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 19466 Short loss at price: 0.6813 On day: 2019-03-28 04:00:00 With loss: -12.975
#
# 20054 New Short trade at price: 0.6413  On day: 2019-08-07 04:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 20054 Short loss at price: 0.6432 On day: 2019-08-07 08:00:00 With loss: -18.82
#
# 23047 New Short trade at price: 0.707  On day: 2021-06-16 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 23047 Short loss at price: 0.7088 On day: 2021-06-17 00:00:00 With loss: -12.9125
#
# 24473 New Long trade at price: 0.6549  On day: 2022-05-04 20:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 24473 Long loss at price: 0.6518 On day: 2022-05-05 04:00:00 With loss: -17.96
#
# 24906 New Long trade at price: 0.6404  On day: 2022-08-10 16:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 24906 Long loss at price: 0.6391 On day: 2022-08-11 00:00:00 With loss: -15.07
#
# 25055 New Short trade at price: 0.5992  On day: 2022-09-13 16:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 25055 Short loss at price: 0.6012 On day: 2022-09-14 12:00:00 With loss: -19.095
#
# 25315 New Long trade at price: 0.6011  On day: 2022-11-10 16:00:00 Pair: NZDUSD/NZDUSD_H4 - NZDUSD_H4
# 25315 Long profit at price: 0.6104 On day: 2022-11-11 12:00:00 With profit: 83.51
#
# 381 New Short trade at price: 1.0734  On day: 2007-05-29 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 381 Short loss at price: 1.0753 On day: 2007-05-30 12:00:00 With loss: -15.98
#
# 5049 New Long trade at price: 1.0132  On day: 2010-04-16 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 5049 Long loss at price: 1.0111 On day: 2010-04-20 04:00:00 With loss: -20.1225
#
# 8950 New Short trade at price: 0.9684  On day: 2012-09-13 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 8950 Short loss at price: 0.971 On day: 2012-09-14 12:00:00 With loss: -13.1875
#
# 10178 New Long trade at price: 1.0281  On day: 2013-06-19 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 10178 Long profit at price: 1.0344 On day: 2013-06-20 08:00:00 With profit: 45.77
#
# 10272 New Short trade at price: 1.0383  On day: 2013-07-11 00:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 10272 Short loss at price: 1.041 On day: 2013-07-11 08:00:00 With loss: -18.105
#
# 10581 New Short trade at price: 1.0222  On day: 2013-09-18 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 10581 Short loss at price: 1.0237 On day: 2013-09-19 12:00:00 With loss: -13.3125
#
# 10735 New Long trade at price: 1.0383  On day: 2013-10-23 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 10735 Long profit at price: 1.0421 On day: 2013-10-24 12:00:00 With profit: 34.47
#
# 11254 New Long trade at price: 1.108  On day: 2014-02-19 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 11254 Long profit at price: 1.1158 On day: 2014-02-21 04:00:00 With profit: 51.0
#
# 11886 New Long trade at price: 1.0733  On day: 2014-07-11 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 11886 Long loss at price: 1.0722 On day: 2014-07-14 12:00:00 With loss: -11.1525
#
# 12734 New Long trade at price: 1.2353  On day: 2015-01-21 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 12734 Long loss at price: 1.2329 On day: 2015-01-22 12:00:00 With loss: -25.715
#
# 12983 New Short trade at price: 1.2554  On day: 2015-03-18 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 12983 Short loss at price: 1.2599 On day: 2015-03-19 00:00:00 With loss: -27.36
#
# 13106 New Short trade at price: 1.2301  On day: 2015-04-15 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 13106 Short profit at price: 1.2181 On day: 2015-04-16 16:00:00 With profit: 95.91
#
# 13509 New Long trade at price: 1.2921  On day: 2015-07-15 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 13509 Long exited after 12 hours: 1.2986 On day: 2015-07-17 16:00:00 With profit: 63.2
#
# 14585 New Short trade at price: 1.3118  On day: 2016-03-16 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 14585 Short profit at price: 1.2981 On day: 2016-03-17 12:00:00 With profit: 103.5
#
# 15027 New Long trade at price: 1.3003  On day: 2016-06-24 04:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 15027 Long loss at price: 1.2947 On day: 2016-06-24 12:00:00 With loss: -35.1075
#
# 15216 New Long trade at price: 1.3164  On day: 2016-08-05 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 15216 Long loss at price: 1.3118 On day: 2016-08-09 12:00:00 With loss: -22.93
#
# 15635 New Long trade at price: 1.3369  On day: 2016-11-09 04:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 15635 Long profit at price: 1.3496 On day: 2016-11-10 12:00:00 With profit: 98.83
#
# 15794 New Long trade at price: 1.3285  On day: 2016-12-14 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 15794 Long profit at price: 1.3396 On day: 2016-12-15 12:00:00 With profit: 66.62
#
# 16197 New Short trade at price: 1.3296  On day: 2017-03-15 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 16197 Short loss at price: 1.3316 On day: 2017-03-16 12:00:00 With loss: -18.1525
#
# 16588 New Short trade at price: 1.3311  On day: 2017-06-12 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 16588 Short profit at price: 1.3226 On day: 2017-06-13 12:00:00 With profit: 61.89
#
# 16723 New Short trade at price: 1.2736  On day: 2017-07-12 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 16723 Short loss at price: 1.2763 On day: 2017-07-13 08:00:00 With loss: -19.1825
#
# 17355 New Short trade at price: 1.2693  On day: 2017-12-01 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 17355 Short loss at price: 1.2719 On day: 2017-12-03 20:00:00 With loss: -19.33
#
# 17442 New Short trade at price: 1.2732  On day: 2017-12-21 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 17442 Short loss at price: 1.2754 On day: 2017-12-22 12:00:00 With loss: -16.345
#
# 20344 New Short trade at price: 1.3202  On day: 2019-10-11 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 20344 Short loss at price: 1.3228 On day: 2019-10-14 12:00:00 With loss: -15.4575
#
# 20425 New Long trade at price: 1.3164  On day: 2019-10-30 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 20425 Long loss at price: 1.3144 On day: 2019-10-31 12:00:00 With loss: -13.04
#
# 20592 New Long trade at price: 1.3263  On day: 2019-12-06 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 20592 Long loss at price: 1.3248 On day: 2019-12-06 20:00:00 With loss: -12.93
#
# 23043 New Long trade at price: 1.2278  On day: 2021-06-16 20:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 23043 Long profit at price: 1.2334 On day: 2021-06-17 08:00:00 With profit: 48.88
#
# 24902 New Short trade at price: 1.2776  On day: 2022-08-10 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 24902 Short exited after 12 hours: 1.2769 On day: 2022-08-12 16:00:00 With profit: 5.5
#
# 25051 New Long trade at price: 1.3165  On day: 2022-09-13 16:00:00 Pair: USDCAD/USDCAD_H4 - USDCAD_H4
# 25051 Long exited after 12 hours: 1.323 On day: 2022-09-15 16:00:00 With profit: 62.4
#
# 3275 New Long trade at price: 1.1841  On day: 2009-03-12 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 3275 Long exited after 12 hours: 1.182 On day: 2009-03-16 12:00:00 With profit: -23.0
#
# 3301 New Short trade at price: 1.1413  On day: 2009-03-18 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 3301 Short profit at price: 1.1184 On day: 2009-03-19 12:00:00 With profit: 138.92
#
# 4459 New Long trade at price: 1.0187  On day: 2009-12-04 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 4459 Long loss at price: 1.0163 On day: 2009-12-04 20:00:00 With loss: -18.615
#
# 7125 New Short trade at price: 0.7869  On day: 2011-07-29 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 7125 Short loss at price: 0.7919 On day: 2011-07-31 20:00:00 With loss: -17.6175
#
# 7292 New Long trade at price: 0.8593  On day: 2011-09-06 12:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 7292 Long exited after 12 hours: 0.8714 On day: 2011-09-08 12:00:00 With profit: 119.4
#
# 7795 New Long trade at price: 0.9424  On day: 2011-12-28 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 7795 Long loss at price: 0.9402 On day: 2011-12-29 20:00:00 With loss: -14.7275
#
# 9724 New Long trade at price: 0.9513  On day: 2013-03-08 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 9724 Long loss at price: 0.9495 On day: 2013-03-11 12:00:00 With loss: -16.945
#
# 10178 New Long trade at price: 0.9292  On day: 2013-06-19 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 10178 Long loss at price: 0.9262 On day: 2013-06-20 20:00:00 With loss: -18.8025
#
# 10581 New Short trade at price: 0.9124  On day: 2013-09-18 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 10581 Short exited after 12 hours: 0.91 On day: 2013-09-20 20:00:00 With profit: 21.5
#
# 10729 New Short trade at price: 0.8949  On day: 2013-10-22 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 10729 Short profit at price: 0.8912 On day: 2013-10-24 08:00:00 With profit: 35.47
#
# 12127 New Long trade at price: 0.9327  On day: 2014-09-04 12:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 12127 Long loss at price: 0.9316 On day: 2014-09-04 16:00:00 With loss: -11.155
#
# 12371 New Long trade at price: 0.9548  On day: 2014-10-29 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 12371 Long profit at price: 0.9596 On day: 2014-10-31 04:00:00 With profit: 44.13
#
# 12531 New Short trade at price: 0.972  On day: 2014-12-04 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 12531 Short loss at price: 0.9777 On day: 2014-12-05 12:00:00 With loss: -16.7625
#
# 12983 New Short trade at price: 0.9811  On day: 2015-03-18 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 12983 Short loss at price: 0.9912 On day: 2015-03-19 00:00:00 With loss: -28.115
#
# 13168 New Short trade at price: 0.9401  On day: 2015-04-29 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 13168 Short profit at price: 0.9294 On day: 2015-05-01 08:00:00 With profit: 95.82
#
# 14135 New Short trade at price: 0.9878  On day: 2015-12-03 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 14135 Short loss at price: 0.9938 On day: 2015-12-03 20:00:00 With loss: -27.0725
#
# 14585 New Short trade at price: 0.978  On day: 2016-03-16 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 14585 Short profit at price: 0.9682 On day: 2016-03-17 08:00:00 With profit: 60.26
#
# 14937 New Short trade at price: 0.9762  On day: 2016-06-03 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 14937 Short profit at price: 0.9685 On day: 2016-06-07 04:00:00 With profit: 60.23
#
# 15635 New Short trade at price: 0.9718  On day: 2016-11-09 04:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 15635 Short loss at price: 0.9815 On day: 2016-11-09 12:00:00 With loss: -27.47
#
# 18947 New Short trade at price: 0.9933  On day: 2018-11-28 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 18947 Short loss at price: 0.9956 On day: 2018-11-29 08:00:00 With loss: -11.7925
#
# 19435 New Short trade at price: 0.991  On day: 2019-03-20 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 19435 Short loss at price: 0.9923 On day: 2019-03-21 04:00:00 With loss: -11.0325
#
# 20127 New Short trade at price: 0.9746  On day: 2019-08-23 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 20127 Short loss at price: 0.9758 On day: 2019-08-26 00:00:00 With loss: -13.525
#
# 22080 New Long trade at price: 0.9123  On day: 2020-11-09 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 22080 Long exited after 12 hours: 0.9172 On day: 2020-11-11 16:00:00 With profit: 46.8
#
# 23044 New Long trade at price: 0.9087  On day: 2021-06-16 20:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 23044 Long profit at price: 0.9153 On day: 2021-06-17 08:00:00 With profit: 39.61
#
# 25312 New Short trade at price: 0.9663  On day: 2022-11-10 16:00:00 Pair: USDCHF/USDCHF_H4 - USDCHF_H4
# 25312 Short profit at price: 0.9457 On day: 2022-11-11 12:00:00 With profit: 92.02
#
# 3118 New Short trade at price: 89.17  On day: 2009-01-21 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 3118 Short exited after 12 hours: 88.8 On day: 2009-01-23 16:00:00 With profit: 35.0
#
# 3367 New Short trade at price: 96.415  On day: 2009-03-18 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 3367 Short profit at price: 94.765 On day: 2009-03-19 08:00:00 With profit: 110.0
#
# 3966 New Long trade at price: 97.5  On day: 2009-08-07 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 3966 Long loss at price: 97.27 On day: 2009-08-10 00:00:00 With loss: -24.9125
#
# 4493 New Long trade at price: 90.7  On day: 2009-12-04 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 4493 Long loss at price: 90.06 On day: 2009-12-06 20:00:00 With loss: -23.4125
#
# 5736 New Long trade at price: 85.455  On day: 2010-09-15 04:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 5736 Long exited after 12 hours: 85.81 On day: 2010-09-17 04:00:00 With profit: 33.5
#
# 7053 New Short trade at price: 80.616  On day: 2011-07-08 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 7053 Short loss at price: 80.758 On day: 2011-07-11 00:00:00 With loss: -12.1275
#
# 7168 New Long trade at price: 79.887  On day: 2011-08-04 04:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 7168 Long loss at price: 79.009 On day: 2011-08-04 12:00:00 With loss: -28.7
#
# 7553 New Long trade at price: 78.798  On day: 2011-10-31 04:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 7553 Long loss at price: 77.917 On day: 2011-10-31 08:00:00 With loss: -22.805
#
# 8442 New Short trade at price: 79.245  On day: 2012-05-17 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 8442 Short loss at price: 79.415 On day: 2012-05-17 20:00:00 With loss: -12.5675
#
# 8938 New Long trade at price: 78.895  On day: 2012-09-06 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 8938 Long loss at price: 78.136 On day: 2012-09-07 12:00:00 With loss: -8.5325
#
# 8944 New Short trade at price: 78.269  On day: 2012-09-07 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 8944 Short profit at price: 77.777 On day: 2012-09-11 12:00:00 With profit: 33.14
#
# 9859 New Long trade at price: 95.484  On day: 2013-04-04 08:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 9859 Long profit at price: 96.904 On day: 2013-04-05 00:00:00 With profit: 101.85
#
# 10017 New Long trade at price: 100.824  On day: 2013-05-09 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 10017 Long profit at price: 101.74 On day: 2013-05-10 12:00:00 With profit: 71.46
#
# 10600 New Short trade at price: 98.182  On day: 2013-09-18 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 10600 Short loss at price: 98.401 On day: 2013-09-19 00:00:00 With loss: -18.715
#
# 10823 New Short trade at price: 98.165  On day: 2013-11-07 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 10823 Short loss at price: 99.069 On day: 2013-11-08 12:00:00 With loss: -16.455
#
# 11986 New Long trade at price: 102.865  On day: 2014-07-30 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 11986 Long loss at price: 102.77 On day: 2014-07-31 00:00:00 With loss: -9.0925
#
# 12204 New Long trade at price: 108.548  On day: 2014-09-17 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 12204 Long profit at price: 109.226 On day: 2014-09-19 00:00:00 With profit: 50.05
#
# 12399 New Long trade at price: 111.595  On day: 2014-10-31 08:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 12399 Long profit at price: 112.834 On day: 2014-11-02 20:00:00 With profit: 83.45
#
# 12827 New Long trade at price: 119.139  On day: 2015-02-06 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 12827 Long loss at price: 118.801 On day: 2015-02-09 00:00:00 With loss: -21.91
#
# 12951 New Long trade at price: 120.692  On day: 2015-03-06 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 12951 Long profit at price: 121.427 On day: 2015-03-09 20:00:00 With profit: 61.28
#
# 13002 New Short trade at price: 120.071  On day: 2015-03-18 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 13002 Short loss at price: 120.407 On day: 2015-03-19 00:00:00 With loss: -15.88
#
# 13371 New Short trade at price: 122.95  On day: 2015-06-10 08:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 13371 Short loss at price: 123.534 On day: 2015-06-11 04:00:00 With loss: -27.835
#
# 13405 New Short trade at price: 123.573  On day: 2015-06-17 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 13405 Short profit at price: 122.858 On day: 2015-06-18 04:00:00 With profit: 53.69
#
# 14036 New Long trade at price: 123.236  On day: 2015-11-06 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 14036 Long loss at price: 123.048 On day: 2015-11-09 20:00:00 With loss: -17.9325
#
# 14278 New Short trade at price: 118.975  On day: 2016-01-04 04:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 14278 Short loss at price: 119.296 On day: 2016-01-04 12:00:00 With loss: -13.55
#
# 14956 New Short trade at price: 106.63  On day: 2016-06-03 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 14956 Short loss at price: 107.046 On day: 2016-06-06 00:00:00 With loss: -28.1225
#
# 15654 New Short trade at price: 103.334  On day: 2016-11-09 04:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 15654 Short loss at price: 104.551 On day: 2016-11-09 12:00:00 With loss: -33.94
#
# 16216 New Short trade at price: 113.388  On day: 2017-03-15 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 16216 Short profit at price: 112.668 On day: 2017-03-17 12:00:00 With profit: 60.62
#
# 16618 New Short trade at price: 109.65  On day: 2017-06-14 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 16618 Short loss at price: 110.122 On day: 2017-06-15 08:00:00 With loss: -18.7525
#
# 19454 New Short trade at price: 110.663  On day: 2019-03-20 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 19454 Short loss at price: 110.851 On day: 2019-03-21 12:00:00 With loss: -11.4825
#
# 20147 New Short trade at price: 105.34  On day: 2019-08-23 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 20147 Short loss at price: 105.738 On day: 2019-08-26 04:00:00 With loss: -15.085
#
# 20637 New Long trade at price: 109.333  On day: 2019-12-12 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 20637 Long exited after 12 hours: 109.625 On day: 2019-12-16 12:00:00 With profit: 27.2
#
# 23063 New Long trade at price: 110.77  On day: 2021-06-16 20:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 23063 Long loss at price: 110.586 On day: 2021-06-17 04:00:00 With loss: -10.5675
#
# 24922 New Short trade at price: 132.91  On day: 2022-08-10 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 24922 Short loss at price: 133.278 On day: 2022-08-12 00:00:00 With loss: -28.81
#
# 25071 New Long trade at price: 144.472  On day: 2022-09-13 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25071 Long loss at price: 143.309 On day: 2022-09-14 04:00:00 With loss: -38.0375
#
# 25113 New Short trade at price: 142.16  On day: 2022-09-22 12:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25113 Short loss at price: 142.793 On day: 2022-09-23 08:00:00 With loss: -45.6425
#
# 25244 New Short trade at price: 147.644  On day: 2022-10-21 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25244 Short loss at price: 148.877 On day: 2022-10-24 00:00:00 With loss: -36.11
#
# 25331 New Short trade at price: 141.814  On day: 2022-11-10 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25331 Short profit at price: 139.492 On day: 2022-11-11 08:00:00 With profit: 156.5
#
# 25474 New Short trade at price: 135.478  On day: 2022-12-13 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25474 Short loss at price: 135.863 On day: 2022-12-15 04:00:00 With loss: -35.705
#
# 25502 New Short trade at price: 132.592  On day: 2022-12-20 04:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25502 Short exited after 12 hours: 131.949 On day: 2022-12-22 04:00:00 With profit: 62.3
#
# 25709 New Long trade at price: 131.057  On day: 2023-02-03 16:00:00 Pair: USDJPY/USDJPY_H4 - USDJPY_H4
# 25709 Long profit at price: 132.845 On day: 2023-02-06 12:00:00 With profit: 122.62
#
# 234 New Long trade at price: 677.559  On day: 2007-02-21 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 234 Long loss at price: 674.574 On day: 2007-02-22 20:00:00 With loss: -226.23
#
# 989 New Long trade at price: 672.62  On day: 2007-08-10 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 989 Long loss at price: 670.401 On day: 2007-08-12 20:00:00 With loss: -222.1825
#
# 1014 New Short trade at price: 652.82  On day: 2007-08-16 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1014 Short loss at price: 657.198 On day: 2007-08-17 12:00:00 With loss: -211.525
#
# 1107 New Long trade at price: 695.416  On day: 2007-09-06 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1107 Long loss at price: 692.791 On day: 2007-09-07 00:00:00 With loss: -164.94
#
# 2775 New Long trade at price: 866.563  On day: 2008-09-17 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2775 Long loss at price: 856.363 On day: 2008-09-18 00:00:00 With loss: -689.5075
#
# 3222 New Long trade at price: 867.057  On day: 2008-12-26 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 3222 Long profit at price: 883.832 On day: 2008-12-29 00:00:00 With profit: 1172.06
#
# 3582 New Long trade at price: 935.251  On day: 2009-03-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 3582 Long loss at price: 928.832 On day: 2009-03-19 00:00:00 With loss: -497.0525
#
# 4707 New Short trade at price: 1162.936  On day: 2009-11-27 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 4707 Short loss at price: 1174.607 On day: 2009-11-27 12:00:00 With loss: -520.0125
#
# 5013 New Short trade at price: 1064.467  On day: 2010-02-04 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5013 Short exited after 12 hours: 1069.052 On day: 2010-02-08 12:00:00 With profit: -460.5
#
# 6055 New Long trade at price: 1308.254  On day: 2010-09-28 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 6055 Long loss at price: 1302.325 On day: 2010-09-30 12:00:00 With loss: -254.14
#
# 6489 New Short trade at price: 1380.226  On day: 2011-01-04 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 6489 Short loss at price: 1384.025 On day: 2011-01-04 20:00:00 With loss: -331.395
#
# 8189 New Long trade at price: 1709.458  On day: 2012-01-25 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8189 Long profit at price: 1730.187 On day: 2012-01-27 12:00:00 With profit: 1959.71
#
# 8641 New Short trade at price: 1606.552  On day: 2012-05-08 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8641 Short profit at price: 1589.252 On day: 2012-05-09 00:00:00 With profit: 1515.18
#
# 8752 New Long trade at price: 1622.068  On day: 2012-06-01 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8752 Long loss at price: 1614.276 On day: 2012-06-04 12:00:00 With loss: -736.025
#
# 8777 New Short trade at price: 1591.552  On day: 2012-06-07 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8777 Short loss at price: 1602.036 On day: 2012-06-10 20:00:00 With loss: -572.115
#
# 9186 New Long trade at price: 1736.652  On day: 2012-09-07 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 9186 Long loss at price: 1729.945 On day: 2012-09-10 08:00:00 With loss: -431.4225
#
# 9434 New Short trade at price: 1677.952  On day: 2012-11-02 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 9434 Short loss at price: 1682.138 On day: 2012-11-04 20:00:00 With loss: -334.6475
#
# 10428 New Short trade at price: 1346.278  On day: 2013-06-19 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10428 Short profit at price: 1314.046 On day: 2013-06-20 04:00:00 With profit: 1382.02
#
# 10831 New Long trade at price: 1367.742  On day: 2013-09-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10831 Long loss at price: 1361.037 On day: 2013-09-19 00:00:00 With loss: -668.46
#
# 10979 New Long trade at price: 1340.162  On day: 2013-10-22 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10979 Long loss at price: 1335.572 On day: 2013-10-23 04:00:00 With loss: -334.8775
#
# 11059 New Short trade at price: 1285.843  On day: 2013-11-08 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11059 Short exited after 12 hours: 1279.592 On day: 2013-11-12 12:00:00 With profit: 623.1
#
# 12608 New Short trade at price: 1212.515  On day: 2014-10-29 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12608 Short profit at price: 1198.591 On day: 2014-10-30 12:00:00 With profit: 907.02
#
# 12873 New Long trade at price: 1199.849  On day: 2014-12-30 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12873 Long loss at price: 1195.998 On day: 2014-12-31 08:00:00 With loss: -350.1425
#
# 13216 New Long trade at price: 1171.638  On day: 2015-03-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13216 Long loss at price: 1166.568 On day: 2015-03-19 04:00:00 With loss: -322.9525
#
# 13401 New Short trade at price: 1182.684  On day: 2015-04-30 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13401 Short loss at price: 1190.398 On day: 2015-05-04 12:00:00 With loss: -349.9725
#
# 13457 New Long trade at price: 1214.918  On day: 2015-05-13 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13457 Long exited after 12 hours: 1224.921 On day: 2015-05-15 16:00:00 With profit: 998.3
#
# 14088 New Long trade at price: 1137.46  On day: 2015-10-02 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14088 Long loss at price: 1132.198 On day: 2015-10-05 08:00:00 With loss: -300.5075
#
# 14201 New Short trade at price: 1158.782  On day: 2015-10-28 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14201 Short profit at price: 1146.039 On day: 2015-10-29 16:00:00 With profit: 1014.52
#
# 14366 New Long trade at price: 1085.18  On day: 2015-12-04 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14366 Long loss at price: 1081.29 On day: 2015-12-07 08:00:00 With loss: -349.925
#
# 14807 New Long trade at price: 1258.761  On day: 2016-03-16 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14807 Long loss at price: 1250.869 On day: 2016-03-18 08:00:00 With loss: -434.23
#
# 15153 New Long trade at price: 1243.98  On day: 2016-06-03 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15153 Long loss at price: 1237.609 On day: 2016-06-07 08:00:00 With loss: -317.385
#
# 15432 New Short trade at price: 1336.449  On day: 2016-08-05 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15432 Short loss at price: 1339.619 On day: 2016-08-09 12:00:00 With loss: -299.14
#
# 15693 New Short trade at price: 1268.549  On day: 2016-10-04 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15693 Short loss at price: 1274.298 On day: 2016-10-05 00:00:00 With loss: -322.7025
#
# 15851 New Long trade at price: 1308.119  On day: 2016-11-09 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15851 Long loss at price: 1302.861 On day: 2016-11-09 08:00:00 With loss: -507.57
#
# 15916 New Short trade at price: 1187.022  On day: 2016-11-23 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15916 Short exited after 12 hours: 1183.778 On day: 2016-11-25 16:00:00 With profit: 322.4
#
# 16400 New Long trade at price: 1220.401  On day: 2017-03-15 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16400 Long profit at price: 1230.852 On day: 2017-03-17 08:00:00 With profit: 1002.3
#
# 16797 New Short trade at price: 1263.368  On day: 2017-06-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16797 Short profit at price: 1253.119 On day: 2017-06-16 00:00:00 With profit: 1015.32
#
# 18401 New Short trade at price: 1280.399  On day: 2018-06-15 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18401 Short loss at price: 1283.768 On day: 2018-06-19 00:00:00 With loss: -243.68
#
# 19618 New Long trade at price: 1315.365  On day: 2019-03-20 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 19618 Long loss at price: 1310.458 On day: 2019-03-21 12:00:00 With loss: -221.0775
#
# 19847 New Long trade at price: 1299.308  On day: 2019-05-13 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 19847 Long loss at price: 1294.308 On day: 2019-05-14 12:00:00 With loss: -194.5025
#
# 20305 New Long trade at price: 1528.448  On day: 2019-08-23 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 20305 Long profit at price: 1547.248 On day: 2019-08-25 20:00:00 With profit: 1355.17
#
# 22246 New Short trade at price: 1866.578  On day: 2020-11-09 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22246 Short loss at price: 1881.135 On day: 2020-11-10 00:00:00 With loss: -809.8425
#
# 23200 New Short trade at price: 1818.688  On day: 2021-06-16 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23200 Short profit at price: 1788.378 On day: 2021-06-17 08:00:00 With profit: 1978.2
#
# 23428 New Short trade at price: 1760.088  On day: 2021-08-06 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23428 Short profit at price: 1718.975 On day: 2021-08-08 20:00:00 With profit: 1621.26
#
# 24259 New Long trade at price: 1857.898  On day: 2022-02-11 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24259 Long loss at price: 1852.968 On day: 2022-02-14 00:00:00 With loss: -358.635
#
# 24959 New Long trade at price: 1719.528  On day: 2022-07-21 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24959 Long loss at price: 1713.578 On day: 2022-07-22 00:00:00 With loss: -411.225
#
# 25443 New Long trade at price: 1711.588  On day: 2022-11-08 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25443 Long loss at price: 1703.688 On day: 2022-11-09 16:00:00 With loss: -534.4225
#
# 25455 New Long trade at price: 1753.998  On day: 2022-11-10 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25455 Long exited after 12 hours: 1771.318 On day: 2022-11-14 12:00:00 With profit: 1730.0

# %%
pairs_results = {}
profits = {}
losses = {}
be = {}

for pair in range(len(pairs_list)):
    profits[pair] = []
    losses[pair] = []
    be[pair] = []
    
    pairs_results[pair] = pd.DataFrame.from_dict({(i, j): trade[pair][j] for j in trade[pair].keys()}, orient = 'index')
    pairs_results[pair] = pairs_results[pair].drop(['signal', 'ID', 'TP', 'SL'], axis = 1)
    pairs_results[pair].set_index('date_of_trade', inplace = True)
    pairs_results[pair]['cum_res'] = pairs_results[pair]['result'].cumsum() + account_size
    
    for t in trade[pair]:
        profits[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] > 0.1 else ''
        losses[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] < -0.1 else ''
        be[pair].append(trade[pair][t]['result']) if -0.1 <= trade[pair][t]['result'] <= 0.1 else ''
        
my_reduce = partial(pd.merge, on = 'date_of_trade', how = 'outer')
strategy_results = reduce(my_reduce, pairs_results.values())
strategy_results = strategy_results.sort_index()
strategy_results['final_res'] = strategy_results.filter(like = 'result', axis = 1).sum(axis = 1)
strategy_results['cum_res'] = strategy_results['final_res'].cumsum() + account_size

profits_keys = list(profits.keys())
profits_values = [profits[x] for x in profits_keys]
str_profits = list(flatten(profits_values))

losses_keys = list(losses.keys())
losses_values = [losses[x] for x in losses_keys]
str_losses = list(flatten(losses_values))

be_keys = list(be.keys())
be_values = [be[x] for x in be_keys]
str_be = list(flatten(be_values))
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_7452\518135374.py:22: FutureWarning: Passing 'suffixes' which cause duplicate columns {'result_x', 'cum_res_x', 'entry_price_x'} in the result is deprecated and will raise a MergeError in a future version.
#   strategy_results = reduce(my_reduce, pairs_results.values())
# C:\Users\Win10\AppData\Local\Temp\ipykernel_7452\518135374.py:22: FutureWarning: Passing 'suffixes' which cause duplicate columns {'result_x', 'cum_res_x', 'entry_price_x'} in the result is deprecated and will raise a MergeError in a future version.
#   strategy_results = reduce(my_reduce, pairs_results.values())
# C:\Users\Win10\AppData\Local\Temp\ipykernel_7452\518135374.py:22: FutureWarning: Passing 'suffixes' which cause duplicate columns {'result_x', 'cum_res_x', 'entry_price_x'} in the result is deprecated and will raise a MergeError in a future version.
#   strategy_results = reduce(my_reduce, pairs_results.values())

# %%
plt.figure(figsize = (26, 10))
for pair in range(len(pairs_list)):
    plt.plot(pairs_results[pair]['cum_res'], label = pairs_list[pair])
plt.legend()
plt.title('Returns of each pair', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Returns of each pair')

# %%
#Strategy performance
print('***** STRATEGY PERFORMANCE *****')
print('--------------------------------')
print('CAGR:', CAGR(strategy_results, df[0]), '%')
print('Sharpe ratio:', sharpe_ratio(strategy_results))
print('Maximum drawdown', max_drawdown(strategy_results), '% \n')
print('Number of trades:', len(str_profits + str_losses + str_be))
print('Number of profits:', len(str_profits))
print('Number of losses:', len(str_losses))
print('Number of breakevens:', len(str_be), '\n')
print('Winning percentage', (round(len(str_profits) / (len(str_profits) + len(str_losses)) * 100, 2)), '%')
print('ROI:', round(strategy_results['cum_res'][-1]) - account_size)
print('--------------------------------')
print('Average profitable trade:', round(sum(str_profits) / len(str_profits), 2))
print('Average lossing trade:', round(sum(str_losses) / len(str_losses), 2))
print('Max profitable trade:', round(max(str_profits), 2))
print('Max lossing trade:', round(min(str_losses), 2))

plt.figure(figsize = (26, 6))
plt.plot(strategy_results['cum_res'])
plt.title('return of strategy', fontsize = 18)
# Out:
# ***** STRATEGY PERFORMANCE *****
# --------------------------------
# CAGR: 68.8 %
# Sharpe ratio: 0.01
# Maximum drawdown 251.73 %
#
# Number of trades: 253
# Number of profits: 91
# Number of losses: 162
# Number of breakevens: 0
#
# Winning percentage 35.97 %
# ROI: 8379
# --------------------------------
# Average profitable trade: 262.25
# Average lossing trade: -95.6
# Max profitable trade: 1978.2
# Max lossing trade: -809.84
# c:\Users\Win10\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Text(0.5, 1.0, 'return of strategy')

# %%
#performance for each pair
for pair in range(len(pairs_list)):
    print(pairs_list[pair], '- PERFORMANCE')
    print('--------------------------------')
    print('Number of trades:', len(profits[pair] + losses[pair] + be[pair]))
    print('Number of profits:', len(profits[pair]))
    print('Number of losses:', len(losses[pair]))
    print('Number of breakevens:', len(be[pair]), '\n')
    print('Winning percentage', (round(len(profits[pair]) / (len(profits[pair]) + len(losses[pair])) * 100, 2)), '%')
    print('ROI:', round(pairs_results[pair]['cum_res'][-1] - account_size, 2))
    print('--------------------------------')
    print('Average profitable trade:', round(sum(profits[pair]) / len(profits[pair]), 2))
    print('Average lossing trade:', round(sum(losses[pair]) / len(losses[pair]), 2))
    print('Max profitable trade:', round(max(profits[pair]), 2))
    print('Max lossing trade:', round(min(losses[pair]), 2))
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx \n')
# Out:
# EURUSD/EURUSD_H4 - EURUSD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 42
# Number of profits: 17
# Number of losses: 25
# Number of breakevens: 0
#
# Winning percentage 40.48 %
# ROI: 721.06
# --------------------------------
# Average profitable trade: 67.8
# Average lossing trade: -17.26
# Max profitable trade: 165.45
# Max lossing trade: -31.28
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# AUDUSD/AUDUSD_H4 - AUDUSD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 23
# Number of profits: 8
# Number of losses: 15
# Number of breakevens: 0
#
# Winning percentage 34.78 %
# ROI: 155.38
# --------------------------------
# Average profitable trade: 52.19
# Average lossing trade: -17.47
# Max profitable trade: 106.8
# Max lossing trade: -28.14
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# GBPUSD/GBPUSD_H4 - GBPUSD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 22
# Number of profits: 7
# Number of losses: 15
# Number of breakevens: 0
#
# Winning percentage 31.82 %
# ROI: 405.78
# --------------------------------
# Average profitable trade: 108.35
# Average lossing trade: -23.51
# Max profitable trade: 422.02
# Max lossing trade: -39.49
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# NZDUSD/NZDUSD_H4 - NZDUSD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 23
# Number of profits: 6
# Number of losses: 17
# Number of breakevens: 0
#
# Winning percentage 26.09 %
# ROI: 78.65
# --------------------------------
# Average profitable trade: 64.2
# Average lossing trade: -18.03
# Max profitable trade: 90.83
# Max lossing trade: -26.02
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# USDCAD/USDCAD_H4 - USDCAD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 29
# Number of profits: 12
# Number of losses: 17
# Number of breakevens: 0
#
# Winning percentage 41.38 %
# ROI: 420.56
# --------------------------------
# Average profitable trade: 61.5
# Average lossing trade: -18.67
# Max profitable trade: 103.5
# Max lossing trade: -35.11
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# USDCHF/USDCHF_H4 - USDCHF_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 25
# Number of profits: 11
# Number of losses: 14
# Number of breakevens: 0
#
# Winning percentage 44.0 %
# ROI: 497.53
# --------------------------------
# Average profitable trade: 68.56
# Average lossing trade: -18.33
# Max profitable trade: 138.92
# Max lossing trade: -28.11
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# USDJPY/USDJPY_H4 - USDJPY_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 41
# Number of profits: 15
# Number of losses: 26
# Number of breakevens: 0
#
# Winning percentage 36.59 %
# ROI: 485.98
# --------------------------------
# Average profitable trade: 70.84
# Average lossing trade: -22.18
# Max profitable trade: 156.5
# Max lossing trade: -45.64
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# XAUUSD/XAUUSD_H4 - XAUUSD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 48
# Number of profits: 15
# Number of losses: 33
# Number of breakevens: 0
#
# Winning percentage 31.25 %
# ROI: 5613.61
# --------------------------------
# Average profitable trade: 1239.77
# Average lossing trade: -393.42
# Max profitable trade: 1978.2
# Max lossing trade: -809.84
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
