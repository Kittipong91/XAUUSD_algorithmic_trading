# %% [markdown]
# # Compare Result Equity

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt
from util.load_data import load_data

# %% [markdown]
# ## Load result strategy

# %%
strategy = {}

# %% [markdown]
# ### Data XAUUSD

# %%
XAUUSD = load_data()

# %% [markdown]
# ### Buy and Hold

# %%
benchmark = {}

# %%
benchmark['D1'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
benchmark['H4'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
benchmark['H1'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
benchmark['M30'] = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Buy and Hold'] = benchmark

# %% [markdown]
# ###  Linear Regression

# %%
Linear_Regression = {}
folder = 'Linear Regression'
Main_folder = 'Machine_Learning'
Sub_folder = 'Optimization'

# %%
for i in range(8):
    Linear_Regression[f'D1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Linear_Regression_WFA_{i+1}y_D1.csv', index_col='Time', parse_dates=True)
    Linear_Regression[f'H4_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Linear_Regression_WFA_{i+1}y_H4.csv', index_col='Time', parse_dates=True)
    Linear_Regression[f'H1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Linear_Regression_WFA_{i+1}y_H1.csv', index_col='Time', parse_dates=True)
    Linear_Regression[f'M30_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Linear_Regression_WFA_{i+1}y_M30.csv', index_col='Time', parse_dates=True)
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_15748\326066445.py:8: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Linear_Regression[f'M30_WFA_{i+1}y'] = pd.read_csv(

# %%
strategy['Linear Regression'] = Linear_Regression

# %%
strategy['Linear Regression'][f'D1_WFA_{0+1}y']['Equity']
# Out:
# Time
# 2007-01-01    10000.000000
# 2007-01-02    10000.000000
# 2007-01-03    10000.000000
# 2007-01-04    10000.000000
# 2007-01-05    10000.000000
#                   ...
# 2023-03-06     9716.834216
# 2023-03-07     9684.444216
# 2023-03-08     9682.751445
# 2023-03-09     9666.511445
# 2023-03-10     9666.132159
# Name: Equity, Length: 5043, dtype: float64

# %% [markdown]
# ###  Logistic Regression

# %%
Logistic_Regression = {}
folder = 'Logistic Regression'
Main_folder = 'Machine_Learning'
Sub_folder = 'Optimization'

# %%
for i in range(8):
    Logistic_Regression[f'D1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Logistic_Regressionon_WFA_{i+1}y_D1.csv', index_col='Time', parse_dates=True)
    Logistic_Regression[f'H4_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Logistic_Regressionon_WFA_{i+1}y_H4.csv', index_col='Time', parse_dates=True)
    Logistic_Regression[f'H1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Logistic_Regressionon_WFA_{i+1}y_H1.csv', index_col='Time', parse_dates=True)

# %%
for i in range(4):
    Logistic_Regression[f'M30_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Logistic_Regressionon_WFA_{i+1}y_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Logistic Regression'] = Logistic_Regression

# %% [markdown]
# ###  Multiple Linear Regression

# %%
Mutiple_Linear_Regression = {}
folder = 'Mutiple_Linear_Regression'
Main_folder = 'Machine_Learning'
Sub_folder = 'Optimization'

# %%
for i in range(8):
    Mutiple_Linear_Regression[f'D1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_D1.csv', index_col='Time', parse_dates=True)
    Mutiple_Linear_Regression[f'H4_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_H4.csv', index_col='Time', parse_dates=True)
    Mutiple_Linear_Regression[f'H1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_H1.csv', index_col='Time', parse_dates=True)
    Mutiple_Linear_Regression[f'M30_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_M30.csv', index_col='Time', parse_dates=True)
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_15748\160610532.py:8: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Mutiple_Linear_Regression[f'M30_WFA_{i+1}y'] = pd.read_csv(

# %%
strategy['Mutiple Linear Regression'] = Mutiple_Linear_Regression

# %% [markdown]
# ###  Support Vector Regression

# %%
Support_Vector_Regression = {}
folder = 'Support Vector Regression'
Main_folder = 'Machine_Learning'
Sub_folder = 'Optimization'

# %%
for i in range(8):
    Support_Vector_Regression[f'D1_WFA_{i+1}y'] = pd.read_csv(
        f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Support_Vector_Regression_WFA_{i+1}y_D1.csv', index_col='Time', parse_dates=True)
    # Support_Vector_Regression[f'H4_WFA_{i+1}y'] = pd.read_csv(
    #     f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_H4.csv', index_col='Time', parse_dates=True)
    # Support_Vector_Regression[f'H1_WFA_{i+1}y'] = pd.read_csv(
    #     f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_H1.csv', index_col='Time', parse_dates=True)
    # Support_Vector_Regression[f'M30_WFA_{i+1}y'] = pd.read_csv(
    #     f'../../out/{Main_folder}/{folder}/{Sub_folder}/result_Mutiple_Regression_WFA_{i+1}y_M30.csv', index_col='Time', parse_dates=True)

# %%
strategy['Support Vector Regression'] = Support_Vector_Regression

# %% [markdown]
# ## Shown Result

# %% [markdown]
# ### Linear Regression

# %%
ML = 'Linear Regression'

# %% [markdown]
# #### TF D1

# %%
TF = 'D1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == 'Linear Regression':
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF H4

# %%
TF = 'H4'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == 'Linear Regression':
            for j in range(8):
                # print(data)
                if j != 4:
                    y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                    # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                    plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF H1

# %%
TF = 'H1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == 'Linear Regression':
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF M30

# %%
TF = 'M30'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == 'Linear Regression':
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### Multiple Linear Regression

# %%
ML = 'Mutiple Linear Regression'

# %% [markdown]
# #### TF D1

# %%
TF = 'D1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        # print(data)

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'Multiple Linear Regression  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF H4

# %%
TF = 'H4'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                if j != 4:
                    y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                    # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                    plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'Multiple Linear Regression  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF H1

# %%
TF = 'H1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'Multiple Linear Regression  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF M30

# %%
TF = 'M30'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
ML = 'Logistic Regression'

# %% [markdown]
# #### TF D1

# %%
TF = 'D1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        # print(data)

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF H4

# %%
TF = 'H4'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                if j != 4:
                    y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                    # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                    plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF H1

# %%
TF = 'H1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### TF M30

# %%
TF = 'M30'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(4):
                # print(data)

                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### Support Vector Regression

# %%
ML = 'Support Vector Regression'

# %% [markdown]
# #### TF D1

# %%
TF = 'D1'

# %%
x = XAUUSD[TF].index  # Using the index directly without calling it

with plt.style.context('seaborn-v0_8-whitegrid'):
    for i, data in enumerate(strategy):
        # print(data)

        if data == 'Buy and Hold':
            y = strategy[f'{data}'][TF]['Equity']
            # print('skip Buy and Hold')
            plt.plot(x, y, label=f'{data}',
                     color='black', linewidth=3, zorder=20)
        elif data == ML:
            for j in range(8):
                # print(data)
                y = strategy[f'{data}'][f'{TF}_WFA_{j+1}y']['Equity']

                # ใช้ axs[1] เพื่อพล็อตในกราฟที่สอง
                plt.plot(x, y, label=f'{data}_{TF}_WFA_{j+1}y')

        plt.title(f'{ML}  WFA  {TF}')
        plt.xlabel('Date 2007 - 2020', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        plt.ylabel('Equity', fontsize=14)
        # ใช้ legend ในกราฟแรก
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        # ใช้ legend ในกราฟที่สอง
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
