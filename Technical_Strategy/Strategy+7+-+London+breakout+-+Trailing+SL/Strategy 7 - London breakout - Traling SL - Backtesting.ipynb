# %% [markdown]
# # London breakout

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
from config.constants import *
from backtesting import Backtest
from util.plot_equity import plot_equity_trades
from util.load_data import load_data
from London_breakout import London_breakout
from util.Save_result_return import save_to_csv

# %% [markdown]
# ## Get Data

# %%
XAUUSD = load_data()

# %%
XAUUSD['D1'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5043 entries, 2007-01-01 to 2023-03-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5043 non-null   float64
#  1   High    5043 non-null   float64
#  2   Low     5043 non-null   float64
#  3   Close   5043 non-null   float64
#  4   Volume  5043 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 236.4 KB

# %% [markdown]
# ## Define Strategy

# %%
strategy = London_breakout

# %%
account_size = 10000

# %% [markdown]
# # Backtest each time frame

# %% [markdown]
# ## TF D1

# %%
Backtest_D1 = Backtest(XAUUSD['D1'], strategy, cash=account_size, margin=1/100,  commission=0.0002 )
result_D1 = Backtest_D1.run()
result_D1
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 00:00:00
# Duration                   5912 days 00:00:00
# Exposure Time [%]                         0.0
# Equity Final [$]                      10000.0
# Equity Peak [$]                       10000.0
# Return [%]                                0.0
# Buy & Hold Return [%]               193.12344
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     0.0
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              NaN
# Max. Drawdown [%]                        -0.0
# Avg. Drawdown [%]                         NaN
# Max. Drawdown Duration                    NaN
# Avg. Drawdown Duration                    NaN
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# _strategy                     London_breakout
# _equity_curve                          Equ...
# _trades                   Empty DataFrame
# ...
# dtype: object

# %%
plot_equity_trades(result_D1['_equity_curve'],'XAUUSD_D1' , account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_D1, '../../out/Technical_Strategy/London_breakout/Backtest/result_D1.csv')

# %% [markdown]
# ## TF H4

# %%
Backtest_H4 = Backtest(XAUUSD['H4'], strategy,
                       cash=account_size, margin=1/100,  commission=0.0002 )
result_H4 = Backtest_H4.run()
result_H4
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 16:00:00
# Duration                   5912 days 16:00:00
# Exposure Time [%]                         0.0
# Equity Final [$]                      10000.0
# Equity Peak [$]                       10000.0
# Return [%]                                0.0
# Buy & Hold Return [%]              193.329158
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     0.0
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              NaN
# Max. Drawdown [%]                        -0.0
# Avg. Drawdown [%]                         NaN
# Max. Drawdown Duration                    NaN
# Avg. Drawdown Duration                    NaN
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# _strategy                     London_breakout
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object

# %%
plot_equity_trades(result_H4['_equity_curve'], 'XAUUSD_H4' , account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_H4, '../../out/Technical_Strategy/London_breakout/Backtest/result_H4.csv')

# %% [markdown]
# ## TF H1

# %%
Backtest_H1 = Backtest(XAUUSD['H1'], strategy,
                       cash=account_size, margin=1/100,  commission=0.0002 )
result_H1 = Backtest_H1.run()
result_H1
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 17:00:00
# Duration                   5912 days 17:00:00
# Exposure Time [%]                    6.841987
# Equity Final [$]                  9781.777251
# Equity Peak [$]                  10025.460008
# Return [%]                          -2.182227
# Buy & Hold Return [%]               193.27055
# Return (Ann.) [%]                   -0.110193
# Volatility (Ann.) [%]                0.469126
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                    -2.85769
# Avg. Drawdown [%]                   -0.390327
# Max. Drawdown Duration     5404 days 10:00:00
# Avg. Drawdown Duration      590 days 03:00:00
# # Trades                                 2005
# Win Rate [%]                        18.653367
# Best Trade [%]                       2.533455
# Worst Trade [%]                     -0.891873
# Avg. Trade [%]                      -0.010843
# Max. Trade Duration           6 days 21:00:00
# Avg. Trade Duration           0 days 03:00:00
# Profit Factor                        0.922765
# Expectancy [%]                      -0.010235
# SQN                                 -1.048748
# _strategy                     London_breakout
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object

# %%
plot_equity_trades(result_H1['_equity_curve'], 'XAUUSD_H1', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_H1, '../../out/Technical_Strategy/London_breakout/Backtest/result_H1.csv')

# %% [markdown]
# ## TF M30

# %%
Backtest_M30 = Backtest(XAUUSD['M30'], strategy,
                       cash=account_size, margin=1/100,  commission=0.0002 )
result_M30 = Backtest_M30.run()
result_M30
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 17:30:00
# Duration                   5912 days 17:30:00
# Exposure Time [%]                    3.954169
# Equity Final [$]                  9189.978126
# Equity Peak [$]                  10002.178032
# Return [%]                          -8.100219
# Buy & Hold Return [%]              193.338852
# Return (Ann.) [%]                   -0.421217
# Volatility (Ann.) [%]                0.335971
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -8.228882
# Avg. Drawdown [%]                   -4.181107
# Max. Drawdown Duration     5856 days 10:30:00
# Avg. Drawdown Duration     2954 days 07:45:00
# # Trades                                 3169
# Win Rate [%]                         17.00852
# Best Trade [%]                       2.174928
# Worst Trade [%]                     -0.565289
# Avg. Trade [%]                      -0.019994
# Max. Trade Duration           2 days 13:30:00
# Avg. Trade Duration           0 days 00:45:00
# Profit Factor                        0.751275
# Expectancy [%]                      -0.019811
# SQN                                 -5.659978
# _strategy                     London_breakout
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object

# %%
plot_equity_trades(result_M30['_equity_curve'], 'XAUUSD_M30', account_size)

# %% [markdown]
# ### Save output

# %%
save_to_csv(result_M30, '../../out/Technical_Strategy/London_breakout/Backtest/result_M30.csv')
