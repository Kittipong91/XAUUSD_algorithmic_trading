# %% [markdown]
# # London breakout

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get Result

# %% [markdown]
# ## Load results strategy Buy and Hold

# %%
benchmark_D1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
benchmark_H4 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
benckmark_H1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
benckmark_M30 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %% [markdown]
# ## Load results Strategy

# %%
folder_strategy = 'London_breakout'

# %%
result_D1 = pd.read_csv(f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
result_H4 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
result_H1 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
result_M30 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %% [markdown]
# ## Define Strategy

# %% [markdown]
# # Reports each time frame

# %% [markdown]
# ## TF D1

# %%
qs.reports.full(result_D1['returns'])

# %% [markdown]
# ### Reports

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_D1['returns'], benchmark=benchmark_D1)

# %% [markdown]
# ## TF H4

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_H4['returns'],benchmark=benchmark_H4)

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_H4['returns'], benchmark=benchmark_H4)

# %% [markdown]
# ## TF H1

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_H1['returns'])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2007-01-01
# End Period                 2023-03-10
# Risk-Free Rate             0.0%
# Time in Market             7.0%
#
# Cumulative Return          1.58%
# CAGR﹪                     0.07%
#
# Sharpe                     0.08
# Prob. Sharpe Ratio         94.32%
# Smart Sharpe               0.08
# Sortino                    0.13
# Smart Sortino              0.13
# Sortino/√2                 0.09
# Smart Sortino/√2           0.09
# Omega                      1.06
#
# Max Drawdown               -0.94%
# Longest DD Days            1689
# Volatility (ann.)          0.05%
# Calmar                     0.07
# Skew                       3.92
# Kurtosis                   120.11
#
# Expected Daily %           0.0%
# Expected Monthly %         0.01%
# Expected Yearly %          0.09%
# Kelly Criterion            2.41%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.01%
# Expected Shortfall (cVaR)  -0.01%
#
# Max Consecutive Wins       7
# Max Consecutive Losses     7
# Gain/Pain Ratio            0.1
# Gain/Pain (1M)             0.35
#
# Payoff Ratio               1.25
# Profit Factor              1.06
# Common Sense Ratio         -
# CPC Index                  0.6
# Tail Ratio                 -
# Outlier Win Ratio          34.21
# Outlier Loss Ratio         1.28
#
# MTD                        -0.04%
# 3M                         -0.08%
# 6M                         0.04%
# YTD                        -0.13%
# 1Y                         0.35%
# 3Y (ann.)                  0.11%
# 5Y (ann.)                  0.07%
# 10Y (ann.)                 0.1%
# All-time (ann.)            0.07%
#
# Best Day                   0.13%
# Worst Day                  -0.05%
# Best Month                 0.35%
# Worst Month                -0.21%
# Best Year                  1.02%
# Worst Year                 -0.28%
#
# Avg. Drawdown              -0.05%
# Avg. Drawdown Days         59
# Recovery Factor            1.67
# Ulcer Index                0.0
# Serenity Index             0.03
#
# Avg. Up Month              0.06%
# Avg. Down Month            -0.05%
# Win Days %                 45.77%
# Win Month %                50.77%
# Win Quarter %              58.46%
# Win Year %                 52.94%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-08-27  2011-10-03  2013-04-12  1689     -0.942262         -0.888205
# 2  2019-04-15  2020-08-20  2022-08-15  1218     -0.500201         -0.458526
# 3  2014-04-29  2014-11-14  2015-03-06   312     -0.329069         -0.311860
# 4  2015-03-09  2017-04-25  2018-04-04  1122     -0.266588         -0.257372
# 5  2013-09-16  2013-10-14  2013-12-05    81     -0.207337         -0.197480
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_H1['returns'], benchmark=benckmark_H1)
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-02   2007-01-02
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       7.0%
#
# Cumulative Return          6.08%        1.58%
# CAGR﹪                     0.25%        0.07%
#
# Sharpe                     0.07         0.08
# Prob. Sharpe Ratio         91.2%        94.32%
# Smart Sharpe               0.07         0.08
# Sortino                    0.1          0.13
# Smart Sortino              0.1          0.13
# Sortino/√2                 0.07         0.09
# Smart Sortino/√2           0.07         0.09
# Omega                      1.06         1.06
#
# Max Drawdown               -4.08%       -0.94%
# Longest DD Days            3247         1689
# Volatility (ann.)          0.22%        0.05%
# R^2                        0.0          0.0
# Information Ratio          -0.0         -0.0
# Calmar                     0.06         0.07
# Skew                       -0.47        3.92
# Kurtosis                   24.36        120.07
#
# Expected Daily %           0.0%         0.0%
# Expected Monthly %         0.03%        0.01%
# Expected Yearly %          0.35%        0.09%
# Kelly Criterion            4.32%        -0.47%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.02%       -0.01%
# Expected Shortfall (cVaR)  -0.02%       -0.01%
#
# Max Consecutive Wins       14           7
# Max Consecutive Losses     12           7
# Gain/Pain Ratio            0.06         0.1
# Gain/Pain (1M)             0.29         0.35
#
# Payoff Ratio               1.08         1.17
# Profit Factor              1.01         1.06
# Common Sense Ratio         1.01         -
# CPC Index                  0.55         0.57
# Tail Ratio                 1.0          -
# Outlier Win Ratio          2.97         80.94
# Outlier Loss Ratio         2.99         3.34
#
# MTD                        0.14%        -0.04%
# 3M                         0.28%        -0.08%
# 6M                         0.66%        0.04%
# YTD                        0.15%        -0.13%
# 1Y                         -0.65%       0.35%
# 3Y (ann.)                  0.19%        0.11%
# 5Y (ann.)                  0.35%        0.07%
# 10Y (ann.)                 0.09%        0.1%
# All-time (ann.)            0.25%        0.07%
#
# Best Day                   0.22%        0.13%
# Worst Day                  -0.38%       -0.05%
# Best Month                 1.01%        0.35%
# Worst Month                -0.96%       -0.21%
# Best Year                  1.82%        1.02%
# Worst Year                 -2.23%       -0.28%
#
# Avg. Drawdown              -0.07%       -0.05%
# Avg. Drawdown Days         18           59
# Recovery Factor            1.47         1.67
# Ulcer Index                0.02         0.0
# Serenity Index             0.01         0.03
#
# Avg. Up Month              0.26%        0.06%
# Avg. Down Month            -0.24%       -0.05%
# Win Days %                 50.4%        45.77%
# Win Month %                51.79%       50.77%
# Win Quarter %              64.62%       58.46%
# Win Year %                 64.71%       52.94%
#
# Beta                       -            -0.0
# Alpha                      -            0.0
# Correlation                -            -0.23%
# Treynor Ratio              -            -3052.84%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-08-27  2011-10-03  2013-04-12  1689     -0.942262         -0.888205
# 2  2019-04-15  2020-08-20  2022-08-15  1218     -0.500201         -0.458526
# 3  2014-04-29  2014-11-14  2015-03-06   312     -0.329069         -0.311860
# 4  2015-03-09  2017-04-25  2018-04-04  1122     -0.266588         -0.257372
# 5  2013-09-16  2013-10-14  2013-12-05    81     -0.207337         -0.197480
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ## TF M30

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_M30['returns'])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2007-01-01
# End Period                 2023-03-10
# Risk-Free Rate             0.0%
# Time in Market             4.0%
#
# Cumulative Return          0.2%
# CAGR﹪                     0.01%
#
# Sharpe                     0.01
# Prob. Sharpe Ratio         60.66%
# Smart Sharpe               0.01
# Sortino                    0.02
# Smart Sortino              0.02
# Sortino/√2                 0.01
# Smart Sortino/√2           0.01
# Omega                      1.01
#
# Max Drawdown               -0.8%
# Longest DD Days            2069
# Volatility (ann.)          0.03%
# Calmar                     0.01
# Skew                       9.37
# Kurtosis                   602.66
#
# Expected Daily %           0.0%
# Expected Monthly %         0.0%
# Expected Yearly %          0.01%
# Kelly Criterion            0.38%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.0%
# Expected Shortfall (cVaR)  -0.0%
#
# Max Consecutive Wins       8
# Max Consecutive Losses     6
# Gain/Pain Ratio            0.02
# Gain/Pain (1M)             0.05
#
# Payoff Ratio               1.37
# Profit Factor              1.01
# Common Sense Ratio         -
# CPC Index                  0.59
# Tail Ratio                 -
# Outlier Win Ratio          30.86
# Outlier Loss Ratio         0.88
#
# MTD                        -0.04%
# 3M                         0.01%
# 6M                         0.12%
# YTD                        -0.03%
# 1Y                         0.14%
# 3Y (ann.)                  -0.02%
# 5Y (ann.)                  -0.03%
# 10Y (ann.)                 0.05%
# All-time (ann.)            0.01%
#
# Best Day                   0.14%
# Worst Day                  -0.07%
# Best Month                 0.17%
# Worst Month                -0.28%
# Best Year                  0.61%
# Worst Year                 -0.2%
#
# Avg. Drawdown              -0.06%
# Avg. Drawdown Days         107
# Recovery Factor            0.25
# Ulcer Index                0.0
# Serenity Index             0.0
#
# Avg. Up Month              0.04%
# Avg. Down Month            -0.04%
# Win Days %                 42.37%
# Win Month %                51.28%
# Win Quarter %              41.54%
# Win Year %                 52.94%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-09-18  2011-09-02  2014-05-19  2069     -0.795895         -0.748011
# 2  2020-02-27  2022-10-25  2023-03-10  1108     -0.597174         -0.575392
# 3  2019-03-11  2020-01-03  2020-01-24   319     -0.184141         -0.176503
# 4  2007-02-26  2007-10-19  2008-04-03   403     -0.178112         -0.171988
# 5  2016-11-11  2017-10-25  2018-11-07   727     -0.162448         -0.151180
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_M30['returns'], benchmark=benckmark_M30)
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-02   2007-01-02
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       4.0%
#
# Cumulative Return          6.12%        0.2%
# CAGR﹪                     0.25%        0.01%
#
# Sharpe                     0.05         0.01
# Prob. Sharpe Ratio         91.28%       60.66%
# Smart Sharpe               0.05         0.01
# Sortino                    0.07         0.02
# Smart Sortino              0.07         0.02
# Sortino/√2                 0.05         0.01
# Smart Sortino/√2           0.05         0.01
# Omega                      1.01         1.01
#
# Max Drawdown               -4.1%        -0.8%
# Longest DD Days            3247         2069
# Volatility (ann.)          0.16%        0.03%
# R^2                        0.0          0.0
# Information Ratio          -0.0         -0.0
# Calmar                     0.06         0.01
# Skew                       -0.57        9.37
# Kurtosis                   28.64        602.47
#
# Expected Daily %           0.0%         0.0%
# Expected Monthly %         0.03%        0.0%
# Expected Yearly %          0.35%        0.01%
# Kelly Criterion            6.63%        -0.06%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.02%       -0.0%
# Expected Shortfall (cVaR)  -0.02%       -0.0%
#
# Max Consecutive Wins       24           8
# Max Consecutive Losses     15           6
# Gain/Pain Ratio            0.06         0.02
# Gain/Pain (1M)             0.29         0.05
#
# Payoff Ratio               1.14         1.36
# Profit Factor              1.01         1.01
# Common Sense Ratio         1.02         -
# CPC Index                  0.58         0.58
# Tail Ratio                 1.01         -
# Outlier Win Ratio          2.63         137.7
# Outlier Loss Ratio         2.77         3.42
#
# MTD                        0.18%        -0.04%
# 3M                         0.32%        0.01%
# 6M                         0.7%         0.12%
# YTD                        0.18%        -0.03%
# 1Y                         -0.64%       0.14%
# 3Y (ann.)                  0.2%         -0.02%
# 5Y (ann.)                  0.35%        -0.03%
# 10Y (ann.)                 0.09%        0.05%
# All-time (ann.)            0.25%        0.01%
#
# Best Day                   0.19%        0.14%
# Worst Day                  -0.34%       -0.07%
# Best Month                 1.01%        0.17%
# Worst Month                -0.96%       -0.28%
# Best Year                  1.82%        0.61%
# Worst Year                 -2.23%       -0.2%
#
# Avg. Drawdown              -0.06%       -0.06%
# Avg. Drawdown Days         14           107
# Recovery Factor            1.47         0.25
# Ulcer Index                0.02         0.0
# Serenity Index             0.01         0.0
#
# Avg. Up Month              0.26%        0.04%
# Avg. Down Month            -0.2%        -0.04%
# Win Days %                 50.27%       42.37%
# Win Month %                51.79%       51.28%
# Win Quarter %              64.62%       41.54%
# Win Year %                 64.71%       52.94%
#
# Beta                       -            -0.0
# Alpha                      -            0.0
# Correlation                -            -0.16%
# Treynor Ratio              -            -760.0%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-09-18  2011-09-02  2014-05-19  2069     -0.795895         -0.748011
# 2  2020-02-27  2022-10-25  2023-03-10  1108     -0.597174         -0.575392
# 3  2019-03-11  2020-01-03  2020-01-24   319     -0.184141         -0.176503
# 4  2007-02-26  2007-10-19  2008-04-03   403     -0.178112         -0.171988
# 5  2016-11-11  2017-10-25  2018-11-07   727     -0.162448         -0.151180
# <h4>Strategy Visualization</h4>
