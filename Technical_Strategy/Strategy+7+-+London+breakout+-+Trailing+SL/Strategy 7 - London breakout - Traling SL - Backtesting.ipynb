# %% [markdown]
# # London breakout

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
from config.constants import *
from backtesting import Backtest
from util.plot_equity import plot_equity_trades
from util.load_data import load_data
from London_breakout import London_breakout
from util.Save_result_return import save_to_csv

# %% [markdown]
# ## Get Data

# %%
XAUUSD = load_data()

# %%
XAUUSD['D1'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5043 entries, 2007-01-01 to 2023-03-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5043 non-null   float64
#  1   High    5043 non-null   float64
#  2   Low     5043 non-null   float64
#  3   Close   5043 non-null   float64
#  4   Volume  5043 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 236.4 KB

# %% [markdown]
# ## Define Strategy

# %%
strategy = London_breakout

# %%
account_size = 20000

# %% [markdown]
# # Backtest each time frame

# %% [markdown]
# ## TF D1

# %%
Backtest_D1 = Backtest(XAUUSD['D1'], strategy, cash=account_size, margin=1/2000, )
result_D1 = Backtest_D1.run()
result_D1
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 00:00:00
# Duration                   5912 days 00:00:00
# Exposure Time [%]                         0.0
# Equity Final [$]                      20000.0
# Equity Peak [$]                       20000.0
# Return [%]                                0.0
# Buy & Hold Return [%]               193.12344
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     0.0
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              NaN
# Max. Drawdown [%]                        -0.0
# Avg. Drawdown [%]                         NaN
# Max. Drawdown Duration                    NaN
# Avg. Drawdown Duration                    NaN
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# _strategy                     London_breakout
# _equity_curve                          Equ...
# _trades                   Empty DataFrame
# ...
# dtype: object

# %%
plot_equity_trades(result_D1['_trades'],'XAUUSD_D1' , account_size)

# %% [markdown]
# ### Save output

# %%
# save_to_csv(result_D1, '../../out/Technical_Strategy/London_breakout/Backtest/result_D1.csv')

# %% [markdown]
# ## TF H4

# %%
Backtest_H4 = Backtest(XAUUSD['H4'], strategy,
                       cash=account_size, margin=1/2000, )
result_H4 = Backtest_H4.run()
result_H4
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 16:00:00
# Duration                   5912 days 16:00:00
# Exposure Time [%]                         0.0
# Equity Final [$]                      20000.0
# Equity Peak [$]                       20000.0
# Return [%]                                0.0
# Buy & Hold Return [%]              193.329158
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     0.0
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              NaN
# Max. Drawdown [%]                        -0.0
# Avg. Drawdown [%]                         NaN
# Max. Drawdown Duration                    NaN
# Avg. Drawdown Duration                    NaN
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# _strategy                     London_breakout
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object

# %%
plot_equity_trades(result_H4['_trades'], 'XAUUSD_H4' , account_size)

# %% [markdown]
# ### Save output

# %%
# save_to_csv(result_H4, '../../out/Technical_Strategy/London_breakout/Backtest/result_H4.csv')

# %% [markdown]
# ## TF H1

# %%
Backtest_H1 = Backtest(XAUUSD['H1'], strategy,
                       cash=account_size, margin=1/2000, )
result_H1 = Backtest_H1.run()
result_H1
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 17:00:00
# Duration                   5912 days 17:00:00
# Exposure Time [%]                    6.841987
# Equity Final [$]                  20316.37235
# Equity Peak [$]                  20358.102375
# Return [%]                           1.581862
# Buy & Hold Return [%]               193.27055
# Return (Ann.) [%]                    0.078458
# Volatility (Ann.) [%]                0.230157
# Sharpe Ratio                          0.34089
# Sortino Ratio                        0.796829
# Calmar Ratio                         0.083266
# Max. Drawdown [%]                   -0.942262
# Avg. Drawdown [%]                   -0.053864
# Max. Drawdown Duration     1688 days 23:00:00
# Avg. Drawdown Duration       58 days 08:00:00
# # Trades                                 2005
# Win Rate [%]                        18.653367
# Best Trade [%]                       2.552949
# Worst Trade [%]                     -0.871694
# Avg. Trade [%]                       0.009153
# Max. Trade Duration           6 days 21:00:00
# Avg. Trade Duration           0 days 03:00:00
# Profit Factor                        1.083969
# Expectancy [%]                       0.009761
# SQN                                  1.520124
# _strategy                     London_breakout
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object

# %%
plot_equity_trades(result_H1['_trades'], 'XAUUSD_H1', account_size)

# %% [markdown]
# ### Save output

# %%
# save_to_csv(result_H1, '../../out/Technical_Strategy/London_breakout/Backtest/result_H1.csv')

# %% [markdown]
# ## TF M30

# %%
Backtest_M30 = Backtest(XAUUSD['M30'], strategy,
                       cash=account_size, margin=1/2000, )
result_M30 = Backtest_M30.run()
result_M30
# Out:
# Start                     2007-01-01 00:00:00
# End                       2023-03-10 17:30:00
# Duration                   5912 days 17:30:00
# Exposure Time [%]                    3.954169
# Equity Final [$]                 20039.241425
# Equity Peak [$]                  20117.640125
# Return [%]                           0.196207
# Buy & Hold Return [%]              193.338852
# Return (Ann.) [%]                    0.009795
# Volatility (Ann.) [%]                0.161093
# Sharpe Ratio                         0.060806
# Sortino Ratio                        0.142981
# Calmar Ratio                         0.012307
# Max. Drawdown [%]                   -0.795895
# Avg. Drawdown [%]                   -0.058477
# Max. Drawdown Duration     2068 days 23:30:00
# Avg. Drawdown Duration      106 days 10:16:00
# # Trades                                 3169
# Win Rate [%]                         17.00852
# Best Trade [%]                       2.194493
# Worst Trade [%]                     -0.545176
# Avg. Trade [%]                       0.000004
# Max. Trade Duration           2 days 13:30:00
# Avg. Trade Duration           0 days 00:45:00
# Profit Factor                        1.002971
# Expectancy [%]                       0.000187
# SQN                                  0.274268
# _strategy                     London_breakout
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object

# %%
plot_equity_trades(result_M30['_trades'], 'XAUUSD_M30', account_size)

# %% [markdown]
# ### Save output

# %%
# save_to_csv(result_M30, '../../out/Technical_Strategy/London_breakout/Backtest/result_M30.csv')
