# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load result strategy

# %%
folder_strategy = 'Momentum'

# %%
result_D1 = pd.read_csv(f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
result_H4 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
result_H1 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
result_M30 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %%
result_strategy = result_D1.copy()

# %%
result_strategy['returns_D1'] = result_D1['returns']
result_strategy['returns_H4'] = result_H4['returns']

# %%
result_strategy
# Out:
#                  returns    returns_D1  returns_H4
# Time
# 2007-01-01  0.000000e+00  0.000000e+00    0.000000
# 2007-01-02  0.000000e+00  0.000000e+00    0.000000
# 2007-01-03  0.000000e+00  0.000000e+00    0.000000
# 2007-01-04  0.000000e+00  0.000000e+00    0.000000
# 2007-01-05  0.000000e+00  0.000000e+00    0.000000
# ...                  ...           ...         ...
# 2023-03-06  3.090330e-04  3.090330e-04   -0.000119
# 2023-03-07  1.667748e-03  1.667748e-03   -0.000055
# 2023-03-08 -6.733906e-05 -6.733906e-05    0.000184
# 2023-03-09 -8.348549e-04 -8.348549e-04    0.000070
# 2023-03-10 -6.688536e-07 -6.688536e-07    0.000103
#
# [5043 rows x 3 columns]

# %%
qs.reports.full(result_D1['returns'])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2007-01-01
# End Period                 2023-03-10
# Risk-Free Rate             0.0%
# Time in Market             89.0%
#
# Cumulative Return          -2.82%
# CAGR﹪                     -0.12%
#
# Sharpe                     -0.15
# Prob. Sharpe Ratio         24.83%
# Smart Sharpe               -0.15
# Sortino                    -0.22
# Smart Sortino              -0.21
# Sortino/√2                 -0.15
# Smart Sortino/√2           -0.15
# Omega                      0.97
#
# Max Drawdown               -5.01%
# Longest DD Days            5323
# Volatility (ann.)          0.91%
# Calmar                     -0.02
# Skew                       0.07
# Kurtosis                   6.19
#
# Expected Daily %           -0.0%
# Expected Monthly %         -0.01%
# Expected Yearly %          -0.17%
# Kelly Criterion            -1.42%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.1%
# Expected Shortfall (cVaR)  -0.1%
#
# Max Consecutive Wins       11
# Max Consecutive Losses     9
# Gain/Pain Ratio            -0.03
# Gain/Pain (1M)             -0.12
#
# Payoff Ratio               1.12
# Profit Factor              0.97
# Common Sense Ratio         1.04
# CPC Index                  0.51
# Tail Ratio                 1.07
# Outlier Win Ratio          5.21
# Outlier Loss Ratio         4.02
#
# MTD                        -0.03%
# 3M                         -0.03%
# 6M                         -0.22%
# YTD                        -0.17%
# 1Y                         -0.61%
# 3Y (ann.)                  -0.03%
# 5Y (ann.)                  0.09%
# 10Y (ann.)                 -0.17%
# All-time (ann.)            -0.12%
#
# Best Day                   0.43%
# Worst Day                  -0.44%
# Best Month                 0.81%
# Worst Month                -0.85%
# Best Year                  0.82%
# Worst Year                 -0.97%
#
# Avg. Drawdown              -0.41%
# Avg. Drawdown Days         307
# Recovery Factor            0.55
# Ulcer Index                0.03
# Serenity Index             -0.01
#
# Avg. Up Month              0.21%
# Avg. Down Month            -0.23%
# Win Days %                 46.35%
# Win Month %                48.72%
# Win Quarter %              44.62%
# Win Year %                 41.18%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-08-13  2018-04-12  2023-03-10  5323     -5.012349         -4.893659
# 2  2007-02-02  2007-09-06  2007-11-07   279     -0.431006         -0.400983
# 3  2007-11-09  2007-12-26  2008-01-20    73     -0.372451         -0.332192
# 4  2008-01-22  2008-02-15  2008-03-02    41     -0.356667         -0.349248
# 5  2008-05-22  2008-06-10  2008-06-30    40     -0.316626         -0.313284
# <h4>Strategy Visualization</h4>
