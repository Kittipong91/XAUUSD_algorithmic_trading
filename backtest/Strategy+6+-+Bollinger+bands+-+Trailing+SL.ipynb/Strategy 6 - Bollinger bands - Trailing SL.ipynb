# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
import os
import matplotlib.style
from pandas.core.common import flatten
from functools import partial, reduce

# %%
import sys
sys.path.append('../../')

# %%
from config.constants import *

# %%
plt.style.use('ggplot')

# %%
pairs_list = [
    'XAUUSD/XAUUSD_H4 - XAUUSD_H4',
]

# %%
df = {}
for pair in range(len(pairs_list)):
    df[pair] = pd.read_csv(PATH_DATA + SYMBOL['XAUUSD']['H4'] + '.csv', index_col='Time', parse_dates=True)

# %%
def Bollinger_bands(df, window, std_mult):
    df['rolling_mean'] = df['Close'].rolling(window).mean()
    df['rolling_std'] = df['Close'].rolling(window).std()
    df['upper_band'] = df['rolling_mean'] + (df['rolling_std'] * std_mult)
    df['lower_band'] = df['rolling_mean'] - (df['rolling_std'] * std_mult)
    return df

def SMA(df, fast, slow):
    df['sma_fast'] = df['Close'].rolling(fast).mean()
    df['sma_slow'] = df['Close'].rolling(slow).mean()
    return df

def ATR(df, n):
    df = df.copy()
    df['High-Low'] = abs(df['High'] - df['Low'])
    df['High-PrevClose'] = abs(df['High'] - df['Close'].shift(1))
    df['Low-PrevClose'] = abs(df['Low'] - df['Close'].shift(1))
    df['TR'] = df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis = 1, skipna = False)
    df['ATR'] = df['TR'].rolling(n).mean()
    df = df.drop(['High-Low', 'High-PrevClose', 'Low-PrevClose'], axis = 1)
    return df

def CAGR(df, source_df,account_size):
    df = df.copy()
    n = len(source_df) / (252*24)
    return round((((df['cum_res'][-1] / account_size)**(1/n)) - 1) * 100, 1)

def sharpe_ratio(df):
    df = df.copy()
    returns = df['cum_res'].pct_change()
    volatility = returns.std() * np.sqrt(252)
    return round((returns.mean() - 0.02) / volatility, 2)

def max_drawdown(df):
    df = df.copy()
    cum_returns = (1 + df['cum_res']).cumprod()
    drawdown = 1 - df['cum_res'].div(df['cum_res'].cummax())
    return round(max(drawdown.expanding().max() * 100), 2)

# %%
#Strategy parameters
account_size = 1000
slippage = 2
size = 1
ATR_SL = 0.5

for pair in range(len(pairs_list)):
    df[pair]['ATR'] = ATR(df[pair], 20)['ATR']
    df[pair]['sma_fast'] = SMA(df[pair], 50, 200)['sma_fast']
    df[pair]['upper_band'] = Bollinger_bands(df[pair], 50, 3)['upper_band']
    if 'USDJPY/USDJPY_H4 - USDJPY_H4'  not in pairs_list[pair] and 'XAUUSD/XAUUSD_H4 - XAUUSD_H4'  not in pairs_list[pair] :
        df[pair]['spread'] = float(slippage) / float(10000)
        df[pair]['size'] = float(size) * float(10000)
        print('Pair: ', pairs_list[pair], 'a')
    else:
        df[pair]['spread'] = float(slippage) / float(100)
        df[pair]['size'] = float(size) * float(100)
        print('Pair: ', pairs_list[pair], 'b')
# Out:
# Pair:  XAUUSD/XAUUSD_H4 - XAUUSD_H4 b

# %%
open_trade = {}
trade = {}
long_take_profit = {}
short_take_profit = {}
long_stop_loss = {}
short_stop_loss = {}
long_entry_price = {}
short_entry_price = {}

for pair in range(len(pairs_list)):
    open_trade[pair] = []
    trade[pair] = {}
    long_take_profit[pair] = []
    short_take_profit[pair] = []
    long_stop_loss[pair] = []
    short_stop_loss[pair] = []
    long_entry_price[pair] = []
    short_entry_price[pair] = []
    
    for i in range(50, len(df[pair])):
        #Buy
        if df[pair]['sma_fast'][i-1] > df[pair]['sma_slow'][i-1] and any (df[pair]['Close'][i-3: i-1].values) <= any (df[pair]['lower_band'][i-3: i-1].values)\
            and df[pair]['Close'][i] >= df[pair]['rolling_mean'][i] and len(open_trade[pair]) == 0:
            print(i, 'New Long trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                             'date_of_trade': df[pair].index[i],
                             'entry_price': df[pair]['Close'][i],
                             'signal': 'Buy',
                             'result': 0, 
                             'TP': df[pair]['Close'][i] + df[pair]['ATR'][i] * 10 * ATR_SL,
                             'SL': df[pair]['Close'][i] - df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            long_take_profit[pair].append(trade[pair][i]['TP'])
            long_stop_loss[pair].append(trade[pair][i]['SL'])
            long_entry_price[pair].append(trade[pair][i]['entry_price'])
        
        #Sell
        if df[pair]['sma_fast'][i-1] < df[pair]['sma_slow'][i-1] and any (df[pair]['Close'][i-3: i-1].values) >= any (df[pair]['upper_band'][i-3: i-1].values)\
            and df[pair]['Close'][i] <= df[pair]['rolling_mean'][i] and len(open_trade[pair]) == 0:
            print(i, 'New Short trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                             'date_of_trade': df[pair].index[i],
                             'entry_price': df[pair]['Close'][i],
                             'signal': 'Sell',
                             'result': 0, 
                             'TP': df[pair]['Close'][i] - df[pair]['ATR'][i] * 10 * ATR_SL,
                             'SL': df[pair]['Close'][i] + df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            short_take_profit[pair].append(trade[pair][i]['TP'])
            short_stop_loss[pair].append(trade[pair][i]['SL'])
            short_entry_price[pair].append(trade[pair][i]['entry_price'])
            
        #Exit trades---------------------------------------------------------------------------
        #Buy Trailing SL
        if any(y <= df[pair]['Close'][i] for y in long_entry_price[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    #Move SL to BE
                    if df[pair]['Close'][i] >= trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * ATR_SL):
                        long_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] + df[pair]['spread'][i]})
                        print(j, 
                             'Moved SL to BE:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        long_entry_price[pair] = []
                        long_stop_loss[pair].append(trade[pair][j]['SL'])
                    #Move SL to first ATR
                    if df[pair]['Close'][i] >= trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * 2 * ATR_SL):
                        long_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] + (df[pair]['ATR'][i] * ATR_SL)})
                        print(j, 
                             'Trailing SL to first ATR:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        long_stop_loss[pair].append(trade[pair][j]['SL'])
        #Sell Trailing SL
        if any(y >= df[pair]['Close'][i] for y in short_entry_price[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    #Move SL to BE
                    if df[pair]['Close'][i] <= trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * ATR_SL):
                        short_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] - df[pair]['spread'][i]})
                        print(j, 
                             'Moved SL to BE:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        short_entry_price[pair] = []
                        short_stop_loss[pair].append(trade[pair][j]['SL'])
                    #Move SL to first ATR
                    if df[pair]['Close'][i] <= trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * 2 * ATR_SL):
                        short_stop_loss[pair] = []
                        trade[pair][j].update({'SL' : trade[pair][j]['entry_price'] - (df[pair]['ATR'][i] * ATR_SL)})
                        print(j, 
                             'Trailing SL to first ATR:', round(trade[pair][j]['SL'], 4),
                             'On day:', df[pair].index[i], '\n')
                        short_stop_loss[pair].append(trade[pair][j]['SL'])
                        
        #Buy profit
        if any(y <= df[pair]['Close'][i] for y in long_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] >= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['TP'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Buy loss
        if any(y >= df[pair]['Close'][i] for y in long_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] <= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['SL'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
                        
        #Sell profit
        if any(y >= df[pair]['Close'][i] for y in short_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] <= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['TP'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Sell loss
        if any(y <= df[pair]['Close'][i] for y in short_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] >= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['SL'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Exit after time
        if len(open_trade[pair]) != 0:
            for j in open_trade[pair]:
                if (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    trade[pair][j].update({'result' : (df[pair]['Close'][i] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Long exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    long_take_profit[pair].remove(trade[pair][j]['TP'])
                    long_stop_loss[pair].remove(trade[pair][j]['SL'])
                elif (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - df[pair]['Close'][i] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Short exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    short_take_profit[pair].remove(trade[pair][j]['TP'])
                    short_stop_loss[pair].remove(trade[pair][j]['SL'])
# Out:
# 200 New Long trade at price: 667.768  On day: 2007-02-14 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 200 Long loss at price: 664.392 On day: 2007-02-16 08:00:00 With loss: -191.94
#
# 213 New Long trade at price: 664.401  On day: 2007-02-16 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 213 Moved SL to BE: 664.421 On day: 2007-02-16 16:00:00
#
# 213 Trailing SL to first ATR: 666.4382 On day: 2007-02-16 16:00:00
#
# 213 Long loss at price: 664.83 On day: 2007-02-20 08:00:00 With loss: 201.725
#
# 233 New Long trade at price: 678.763  On day: 2007-02-21 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 233 Long loss at price: 674.574 On day: 2007-02-22 20:00:00 With loss: -236.2875
#
# 241 New Long trade at price: 674.35  On day: 2007-02-23 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 241 Moved SL to BE: 674.37 On day: 2007-02-23 08:00:00
#
# 241 Long exited after 12 hours: 686.035 On day: 2007-02-26 20:00:00 With profit: 1166.5
#
# 254 New Long trade at price: 684.73  On day: 2007-02-27 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 254 Long loss at price: 682.451 On day: 2007-02-27 04:00:00 With loss: -205.9275
#
# 256 New Long trade at price: 680.222  On day: 2007-02-27 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 256 Long loss at price: 676.842 On day: 2007-02-27 12:00:00 With loss: -219.5625
#
# 262 New Long trade at price: 674.298  On day: 2007-02-28 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 262 Long loss at price: 663.668 On day: 2007-02-28 12:00:00 With loss: -293.7825
#
# 301 New Short trade at price: 650.97  On day: 2007-03-08 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 301 Moved SL to BE: 650.95 On day: 2007-03-09 16:00:00
#
# 301 Short loss at price: 653.076 On day: 2007-03-12 04:00:00 With loss: -0.0
#
# 314 New Short trade at price: 649.548  On day: 2007-03-12 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 314 Moved SL to BE: 649.528 On day: 2007-03-13 08:00:00
#
# 314 Short exited after 12 hours: 643.62 On day: 2007-03-14 16:00:00 With profit: 590.8
#
# 327 New Short trade at price: 643.945  On day: 2007-03-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 327 Short loss at price: 647.68 On day: 2007-03-15 12:00:00 With loss: -218.475
#
# 332 New Short trade at price: 645.132  On day: 2007-03-15 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 332 Short loss at price: 647.882 On day: 2007-03-15 20:00:00 With loss: -233.7875
#
# 334 New Short trade at price: 645.595  On day: 2007-03-16 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 334 Short loss at price: 650.848 On day: 2007-03-16 08:00:00 With loss: -223.32
#
# 390 New Long trade at price: 665.398  On day: 2007-03-29 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 390 Long loss at price: 658.572 On day: 2007-03-29 12:00:00 With loss: -171.3675
#
# 394 New Long trade at price: 661.895  On day: 2007-03-29 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 394 Moved SL to BE: 661.915 On day: 2007-03-30 12:00:00
#
# 394 Long loss at price: 659.686 On day: 2007-04-02 12:00:00 With loss: -0.0
#
# 407 New Long trade at price: 663.671  On day: 2007-04-02 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 407 Moved SL to BE: 663.691 On day: 2007-04-03 12:00:00
#
# 407 Long loss at price: 663.148 On day: 2007-04-03 20:00:00 With loss: -0.0
#
# 415 New Long trade at price: 664.103  On day: 2007-04-04 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 415 Moved SL to BE: 664.123 On day: 2007-04-04 12:00:00
#
# 415 Trailing SL to first ATR: 665.9805 On day: 2007-04-04 12:00:00
#
# 415 Long exited after 12 hours: 673.432 On day: 2007-04-06 00:00:00 With profit: 930.9
#
# 428 New Long trade at price: 673.57  On day: 2007-04-06 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 428 Long loss at price: 670.44 On day: 2007-04-09 00:00:00 With loss: -154.4725
#
# 435 New Long trade at price: 672.053  On day: 2007-04-09 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 435 Moved SL to BE: 672.073 On day: 2007-04-09 08:00:00
#
# 435 Long exited after 12 hours: 676.833 On day: 2007-04-11 04:00:00 With profit: 476.0
#
# 448 New Long trade at price: 677.813  On day: 2007-04-11 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 448 Long loss at price: 673.872 On day: 2007-04-12 12:00:00 With loss: -135.045
#
# 456 New Long trade at price: 675.798  On day: 2007-04-12 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 456 Moved SL to BE: 675.818 On day: 2007-04-13 08:00:00
#
# 456 Long exited after 12 hours: 683.866 On day: 2007-04-16 12:00:00 With profit: 804.8
#
# 469 New Long trade at price: 690.545  On day: 2007-04-16 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 469 Long loss at price: 687.523 On day: 2007-04-17 00:00:00 With loss: -171.12
#
# 472 New Long trade at price: 687.22  On day: 2007-04-17 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 472 Moved SL to BE: 687.24 On day: 2007-04-18 04:00:00
#
# 472 Long loss at price: 683.85 On day: 2007-04-19 04:00:00 With loss: -0.0
#
# 485 New Long trade at price: 685.523  On day: 2007-04-19 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 485 Long loss at price: 682.447 On day: 2007-04-19 12:00:00 With loss: -183.6075
#
# 488 New Long trade at price: 683.857  On day: 2007-04-19 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 488 Moved SL to BE: 683.877 On day: 2007-04-20 08:00:00
#
# 488 Trailing SL to first ATR: 685.894 On day: 2007-04-20 08:00:00
#
# 488 Long exited after 12 hours: 688.448 On day: 2007-04-23 16:00:00 With profit: 457.1
#
# 501 New Long trade at price: 689.536  On day: 2007-04-23 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 501 Long loss at price: 686.076 On day: 2007-04-24 00:00:00 With loss: -186.785
#
# 503 New Long trade at price: 688.598  On day: 2007-04-24 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 503 Moved SL to BE: 688.618 On day: 2007-04-24 08:00:00
#
# 503 Long loss at price: 684.44 On day: 2007-04-24 12:00:00 With loss: -0.0
#
# 548 New Long trade at price: 680.071  On day: 2007-05-03 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 548 Moved SL to BE: 680.091 On day: 2007-05-03 20:00:00
#
# 548 Long exited after 12 hours: 690.228 On day: 2007-05-07 08:00:00 With profit: 1013.7
#
# 561 New Long trade at price: 688.456  On day: 2007-05-07 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 561 Long loss at price: 686.588 On day: 2007-05-08 04:00:00 With loss: -152.83
#
# 566 New Long trade at price: 684.623  On day: 2007-05-08 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 566 Long loss at price: 678.137 On day: 2007-05-09 12:00:00 With loss: -143.9875
#
# 600 New Short trade at price: 671.713  On day: 2007-05-15 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 600 Moved SL to BE: 671.693 On day: 2007-05-16 12:00:00
#
# 600 Trailing SL to first ATR: 670.1153 On day: 2007-05-16 12:00:00
#
# 600 Short exited after 12 hours: 657.41 On day: 2007-05-17 20:00:00 With profit: 1428.3
#
# 613 New Short trade at price: 657.785  On day: 2007-05-18 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 613 Short loss at price: 659.864 On day: 2007-05-18 04:00:00 With loss: -165.455
#
# 615 New Short trade at price: 658.466  On day: 2007-05-18 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 615 Short loss at price: 660.265 On day: 2007-05-18 12:00:00 With loss: -176.8225
#
# 617 New Short trade at price: 660.997  On day: 2007-05-18 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 617 Moved SL to BE: 660.977 On day: 2007-05-21 08:00:00
#
# 617 Short loss at price: 661.943 On day: 2007-05-21 12:00:00 With loss: -0.0
#
# 624 New Short trade at price: 662.41  On day: 2007-05-21 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 624 Short loss at price: 664.522 On day: 2007-05-22 04:00:00 With loss: -170.6275
#
# 628 New Short trade at price: 663.57  On day: 2007-05-22 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 628 Moved SL to BE: 663.55 On day: 2007-05-22 12:00:00
#
# 628 Short exited after 12 hours: 660.57 On day: 2007-05-24 08:00:00 With profit: 298.0
#
# 641 New Short trade at price: 653.697  On day: 2007-05-24 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 641 Short loss at price: 655.66 On day: 2007-05-25 20:00:00 With loss: -185.6
#
# 650 New Short trade at price: 655.372  On day: 2007-05-27 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 650 Moved SL to BE: 655.352 On day: 2007-05-29 04:00:00
#
# 650 Short loss at price: 657.923 On day: 2007-05-29 08:00:00 With loss: -0.0
#
# 660 New Short trade at price: 657.095  On day: 2007-05-29 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 660 Moved SL to BE: 657.075 On day: 2007-05-30 08:00:00
#
# 660 Trailing SL to first ATR: 655.8251 On day: 2007-05-30 08:00:00
# 660 Short loss at price: 655.848 On day: 2007-05-31 00:00:00 With loss: 124.99
#
# 670 New Short trade at price: 656.42  On day: 2007-05-31 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 670 Short loss at price: 658.895 On day: 2007-05-31 12:00:00 With loss: -136.735
#
# 704 New Short trade at price: 659.198  On day: 2007-06-07 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 704 Moved SL to BE: 659.178 On day: 2007-06-08 04:00:00
#
# 704 Short exited after 12 hours: 653.684 On day: 2007-06-11 12:00:00 With profit: 549.4
#
# 717 New Short trade at price: 652.968  On day: 2007-06-11 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 717 Moved SL to BE: 652.948 On day: 2007-06-12 08:00:00
#
# 717 Short exited after 12 hours: 651.172 On day: 2007-06-13 16:00:00 With profit: 177.6
#
# 730 New Short trade at price: 650.74  On day: 2007-06-13 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 730 Moved SL to BE: 650.72 On day: 2007-06-14 08:00:00
#
# 730 Short loss at price: 651.27 On day: 2007-06-14 16:00:00 With loss: -0.0
#
# 736 New Short trade at price: 652.378  On day: 2007-06-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 736 Moved SL to BE: 652.358 On day: 2007-06-15 08:00:00
#
# 736 Short loss at price: 653.045 On day: 2007-06-15 12:00:00 With loss: -0.0
#
# 741 New Short trade at price: 654.648  On day: 2007-06-15 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 741 Short loss at price: 657.808 On day: 2007-06-18 04:00:00 With loss: -188.7075
#
# 760 New Short trade at price: 652.67  On day: 2007-06-20 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 760 Short loss at price: 654.17 On day: 2007-06-20 20:00:00 With loss: -146.74
#
# 764 New Short trade at price: 652.748  On day: 2007-06-21 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 764 Moved SL to BE: 652.728 On day: 2007-06-21 12:00:00
#
# 764 Trailing SL to first ATR: 651.0543 On day: 2007-06-21 12:00:00
#
# 764 Short loss at price: 651.698 On day: 2007-06-21 16:00:00 With loss: 167.3675
#
# 767 New Short trade at price: 651.094  On day: 2007-06-21 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 767 Short loss at price: 653.723 On day: 2007-06-22 08:00:00 With loss: -173.2975
#
# 771 New Short trade at price: 653.02  On day: 2007-06-22 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 771 Moved SL to BE: 653.0 On day: 2007-06-25 16:00:00
#
# 771 Short exited after 12 hours: 648.823 On day: 2007-06-26 08:00:00 With profit: 417.7
#
# 784 New Short trade at price: 643.92  On day: 2007-06-26 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 784 Moved SL to BE: 643.9 On day: 2007-06-26 16:00:00
#
# 784 Short loss at price: 644.398 On day: 2007-06-27 12:00:00 With loss: -0.0
#
# 791 New Short trade at price: 643.222  On day: 2007-06-27 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 791 Short loss at price: 646.373 On day: 2007-06-28 08:00:00 With loss: -168.29
#
# 796 New Short trade at price: 648.62  On day: 2007-06-28 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 796 Moved SL to BE: 648.6 On day: 2007-06-29 00:00:00
#
# 796 Short loss at price: 649.248 On day: 2007-06-29 08:00:00 With loss: -0.0
#
# 803 New Short trade at price: 648.923  On day: 2007-06-29 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 803 Short loss at price: 651.3 On day: 2007-07-02 04:00:00 With loss: -182.15
#
# 827 New Short trade at price: 648.273  On day: 2007-07-05 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 827 Short loss at price: 649.97 On day: 2007-07-05 16:00:00 With loss: -137.51
#
# 829 New Short trade at price: 648.882  On day: 2007-07-05 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 829 Short loss at price: 650.27 On day: 2007-07-06 00:00:00 With loss: -126.0675
#
# 831 New Short trade at price: 647.57  On day: 2007-07-06 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 831 Short loss at price: 653.848 On day: 2007-07-06 12:00:00 With loss: -131.0375
#
# 854 New Long trade at price: 660.997  On day: 2007-07-11 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 854 Moved SL to BE: 661.017 On day: 2007-07-12 04:00:00
#
# 854 Long exited after 12 hours: 666.223 On day: 2007-07-13 20:00:00 With profit: 520.6
#
# 867 New Long trade at price: 666.72  On day: 2007-07-15 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 867 Long loss at price: 665.307 On day: 2007-07-16 12:00:00 With loss: -131.565
#
# 872 New Long trade at price: 664.811  On day: 2007-07-16 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 872 Long loss at price: 662.948 On day: 2007-07-17 08:00:00 With loss: -128.5225
#
# 877 New Long trade at price: 665.297  On day: 2007-07-17 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 877 Moved SL to BE: 665.317 On day: 2007-07-18 04:00:00
#
# 877 Long exited after 12 hours: 674.572 On day: 2007-07-19 12:00:00 With profit: 925.5
#
# 890 New Long trade at price: 676.495  On day: 2007-07-19 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 890 Moved SL to BE: 676.515 On day: 2007-07-20 12:00:00
#
# 890 Trailing SL to first ATR: 678.0742 On day: 2007-07-20 12:00:00
#
# 890 Long exited after 12 hours: 681.562 On day: 2007-07-23 12:00:00 With profit: 504.7
#
# 903 New Long trade at price: 681.37  On day: 2007-07-23 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 903 Long loss at price: 679.795 On day: 2007-07-25 00:00:00 With loss: -138.11
#
# 912 New Long trade at price: 677.897  On day: 2007-07-25 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 912 Long loss at price: 673.048 On day: 2007-07-25 12:00:00 With loss: -144.72
#
# 915 New Long trade at price: 674.722  On day: 2007-07-25 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 915 Long loss at price: 670.52 On day: 2007-07-26 08:00:00 With loss: -152.36
#
# 957 New Long trade at price: 670.098  On day: 2007-08-03 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 957 Moved SL to BE: 670.118 On day: 2007-08-03 16:00:00
#
# 957 Trailing SL to first ATR: 671.8463 On day: 2007-08-03 16:00:00
#
# 957 Long loss at price: 669.429 On day: 2007-08-06 12:00:00 With loss: 172.8325
#
# 965 New Long trade at price: 671.327  On day: 2007-08-06 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 965 Long loss at price: 669.62 On day: 2007-08-07 04:00:00 With loss: -153.4775
#
# 969 New Long trade at price: 668.57  On day: 2007-08-07 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 969 Moved SL to BE: 668.59 On day: 2007-08-07 16:00:00
#
# 969 Trailing SL to first ATR: 670.0575 On day: 2007-08-07 16:00:00
#
# 969 Long loss at price: 669.797 On day: 2007-08-08 04:00:00 With loss: 146.75
#
# 975 New Long trade at price: 672.723  On day: 2007-08-08 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 975 Moved SL to BE: 672.743 On day: 2007-08-08 12:00:00
#
# 975 Long loss at price: 672.598 On day: 2007-08-09 00:00:00 With loss: -0.0
#
# 980 New Long trade at price: 672.67  On day: 2007-08-09 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 980 Long loss at price: 667.02 On day: 2007-08-09 08:00:00 With loss: -135.195
#
# 988 New Long trade at price: 674.17  On day: 2007-08-10 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 988 Long loss at price: 670.401 On day: 2007-08-12 20:00:00 With loss: -217.195
#
# 992 New Long trade at price: 670.095  On day: 2007-08-13 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 992 Long loss at price: 667.522 On day: 2007-08-14 04:00:00 With loss: -209.5775
#
# 1001 New Long trade at price: 669.37  On day: 2007-08-14 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1001 Long loss at price: 666.947 On day: 2007-08-15 00:00:00 With loss: -199.265
#
# 1007 New Long trade at price: 669.573  On day: 2007-08-15 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1007 Long loss at price: 667.47 On day: 2007-08-15 20:00:00 With loss: -186.9925
#
# 1019 New Short trade at price: 657.198  On day: 2007-08-17 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1019 Moved SL to BE: 657.178 On day: 2007-08-19 20:00:00
#
# 1019 Short loss at price: 657.79 On day: 2007-08-20 04:00:00 With loss: -0.0
#
# 1025 New Short trade at price: 657.017  On day: 2007-08-20 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1025 Moved SL to BE: 656.997 On day: 2007-08-22 00:00:00
#
# 1025 Short loss at price: 658.143 On day: 2007-08-22 08:00:00 With loss: -0.0
#
# 1038 New Short trade at price: 659.272  On day: 2007-08-22 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1038 Short loss at price: 661.551 On day: 2007-08-23 00:00:00 With loss: -192.185
#
# 1044 New Short trade at price: 659.094  On day: 2007-08-23 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1044 Short loss at price: 661.035 On day: 2007-08-24 08:00:00 With loss: -171.735
#
# 1095 New Long trade at price: 681.65  On day: 2007-09-04 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1095 Long loss at price: 679.119 On day: 2007-09-05 04:00:00 With loss: -131.6625
#
# 1099 New Long trade at price: 678.654  On day: 2007-09-05 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1099 Moved SL to BE: 678.674 On day: 2007-09-05 12:00:00
#
# 1099 Trailing SL to first ATR: 679.9047 On day: 2007-09-05 12:00:00
#
# 1099 Long profit at price: 695.914 On day: 2007-09-06 12:00:00 With profit: 1278.2
#
# 1107 New Long trade at price: 695.416  On day: 2007-09-06 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1107 Long loss at price: 692.791 On day: 2007-09-07 00:00:00 With loss: -164.94
#
# 1110 New Long trade at price: 692.775  On day: 2007-09-07 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1110 Moved SL to BE: 692.795 On day: 2007-09-07 08:00:00
#
# 1110 Trailing SL to first ATR: 694.609 On day: 2007-09-07 08:00:00
#
# 1110 Long exited after 12 hours: 703.09 On day: 2007-09-11 00:00:00 With profit: 1029.5
#
# 1123 New Long trade at price: 702.743  On day: 2007-09-11 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1123 Moved SL to BE: 702.763 On day: 2007-09-11 12:00:00
#
# 1123 Trailing SL to first ATR: 705.0016 On day: 2007-09-11 12:00:00
#
# 1123 Long exited after 12 hours: 707.876 On day: 2007-09-13 04:00:00 With profit: 511.3
#
# 1136 New Long trade at price: 706.294  On day: 2007-09-13 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1136 Moved SL to BE: 706.314 On day: 2007-09-13 12:00:00
#
# 1136 Long loss at price: 706.035 On day: 2007-09-13 20:00:00 With loss: -0.0
#
# 1140 New Long trade at price: 705.833  On day: 2007-09-14 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1140 Moved SL to BE: 705.853 On day: 2007-09-14 12:00:00
#
# 1140 Trailing SL to first ATR: 707.9354 On day: 2007-09-14 12:00:00
#
# 1140 Long loss at price: 707.29 On day: 2007-09-14 16:00:00 With loss: 208.245
#
# 1145 New Long trade at price: 707.106  On day: 2007-09-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1145 Moved SL to BE: 707.126 On day: 2007-09-17 00:00:00
#
# 1145 Long exited after 12 hours: 723.691 On day: 2007-09-18 16:00:00 With profit: 1656.5
#
# 1158 New Long trade at price: 723.386  On day: 2007-09-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1158 Moved SL to BE: 723.406 On day: 2007-09-20 04:00:00
#
# 1158 Long exited after 12 hours: 733.583 On day: 2007-09-20 20:00:00 With profit: 1017.7
#
# 1171 New Long trade at price: 735.252  On day: 2007-09-21 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1171 Long loss at price: 728.042 On day: 2007-09-21 12:00:00 With loss: -227.6375
#
# 1175 New Long trade at price: 730.472  On day: 2007-09-21 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1175 Moved SL to BE: 730.492 On day: 2007-09-24 00:00:00
#
# 1175 Long loss at price: 730.15 On day: 2007-09-24 12:00:00 With loss: -0.0
#
# 1182 New Long trade at price: 729.687  On day: 2007-09-24 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1182 Long loss at price: 723.842 On day: 2007-09-25 04:00:00 With loss: -212.5025
#
# 1186 New Long trade at price: 723.731  On day: 2007-09-25 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1186 Moved SL to BE: 723.751 On day: 2007-09-25 12:00:00
#
# 1186 Trailing SL to first ATR: 726.0912 On day: 2007-09-25 12:00:00
#
# 1186 Long exited after 12 hours: 733.078 On day: 2007-09-27 08:00:00 With profit: 932.7
#
# 1199 New Long trade at price: 729.735  On day: 2007-09-27 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1199 Moved SL to BE: 729.755 On day: 2007-09-27 16:00:00
#
# 1199 Long exited after 12 hours: 742.989 On day: 2007-10-01 08:00:00 With profit: 1323.4
#
# 1212 New Long trade at price: 745.44  On day: 2007-10-01 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1212 Long loss at price: 741.92 On day: 2007-10-02 00:00:00 With loss: -218.7075
#
# 1231 New Long trade at price: 737.495  On day: 2007-10-04 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1231 Long loss at price: 734.248 On day: 2007-10-05 04:00:00 With loss: -291.565
#
# 1235 New Long trade at price: 736.048  On day: 2007-10-05 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1235 Moved SL to BE: 736.068 On day: 2007-10-05 12:00:00
#
# 1235 Long loss at price: 734.8 On day: 2007-10-08 08:00:00 With loss: -0.0
#
# 1249 New Long trade at price: 736.895  On day: 2007-10-09 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1249 Moved SL to BE: 736.915 On day: 2007-10-10 00:00:00
#
# 1249 Long exited after 12 hours: 750.521 On day: 2007-10-11 12:00:00 With profit: 1360.6
#
# 1262 New Long trade at price: 746.893  On day: 2007-10-11 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1262 Moved SL to BE: 746.913 On day: 2007-10-12 16:00:00
#
# 1262 Long exited after 12 hours: 756.204 On day: 2007-10-15 12:00:00 With profit: 929.1
#
# 1275 New Long trade at price: 759.254  On day: 2007-10-15 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1275 Moved SL to BE: 759.274 On day: 2007-10-16 04:00:00
#
# 1275 Long loss at price: 758.102 On day: 2007-10-16 08:00:00 With loss: -0.0
#
# 1280 New Long trade at price: 758.694  On day: 2007-10-16 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1280 Moved SL to BE: 758.714 On day: 2007-10-17 00:00:00
#
# 1280 Long loss at price: 757.733 On day: 2007-10-17 04:00:00 With loss: -0.0
#
# 1285 New Long trade at price: 759.738  On day: 2007-10-17 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1285 Long loss at price: 753.924 On day: 2007-10-17 16:00:00 With loss: -229.32
#
# 1288 New Long trade at price: 755.666  On day: 2007-10-17 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1288 Moved SL to BE: 755.686 On day: 2007-10-18 00:00:00
#
# 1288 Long exited after 12 hours: 764.548 On day: 2007-10-19 20:00:00 With profit: 886.2
#
# 1301 New Long trade at price: 767.345  On day: 2007-10-21 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1301 Long loss at price: 759.864 On day: 2007-10-22 00:00:00 With loss: -250.475
#
# 1303 New Long trade at price: 758.028  On day: 2007-10-22 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1303 Long loss at price: 747.708 On day: 2007-10-22 08:00:00 With loss: -275.395
#
# 1308 New Long trade at price: 757.12  On day: 2007-10-23 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1308 Moved SL to BE: 757.14 On day: 2007-10-24 16:00:00
#
# 1308 Trailing SL to first ATR: 759.5564 On day: 2007-10-24 16:00:00
#
# 1308 Long exited after 12 hours: 762.737 On day: 2007-10-25 00:00:00 With profit: 559.7
#
# 1321 New Long trade at price: 762.335  On day: 2007-10-25 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1321 Moved SL to BE: 762.355 On day: 2007-10-25 08:00:00
#
# 1321 Trailing SL to first ATR: 764.5078 On day: 2007-10-25 08:00:00
#
# 1321 Long profit at price: 788.977 On day: 2007-10-28 20:00:00 With profit: 2378.225
#
# 1333 New Long trade at price: 792.441  On day: 2007-10-29 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1333 Long loss at price: 788.993 On day: 2007-10-29 12:00:00 With loss: -203.4225
#
# 1337 New Long trade at price: 790.123  On day: 2007-10-29 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1337 Long loss at price: 785.599 On day: 2007-10-30 00:00:00 With loss: -220.7275
#
# 1340 New Long trade at price: 784.65  On day: 2007-10-30 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1340 Long loss at price: 777.569 On day: 2007-10-30 20:00:00 With loss: -226.22
#
# 1345 New Long trade at price: 781.363  On day: 2007-10-31 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1345 Moved SL to BE: 781.383 On day: 2007-10-31 08:00:00
#
# 1345 Long exited after 12 hours: 790.085 On day: 2007-11-02 00:00:00 With profit: 870.2
#
# 1358 New Long trade at price: 788.552  On day: 2007-11-02 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1358 Moved SL to BE: 788.572 On day: 2007-11-02 08:00:00
#
# 1358 Trailing SL to first ATR: 791.0522 On day: 2007-11-02 08:00:00
#
# 1358 Long exited after 12 hours: 808.142 On day: 2007-11-06 00:00:00 With profit: 1957.0
#
# 1371 New Long trade at price: 814.457  On day: 2007-11-06 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1371 Moved SL to BE: 814.477 On day: 2007-11-06 08:00:00
#
# 1371 Trailing SL to first ATR: 816.9586 On day: 2007-11-06 08:00:00
#
# 1371 Long profit at price: 838.496 On day: 2007-11-07 08:00:00 With profit: 2380.975
#
# 1379 New Long trade at price: 835.26  On day: 2007-11-07 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1379 Long loss at price: 824.689 On day: 2007-11-07 20:00:00 With loss: -316.59
#
# 1382 New Long trade at price: 834.204  On day: 2007-11-08 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1382 Moved SL to BE: 834.224 On day: 2007-11-08 12:00:00
#
# 1382 Long loss at price: 827.962 On day: 2007-11-08 16:00:00 With loss: -0.0
#
# 1387 New Long trade at price: 834.97  On day: 2007-11-08 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1387 Long loss at price: 829.438 On day: 2007-11-09 08:00:00 With loss: -435.905
#
# 1391 New Long trade at price: 831.38  On day: 2007-11-09 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1391 Long loss at price: 818.101 On day: 2007-11-12 00:00:00 With loss: -450.56
#
# 1396 New Long trade at price: 818.962  On day: 2007-11-12 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1396 Long loss at price: 805.539 On day: 2007-11-12 12:00:00 With loss: -437.4475
#
# 1438 New Long trade at price: 803.775  On day: 2007-11-21 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1438 Long loss at price: 796.275 On day: 2007-11-21 08:00:00 With loss: -347.5825
#
# 1442 New Long trade at price: 801.388  On day: 2007-11-21 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1442 Moved SL to BE: 801.408 On day: 2007-11-23 00:00:00
#
# 1442 Trailing SL to first ATR: 804.5484 On day: 2007-11-23 00:00:00
#
# 1442 Long exited after 12 hours: 822.086 On day: 2007-11-23 16:00:00 With profit: 2067.8
#
# 1455 New Long trade at price: 823.223  On day: 2007-11-23 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1455 Moved SL to BE: 823.243 On day: 2007-11-26 00:00:00
#
# 1455 Long loss at price: 821.052 On day: 2007-11-26 12:00:00 With loss: -0.0
#
# 1461 New Long trade at price: 822.74  On day: 2007-11-26 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1461 Moved SL to BE: 822.76 On day: 2007-11-27 00:00:00
#
# 1461 Long loss at price: 821.225 On day: 2007-11-27 08:00:00 With loss: -0.0
#
# 1466 New Long trade at price: 814.048  On day: 2007-11-27 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1466 Long loss at price: 809.326 On day: 2007-11-27 16:00:00 With loss: -341.525
#
# 1468 New Long trade at price: 814.876  On day: 2007-11-27 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1468 Long loss at price: 806.44 On day: 2007-11-28 00:00:00 With loss: -359.6275
#
# 1473 New Long trade at price: 806.648  On day: 2007-11-28 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1473 Long loss at price: 797.704 On day: 2007-11-29 12:00:00 With loss: -392.73
#
# 1509 New Long trade at price: 800.845  On day: 2007-12-06 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1509 Long loss at price: 795.407 On day: 2007-12-07 12:00:00 With loss: -328.9925
#
# 1516 New Short trade at price: 795.251  On day: 2007-12-07 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1516 Short loss at price: 799.26 On day: 2007-12-10 08:00:00 With loss: -323.63
#
# 1540 New Short trade at price: 795.005  On day: 2007-12-13 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1540 Short loss at price: 798.709 On day: 2007-12-13 20:00:00 With loss: -298.36
#
# 1544 New Short trade at price: 799.001  On day: 2007-12-14 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1544 Moved SL to BE: 798.981 On day: 2007-12-14 08:00:00
#
# 1544 Trailing SL to first ATR: 795.9409 On day: 2007-12-14 08:00:00
#
# 1544 Short loss at price: 797.367 On day: 2007-12-17 00:00:00 With loss: 304.005
#
# 1551 New Short trade at price: 791.847  On day: 2007-12-17 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1551 Short loss at price: 795.653 On day: 2007-12-17 20:00:00 With loss: -276.78
#
# 1556 New Short trade at price: 792.307  On day: 2007-12-18 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1556 Short loss at price: 797.531 On day: 2007-12-18 08:00:00 With loss: -298.7775
#
# 1561 New Short trade at price: 800.139  On day: 2007-12-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1561 Short loss at price: 803.272 On day: 2007-12-19 12:00:00 With loss: -284.1425
#
# 1569 New Short trade at price: 800.826  On day: 2007-12-20 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1569 Moved SL to BE: 800.806 On day: 2007-12-20 08:00:00
#
# 1569 Short loss at price: 800.938 On day: 2007-12-21 04:00:00 With loss: -0.0
#
# 1595 New Long trade at price: 813.236  On day: 2007-12-26 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1595 Moved SL to BE: 813.256 On day: 2007-12-26 12:00:00
#
# 1595 Trailing SL to first ATR: 814.8076 On day: 2007-12-26 12:00:00
#
# 1595 Long profit at price: 827.666 On day: 2007-12-28 00:00:00 With profit: 1407.4
#
# 1606 New Long trade at price: 827.609  On day: 2007-12-28 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1606 Moved SL to BE: 827.629 On day: 2007-12-28 08:00:00
#
# 1606 Trailing SL to first ATR: 829.4648 On day: 2007-12-28 08:00:00
#
# 1606 Long exited after 12 hours: 833.041 On day: 2008-01-01 00:00:00 With profit: 541.2
#
# 1619 New Long trade at price: 833.137  On day: 2008-01-01 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1619 Moved SL to BE: 833.157 On day: 2008-01-02 00:00:00
#
# 1619 Long profit at price: 856.298 On day: 2008-01-02 16:00:00 With profit: 2120.675
#
# 1629 New Long trade at price: 856.723  On day: 2008-01-02 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1629 Long loss at price: 854.285 On day: 2008-01-03 00:00:00 With loss: -186.995
#
# 1631 New Long trade at price: 856.631  On day: 2008-01-03 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1631 Moved SL to BE: 856.651 On day: 2008-01-03 08:00:00
#
# 1631 Trailing SL to first ATR: 858.7295 On day: 2008-01-03 08:00:00
#
# 1631 Long loss at price: 857.102 On day: 2008-01-07 00:00:00 With loss: 207.8475
#
# 1644 New Long trade at price: 855.736  On day: 2008-01-07 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1644 Moved SL to BE: 855.756 On day: 2008-01-07 08:00:00
#
# 1644 Long exited after 12 hours: 884.475 On day: 2008-01-09 04:00:00 With profit: 2871.9
#
# 1657 New Long trade at price: 884.781  On day: 2008-01-09 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1657 Long loss at price: 879.746 On day: 2008-01-09 12:00:00 With loss: -324.18
#
# 1659 New Long trade at price: 875.338  On day: 2008-01-09 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1659 Moved SL to BE: 875.358 On day: 2008-01-09 20:00:00
#
# 1659 Long loss at price: 872.976 On day: 2008-01-10 04:00:00 With loss: -0.0
#
# 1663 New Long trade at price: 876.468  On day: 2008-01-10 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1663 Moved SL to BE: 876.488 On day: 2008-01-10 12:00:00
#
# 1663 Long exited after 12 hours: 906.164 On day: 2008-01-14 04:00:00 With profit: 2967.6
#
# 1676 New Long trade at price: 910.948  On day: 2008-01-14 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1676 Long loss at price: 904.859 On day: 2008-01-14 16:00:00 With loss: -397.495
#
# 1679 New Long trade at price: 904.784  On day: 2008-01-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1679 Moved SL to BE: 904.804 On day: 2008-01-15 12:00:00
#
# 1679 Long loss at price: 895.486 On day: 2008-01-15 16:00:00 With loss: -0.0
#
# 1685 New Long trade at price: 891.999  On day: 2008-01-15 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1685 Moved SL to BE: 892.019 On day: 2008-01-16 00:00:00
#
# 1685 Long loss at price: 884.457 On day: 2008-01-16 04:00:00 With loss: -0.0
#
# 1688 New Long trade at price: 883.665  On day: 2008-01-16 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1688 Long loss at price: 875.852 On day: 2008-01-16 12:00:00 With loss: -413.9275
#
# 1690 New Long trade at price: 884.475  On day: 2008-01-16 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1690 Long loss at price: 876.466 On day: 2008-01-16 20:00:00 With loss: -459.515
#
# 1695 New Long trade at price: 887.118  On day: 2008-01-17 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1695 Long loss at price: 877.511 On day: 2008-01-17 16:00:00 With loss: -480.5325
#
# 1714 New Long trade at price: 888.557  On day: 2008-01-22 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1714 Long loss at price: 883.054 On day: 2008-01-23 16:00:00 With loss: -450.23
#
# 1722 New Long trade at price: 892.198  On day: 2008-01-23 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1722 Moved SL to BE: 892.218 On day: 2008-01-24 08:00:00
#
# 1722 Long exited after 12 hours: 913.247 On day: 2008-01-25 20:00:00 With profit: 2102.9
#
# 1735 New Long trade at price: 915.116  On day: 2008-01-27 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1735 Moved SL to BE: 915.136 On day: 2008-01-28 00:00:00
#
# 1735 Long exited after 12 hours: 923.605 On day: 2008-01-29 20:00:00 With profit: 846.9
#
# 1748 New Long trade at price: 922.728  On day: 2008-01-30 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1748 Moved SL to BE: 922.748 On day: 2008-01-30 16:00:00
#
# 1748 Trailing SL to first ATR: 926.078 On day: 2008-01-30 16:00:00
#
# 1748 Long loss at price: 925.765 On day: 2008-01-30 20:00:00 With loss: 332.9975
#
# 1754 New Long trade at price: 923.639  On day: 2008-01-31 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1754 Long loss at price: 920.127 On day: 2008-01-31 12:00:00 With loss: -351.1175
#
# 1758 New Long trade at price: 926.079  On day: 2008-01-31 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1758 Moved SL to BE: 926.099 On day: 2008-02-01 08:00:00
#
# 1758 Trailing SL to first ATR: 929.6697 On day: 2008-02-01 08:00:00
#
# 1758 Long loss at price: 906.315 On day: 2008-02-01 12:00:00 With loss: 357.0725
#
# 1793 New Long trade at price: 912.655  On day: 2008-02-08 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1793 Moved SL to BE: 912.675 On day: 2008-02-08 12:00:00
#
# 1793 Long exited after 12 hours: 923.403 On day: 2008-02-12 04:00:00 With profit: 1072.8
#
# 1806 New Long trade at price: 920.231  On day: 2008-02-12 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1806 Long loss at price: 917.052 On day: 2008-02-12 12:00:00 With loss: -307.5475
#
# 1817 New Long trade at price: 912.141  On day: 2008-02-14 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1817 Long loss at price: 908.715 On day: 2008-02-14 16:00:00 With loss: -337.63
#
# 1821 New Long trade at price: 908.279  On day: 2008-02-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1821 Long loss at price: 902.605 On day: 2008-02-15 16:00:00 With loss: -339.215
#
# 1836 New Long trade at price: 911.528  On day: 2008-02-19 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1836 Moved SL to BE: 911.548 On day: 2008-02-19 08:00:00
#
# 1836 Long profit at price: 939.802 On day: 2008-02-20 16:00:00 With profit: 2393.875
#
# 1846 New Long trade at price: 941.368  On day: 2008-02-20 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1846 Moved SL to BE: 941.388 On day: 2008-02-21 12:00:00
#
# 1846 Long loss at price: 940.051 On day: 2008-02-22 12:00:00 With loss: -0.0
#
# 1857 New Long trade at price: 943.494  On day: 2008-02-22 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1857 Moved SL to BE: 943.514 On day: 2008-02-25 00:00:00
#
# 1857 Long loss at price: 935.631 On day: 2008-02-25 12:00:00 With loss: -0.0
#
# 1864 New Long trade at price: 939.066  On day: 2008-02-25 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1864 Long loss at price: 930.549 On day: 2008-02-26 00:00:00 With loss: -355.9625
#
# 1867 New Long trade at price: 928.564  On day: 2008-02-26 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1867 Moved SL to BE: 928.584 On day: 2008-02-26 08:00:00
#
# 1867 Long exited after 12 hours: 953.003 On day: 2008-02-28 04:00:00 With profit: 2441.9
#
# 1880 New Long trade at price: 958.996  On day: 2008-02-28 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1880 Moved SL to BE: 959.016 On day: 2008-02-28 12:00:00
#
# 1880 Long exited after 12 hours: 982.176 On day: 2008-03-03 04:00:00 With profit: 2316.0
#
# 1893 New Long trade at price: 981.513  On day: 2008-03-03 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1893 Moved SL to BE: 981.533 On day: 2008-03-03 20:00:00
#
# 1893 Long loss at price: 981.449 On day: 2008-03-04 00:00:00 With loss: -0.0
#
# 1898 New Long trade at price: 981.102  On day: 2008-03-04 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1898 Moved SL to BE: 981.122 On day: 2008-03-04 08:00:00
#
# 1898 Long loss at price: 960.032 On day: 2008-03-04 16:00:00 With loss: -0.0
#
# 1902 New Long trade at price: 966.406  On day: 2008-03-04 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1902 Long loss at price: 962.141 On day: 2008-03-05 08:00:00 With loss: -331.115
#
# 1906 New Long trade at price: 982.69  On day: 2008-03-05 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1906 Moved SL to BE: 982.71 On day: 2008-03-05 16:00:00
#
# 1906 Long loss at price: 977.425 On day: 2008-03-06 16:00:00 With loss: -0.0
#
# 1914 New Long trade at price: 977.281  On day: 2008-03-06 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1914 Moved SL to BE: 977.301 On day: 2008-03-07 00:00:00
#
# 1914 Long loss at price: 976.023 On day: 2008-03-07 12:00:00 With loss: -0.0
#
# 1921 New Long trade at price: 974.384  On day: 2008-03-09 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1921 Long loss at price: 967.91 On day: 2008-03-10 08:00:00 With loss: -406.6525
#
# 1930 New Long trade at price: 982.603  On day: 2008-03-11 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1930 Long loss at price: 974.823 On day: 2008-03-11 12:00:00 With loss: -407.9625
#
# 1937 New Long trade at price: 978.317  On day: 2008-03-12 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1937 Moved SL to BE: 978.337 On day: 2008-03-12 20:00:00
#
# 1937 Long exited after 12 hours: 998.56 On day: 2008-03-14 12:00:00 With profit: 2022.3
#
# 1950 New Long trade at price: 999.33  On day: 2008-03-14 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1950 Moved SL to BE: 999.35 On day: 2008-03-14 20:00:00
#
# 1950 Long loss at price: 998.469 On day: 2008-03-18 04:00:00 With loss: -0.0
#
# 1961 New Long trade at price: 1009.095  On day: 2008-03-18 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1961 Long loss at price: 1003.871 On day: 2008-03-18 12:00:00 With loss: -461.5475
#
# 1965 New Long trade at price: 989.002  On day: 2008-03-19 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1965 Long loss at price: 943.892 On day: 2008-03-19 12:00:00 With loss: -532.0325
#
# 2001 New Long trade at price: 951.751  On day: 2008-03-26 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2001 Long loss at price: 943.567 On day: 2008-03-27 12:00:00 With loss: -418.2125
#
# 2011 New Short trade at price: 927.427  On day: 2008-03-28 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2011 Short loss at price: 933.022 On day: 2008-03-31 00:00:00 With loss: -376.5825
#
# 2018 New Short trade at price: 923.486  On day: 2008-03-31 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2018 Moved SL to BE: 923.466 On day: 2008-03-31 16:00:00
#
# 2018 Short profit at price: 882.869 On day: 2008-04-01 12:00:00 With profit: 3756.475
#
# 2025 New Short trade at price: 879.847  On day: 2008-04-01 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2025 Short loss at price: 885.807 On day: 2008-04-01 20:00:00 With loss: -511.335
#
# 2027 New Short trade at price: 883.531  On day: 2008-04-02 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2027 Short loss at price: 890.255 On day: 2008-04-02 08:00:00 With loss: -513.0175
#
# 2030 New Short trade at price: 888.162  On day: 2008-04-02 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2030 Short loss at price: 903.531 On day: 2008-04-02 16:00:00 With loss: -533.0775
#
# 2032 New Short trade at price: 902.979  On day: 2008-04-02 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2032 Moved SL to BE: 902.959 On day: 2008-04-03 08:00:00
#
# 2032 Short loss at price: 906.821 On day: 2008-04-03 12:00:00 With loss: -0.0
#
# 2037 New Short trade at price: 904.866  On day: 2008-04-03 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2037 Short loss at price: 913.262 On day: 2008-04-04 16:00:00 With loss: -548.12
#
# 2044 New Short trade at price: 913.08  On day: 2008-04-04 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2044 Short loss at price: 927.803 On day: 2008-04-07 12:00:00 With loss: -371.3275
#
# 2055 New Short trade at price: 913.257  On day: 2008-04-08 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2055 Moved SL to BE: 913.237 On day: 2008-04-09 04:00:00
#
# 2055 Trailing SL to first ATR: 910.0942 On day: 2008-04-09 04:00:00
#
# 2055 Short loss at price: 926.135 On day: 2008-04-09 12:00:00 With loss: 314.28
#
# 2103 New Short trade at price: 923.523  On day: 2008-04-18 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2103 Moved SL to BE: 923.503 On day: 2008-04-18 12:00:00
#
# 2103 Trailing SL to first ATR: 919.8223 On day: 2008-04-18 12:00:00
#
# 2103 Short loss at price: 921.839 On day: 2008-04-21 00:00:00 With loss: 368.0725
#
# 2109 New Short trade at price: 921.918  On day: 2008-04-21 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2109 Moved SL to BE: 921.898 On day: 2008-04-21 12:00:00
#
# 2109 Trailing SL to first ATR: 918.0642 On day: 2008-04-21 12:00:00
#
# 2109 Short loss at price: 918.997 On day: 2008-04-22 08:00:00 With loss: 383.375
#
# 2117 New Short trade at price: 921.607  On day: 2008-04-22 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2117 Moved SL to BE: 921.587 On day: 2008-04-22 16:00:00
#
# 2117 Trailing SL to first ATR: 917.8606 On day: 2008-04-22 16:00:00
#
# 2117 Short loss at price: 919.976 On day: 2008-04-23 00:00:00 With loss: 372.645
#
# 2121 New Short trade at price: 920.433  On day: 2008-04-23 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2121 Moved SL to BE: 920.413 On day: 2008-04-23 08:00:00
#
# 2121 Trailing SL to first ATR: 916.4836 On day: 2008-04-23 08:00:00
#
# 2121 Short profit at price: 878.835 On day: 2008-04-25 04:00:00 With profit: 3714.55
#
# 2134 New Short trade at price: 886.498  On day: 2008-04-25 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2134 Short loss at price: 892.144 On day: 2008-04-28 00:00:00 With loss: -383.01
#
# 2140 New Short trade at price: 890.748  On day: 2008-04-28 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2140 Moved SL to BE: 890.728 On day: 2008-04-29 08:00:00
#
# 2140 Trailing SL to first ATR: 887.3354 On day: 2008-04-29 08:00:00
#
# 2140 Short exited after 12 hours: 870.623 On day: 2008-04-30 04:00:00 With profit: 2010.5
#
# 2153 New Short trade at price: 868.158  On day: 2008-04-30 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2153 Short loss at price: 876.491 On day: 2008-04-30 16:00:00 With loss: -306.13
#
# 2156 New Short trade at price: 874.447  On day: 2008-04-30 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2156 Moved SL to BE: 874.427 On day: 2008-05-01 08:00:00
#
# 2156 Trailing SL to first ATR: 871.075 On day: 2008-05-01 08:00:00
#
# 2156 Short exited after 12 hours: 855.216 On day: 2008-05-02 20:00:00 With profit: 1921.1
#
# 2169 New Short trade at price: 860.573  On day: 2008-05-04 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2169 Short loss at price: 866.879 On day: 2008-05-05 08:00:00 With loss: -355.505
#
# 2173 New Short trade at price: 870.307  On day: 2008-05-05 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2173 Short loss at price: 874.43 On day: 2008-05-06 00:00:00 With loss: -346.3025
#
# 2184 New Short trade at price: 869.958  On day: 2008-05-07 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2184 Moved SL to BE: 869.938 On day: 2008-05-07 12:00:00
#
# 2184 Short loss at price: 871.114 On day: 2008-05-08 08:00:00 With loss: -0.0
#
# 2210 New Short trade at price: 870.06  On day: 2008-05-13 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2210 Moved SL to BE: 870.04 On day: 2008-05-13 16:00:00
#
# 2210 Short loss at price: 883.494 On day: 2008-05-15 12:00:00 With loss: -0.0
#
# 2259 New Long trade at price: 923.24  On day: 2008-05-23 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2259 Moved SL to BE: 923.26 On day: 2008-05-26 00:00:00
#
# 2259 Long loss at price: 923.211 On day: 2008-05-27 04:00:00 With loss: -0.0
#
# 2271 New Long trade at price: 923.304  On day: 2008-05-27 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2271 Long loss at price: 908.87 On day: 2008-05-27 12:00:00 With loss: -220.345
#
# 2320 New Short trade at price: 883.575  On day: 2008-06-06 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2320 Short loss at price: 896.277 On day: 2008-06-06 12:00:00 With loss: -306.205
#
# 2332 New Short trade at price: 883.458  On day: 2008-06-10 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2332 Short loss at price: 887.28 On day: 2008-06-10 08:00:00 With loss: -357.62
#
# 2334 New Short trade at price: 867.296  On day: 2008-06-10 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2334 Short loss at price: 871.465 On day: 2008-06-11 00:00:00 With loss: -401.4625
#
# 2338 New Short trade at price: 871.328  On day: 2008-06-11 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2338 Short loss at price: 881.044 On day: 2008-06-11 12:00:00 With loss: -389.1425
#
# 2341 New Short trade at price: 881.428  On day: 2008-06-11 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2341 Moved SL to BE: 881.408 On day: 2008-06-12 00:00:00
#
# 2341 Trailing SL to first ATR: 877.8442 On day: 2008-06-12 00:00:00
#
# 2341 Short exited after 12 hours: 868.81 On day: 2008-06-13 16:00:00 With profit: 1259.8
#
# 2354 New Short trade at price: 870.946  On day: 2008-06-13 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2354 Moved SL to BE: 870.926 On day: 2008-06-16 04:00:00
#
# 2354 Short loss at price: 876.095 On day: 2008-06-16 08:00:00 With loss: -0.0
#
# 2390 New Short trade at price: 881.86  On day: 2008-06-23 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2390 Short loss at price: 886.536 On day: 2008-06-24 00:00:00 With loss: -370.1475
#
# 2399 New Short trade at price: 886.755  On day: 2008-06-25 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2399 Moved SL to BE: 886.735 On day: 2008-06-25 12:00:00
#
# 2399 Trailing SL to first ATR: 883.7243 On day: 2008-06-25 12:00:00
#
# 2399 Short loss at price: 885.778 On day: 2008-06-25 16:00:00 With loss: 301.0675
#
# 2404 New Short trade at price: 884.271  On day: 2008-06-25 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2404 Short loss at price: 887.718 On day: 2008-06-26 00:00:00 With loss: -304.17
#
# 2406 New Short trade at price: 887.227  On day: 2008-06-26 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2406 Short loss at price: 896.738 On day: 2008-06-26 08:00:00 With loss: -307.015
#
# 2413 New Long trade at price: 921.669  On day: 2008-06-27 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2413 Moved SL to BE: 921.689 On day: 2008-06-27 12:00:00
#
# 2413 Long exited after 12 hours: 926.655 On day: 2008-07-01 04:00:00 With profit: 496.6
#
# 2426 New Long trade at price: 927.501  On day: 2008-07-01 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2426 Moved SL to BE: 927.521 On day: 2008-07-01 12:00:00
#
# 2426 Trailing SL to first ATR: 931.1236 On day: 2008-07-01 12:00:00
#
# 2426 Long exited after 12 hours: 943.757 On day: 2008-07-03 08:00:00 With profit: 1623.6
#
# 2439 New Long trade at price: 934.688  On day: 2008-07-03 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2439 Long loss at price: 931.028 On day: 2008-07-03 20:00:00 With loss: -347.125
#
# 2442 New Long trade at price: 935.038  On day: 2008-07-04 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2442 Long loss at price: 931.014 On day: 2008-07-04 08:00:00 With loss: -315.0975
#
# 2445 New Long trade at price: 931.715  On day: 2008-07-04 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2445 Long loss at price: 925.287 On day: 2008-07-07 00:00:00 With loss: -309.495
#
# 2456 New Long trade at price: 931.655  On day: 2008-07-08 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2456 Long loss at price: 923.39 On day: 2008-07-08 08:00:00 With loss: -280.325
#
# 2470 New Long trade at price: 938.782  On day: 2008-07-10 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2470 Moved SL to BE: 938.802 On day: 2008-07-10 16:00:00
#
# 2470 Trailing SL to first ATR: 942.4588 On day: 2008-07-10 16:00:00
#
# 2470 Long exited after 12 hours: 956.086 On day: 2008-07-14 08:00:00 With profit: 1728.4
#
# ...
# 25255 Moved SL to BE: 1636.615 On day: 2022-09-27 16:00:00
#
# 25255 Short loss at price: 1658.645 On day: 2022-09-28 12:00:00 With loss: -0.0
#
# 25265 New Short trade at price: 1654.285  On day: 2022-09-29 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25265 Moved SL to BE: 1654.265 On day: 2022-09-29 04:00:00
#
# 25265 Short loss at price: 1659.818 On day: 2022-09-29 12:00:00 With loss: -0.0
#
# 25310 New Short trade at price: 1682.718  On day: 2022-10-10 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25310 Moved SL to BE: 1682.698 On day: 2022-10-10 08:00:00
#
# 25310 Short exited after 12 hours: 1668.898 On day: 2022-10-12 04:00:00 With profit: 1380.0
#
# 25340 New Short trade at price: 1650.028  On day: 2022-10-17 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25340 Short loss at price: 1655.848 On day: 2022-10-17 04:00:00 With loss: -487.81
#
# 25342 New Short trade at price: 1657.848  On day: 2022-10-17 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25342 Short loss at price: 1663.218 On day: 2022-10-17 12:00:00 With loss: -489.595
#
# 25344 New Short trade at price: 1647.848  On day: 2022-10-17 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25344 Short loss at price: 1656.278 On day: 2022-10-18 04:00:00 With loss: -525.2225
#
# 25348 New Short trade at price: 1652.778  On day: 2022-10-18 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25348 Moved SL to BE: 1652.758 On day: 2022-10-19 04:00:00
#
# 25348 Short exited after 12 hours: 1637.168 On day: 2022-10-20 08:00:00 With profit: 1559.0
#
# 25361 New Short trade at price: 1641.148  On day: 2022-10-20 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25361 Moved SL to BE: 1641.128 On day: 2022-10-20 16:00:00
#
# 25361 Trailing SL to first ATR: 1636.7816 On day: 2022-10-20 16:00:00
#
# 25361 Short loss at price: 1650.668 On day: 2022-10-21 12:00:00 With loss: 434.64
#
# 25372 New Short trade at price: 1649.118  On day: 2022-10-24 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25372 Moved SL to BE: 1649.098 On day: 2022-10-25 08:00:00
#
# 25372 Short loss at price: 1655.898 On day: 2022-10-25 12:00:00 With loss: -0.0
#
# 25398 New Short trade at price: 1639.448  On day: 2022-10-28 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25398 Short loss at price: 1645.048 On day: 2022-10-28 16:00:00 With loss: -461.9775
#
# 25400 New Short trade at price: 1644.498  On day: 2022-10-28 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25400 Moved SL to BE: 1644.478 On day: 2022-10-31 08:00:00
#
# 25400 Short loss at price: 1645.148 On day: 2022-11-01 04:00:00 With loss: -0.0
#
# 25411 New Short trade at price: 1644.445  On day: 2022-11-01 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25411 Short loss at price: 1650.597 On day: 2022-11-02 00:00:00 With loss: -397.84
#
# 25417 New Short trade at price: 1646.288  On day: 2022-11-02 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25417 Moved SL to BE: 1646.268 On day: 2022-11-02 16:00:00
#
# 25417 Trailing SL to first ATR: 1642.05 On day: 2022-11-02 16:00:00
#
# 25417 Short loss at price: 1644.778 On day: 2022-11-04 04:00:00 With loss: 421.7975
#
# 25454 New Long trade at price: 1750.798  On day: 2022-11-10 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25454 Moved SL to BE: 1750.818 On day: 2022-11-11 04:00:00
#
# 25454 Long exited after 12 hours: 1756.198 On day: 2022-11-14 08:00:00 With profit: 538.0
#
# 25467 New Long trade at price: 1771.318  On day: 2022-11-14 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25467 Moved SL to BE: 1771.338 On day: 2022-11-15 04:00:00
#
# 25467 Trailing SL to first ATR: 1776.8725 On day: 2022-11-15 04:00:00
#
# 25467 Long loss at price: 1776.718 On day: 2022-11-15 08:00:00 With loss: 553.45
#
# 25473 New Long trade at price: 1771.008  On day: 2022-11-15 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25473 Moved SL to BE: 1771.028 On day: 2022-11-15 16:00:00
#
# 25473 Long loss at price: 1763.698 On day: 2022-11-17 00:00:00 With loss: -0.0
#
# 25483 New Long trade at price: 1766.858  On day: 2022-11-17 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25483 Long loss at price: 1760.088 On day: 2022-11-17 12:00:00 With loss: -496.4325
#
# 25486 New Long trade at price: 1760.647  On day: 2022-11-17 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25486 Moved SL to BE: 1760.667 On day: 2022-11-18 04:00:00
#
# 25486 Long loss at price: 1760.177 On day: 2022-11-18 08:00:00 With loss: -0.0
#
# 25491 New Long trade at price: 1757.178  On day: 2022-11-18 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25491 Long loss at price: 1748.198 On day: 2022-11-18 16:00:00 With loss: -466.4525
#
# 25515 New Long trade at price: 1758.178  On day: 2022-11-24 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25515 Long loss at price: 1751.468 On day: 2022-11-25 04:00:00 With loss: -379.8825
#
# 25527 New Long trade at price: 1758.528  On day: 2022-11-28 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25527 Long loss at price: 1745.307 On day: 2022-11-28 12:00:00 With loss: -382.58
#
# 25532 New Long trade at price: 1753.808  On day: 2022-11-29 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25532 Long loss at price: 1750.148 On day: 2022-11-29 16:00:00 With loss: -339.205
#
# 25537 New Long trade at price: 1754.598  On day: 2022-11-30 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25537 Moved SL to BE: 1754.618 On day: 2022-11-30 08:00:00
#
# 25537 Trailing SL to first ATR: 1758.3336 On day: 2022-11-30 08:00:00
#
# 25537 Long loss at price: 1752.408 On day: 2022-11-30 12:00:00 With loss: 371.5575
#
# 25541 New Long trade at price: 1767.718  On day: 2022-11-30 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25541 Moved SL to BE: 1767.738 On day: 2022-11-30 20:00:00
#
# 25541 Long exited after 12 hours: 1798.388 On day: 2022-12-02 16:00:00 With profit: 3065.0
#
# 25554 New Long trade at price: 1797.248  On day: 2022-12-02 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25554 Moved SL to BE: 1797.268 On day: 2022-12-05 00:00:00
#
# 25554 Trailing SL to first ATR: 1802.1807 On day: 2022-12-05 00:00:00
#
# 25554 Long loss at price: 1799.748 On day: 2022-12-05 04:00:00 With loss: 491.27
#
# 25558 New Long trade at price: 1793.738  On day: 2022-12-05 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25558 Long loss at price: 1777.788 On day: 2022-12-05 12:00:00 With loss: -516.97
#
# 25560 New Long trade at price: 1767.978  On day: 2022-12-05 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25560 Moved SL to BE: 1767.998 On day: 2022-12-06 08:00:00
#
# 25560 Trailing SL to first ATR: 1773.0102 On day: 2022-12-06 08:00:00
#
# 25560 Long loss at price: 1772.418 On day: 2022-12-06 12:00:00 With loss: 501.215
#
# 25566 New Long trade at price: 1771.258  On day: 2022-12-06 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25566 Moved SL to BE: 1771.278 On day: 2022-12-07 12:00:00
#
# 25566 Long exited after 12 hours: 1789.448 On day: 2022-12-08 16:00:00 With profit: 1817.0
#
# 25579 New Long trade at price: 1789.078  On day: 2022-12-08 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25579 Moved SL to BE: 1789.098 On day: 2022-12-09 00:00:00
#
# 25579 Long loss at price: 1787.378 On day: 2022-12-12 00:00:00 With loss: -0.0
#
# 25588 New Long trade at price: 1791.158  On day: 2022-12-12 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25588 Long loss at price: 1784.788 On day: 2022-12-12 12:00:00 With loss: -391.4325
#
# 25594 New Long trade at price: 1787.858  On day: 2022-12-13 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25594 Moved SL to BE: 1787.878 On day: 2022-12-13 12:00:00
#
# 25594 Trailing SL to first ATR: 1792.3031 On day: 2022-12-13 12:00:00
#
# 25594 Long loss at price: 1788.825 On day: 2022-12-15 04:00:00 With loss: 442.5075
#
# 25615 New Long trade at price: 1792.755  On day: 2022-12-16 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25615 Long loss at price: 1786.065 On day: 2022-12-19 12:00:00 With loss: -523.135
#
# 25624 New Long trade at price: 1792.105  On day: 2022-12-20 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25624 Moved SL to BE: 1792.125 On day: 2022-12-20 08:00:00
#
# 25624 Trailing SL to first ATR: 1796.0634 On day: 2022-12-20 08:00:00
#
# 25624 Long exited after 12 hours: 1819.325 On day: 2022-12-22 00:00:00 With profit: 2720.0
#
# 25637 New Long trade at price: 1816.765  On day: 2022-12-22 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25637 Long loss at price: 1795.418 On day: 2022-12-22 12:00:00 With loss: -373.4725
#
# 25645 New Long trade at price: 1800.415  On day: 2022-12-23 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25645 Moved SL to BE: 1800.435 On day: 2022-12-27 00:00:00
#
# 25645 Long exited after 12 hours: 1803.175 On day: 2022-12-28 08:00:00 With profit: 274.0
#
# 25659 New Long trade at price: 1805.265  On day: 2022-12-28 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25659 Moved SL to BE: 1805.285 On day: 2022-12-29 12:00:00
#
# 25659 Long exited after 12 hours: 1821.548 On day: 2022-12-30 16:00:00 With profit: 1626.3
#
# 25672 New Long trade at price: 1823.463  On day: 2022-12-30 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25672 Moved SL to BE: 1823.483 On day: 2023-01-02 20:00:00
#
# 25672 Long exited after 12 hours: 1852.335 On day: 2023-01-04 16:00:00 With profit: 2885.2
#
# 25685 New Long trade at price: 1854.648  On day: 2023-01-04 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25685 Long loss at price: 1849.265 On day: 2023-01-05 04:00:00 With loss: -510.525
#
# 25688 New Long trade at price: 1846.165  On day: 2023-01-05 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25688 Long loss at price: 1826.725 On day: 2023-01-05 12:00:00 With loss: -525.1075
#
# 25690 New Long trade at price: 1834.205  On day: 2023-01-05 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25690 Moved SL to BE: 1834.225 On day: 2023-01-06 12:00:00
#
# 25690 Trailing SL to first ATR: 1839.9914 On day: 2023-01-06 12:00:00
#
# 25690 Long exited after 12 hours: 1874.635 On day: 2023-01-09 12:00:00 With profit: 4041.0
#
# 25703 New Long trade at price: 1875.075  On day: 2023-01-09 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25703 Moved SL to BE: 1875.095 On day: 2023-01-11 04:00:00
#
# 25703 Long loss at price: 1871.875 On day: 2023-01-11 12:00:00 With loss: -0.0
#
# 25715 New Long trade at price: 1877.605  On day: 2023-01-11 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25715 Moved SL to BE: 1877.625 On day: 2023-01-12 00:00:00
#
# 25715 Long profit at price: 1919.945 On day: 2023-01-13 16:00:00 With profit: 3824.675
#
# 25728 New Long trade at price: 1919.398  On day: 2023-01-13 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25728 Moved SL to BE: 1919.418 On day: 2023-01-16 00:00:00
#
# 25728 Long loss at price: 1917.018 On day: 2023-01-16 04:00:00 With loss: -0.0
#
# 25732 New Long trade at price: 1916.495  On day: 2023-01-16 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25732 Long loss at price: 1910.215 On day: 2023-01-17 00:00:00 With loss: -505.34
#
# 25737 New Long trade at price: 1909.845  On day: 2023-01-17 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25737 Long loss at price: 1899.967 On day: 2023-01-18 00:00:00 With loss: -470.125
#
# 25743 New Long trade at price: 1907.655  On day: 2023-01-18 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25743 Moved SL to BE: 1907.675 On day: 2023-01-18 08:00:00
#
# 25743 Long loss at price: 1904.968 On day: 2023-01-18 16:00:00 With loss: -0.0
#
# 25747 New Long trade at price: 1906.795  On day: 2023-01-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25747 Moved SL to BE: 1906.815 On day: 2023-01-19 04:00:00
#
# 25747 Long exited after 12 hours: 1925.298 On day: 2023-01-20 20:00:00 With profit: 1848.3
#
# 25760 New Long trade at price: 1927.165  On day: 2023-01-22 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25760 Long loss at price: 1920.185 On day: 2023-01-23 04:00:00 With loss: -466.8875
#
# 25763 New Long trade at price: 1925.428  On day: 2023-01-23 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25763 Moved SL to BE: 1925.448 On day: 2023-01-23 20:00:00
#
# 25763 Long exited after 12 hours: 1925.865 On day: 2023-01-25 08:00:00 With profit: 41.7
#
# 25776 New Long trade at price: 1932.875  On day: 2023-01-25 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25776 Moved SL to BE: 1932.895 On day: 2023-01-25 16:00:00
#
# 25776 Long loss at price: 1924.667 On day: 2023-01-26 12:00:00 With loss: -0.0
#
# 25783 New Long trade at price: 1931.105  On day: 2023-01-26 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25783 Long loss at price: 1924.665 On day: 2023-01-27 00:00:00 With loss: -554.825
#
# 25787 New Long trade at price: 1930.018  On day: 2023-01-27 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25787 Long loss at price: 1923.975 On day: 2023-01-27 12:00:00 With loss: -528.1
#
# 25789 New Long trade at price: 1929.825  On day: 2023-01-27 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25789 Long loss at price: 1923.105 On day: 2023-01-30 08:00:00 With loss: -551.0
#
# 25807 New Long trade at price: 1931.785  On day: 2023-02-01 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25807 Moved SL to BE: 1931.805 On day: 2023-02-01 16:00:00
#
# 25807 Trailing SL to first ATR: 1936.1816 On day: 2023-02-01 16:00:00
#
# 25807 Long loss at price: 1926.065 On day: 2023-02-02 12:00:00 With loss: 437.66
#
# 25855 New Short trade at price: 1863.835  On day: 2023-02-13 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25855 Moved SL to BE: 1863.815 On day: 2023-02-13 12:00:00
#
# 25855 Short exited after 12 hours: 1835.575 On day: 2023-02-15 04:00:00 With profit: 2824.0
#
# 25868 New Short trade at price: 1834.885  On day: 2023-02-15 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25868 Short loss at price: 1840.375 On day: 2023-02-16 00:00:00 With loss: -450.1625
#
# 25873 New Short trade at price: 1841.235  On day: 2023-02-16 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25873 Moved SL to BE: 1841.215 On day: 2023-02-16 12:00:00
#
# 25873 Short loss at price: 1842.665 On day: 2023-02-16 16:00:00 With loss: -0.0
#
# 25877 New Short trade at price: 1834.255  On day: 2023-02-16 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25877 Moved SL to BE: 1834.235 On day: 2023-02-17 00:00:00
#
# 25877 Short loss at price: 1834.644 On day: 2023-02-17 12:00:00 With loss: -0.0
#
# 25882 New Short trade at price: 1842.635  On day: 2023-02-17 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25882 Moved SL to BE: 1842.615 On day: 2023-02-21 00:00:00
#
# 25882 Short exited after 12 hours: 1838.645 On day: 2023-02-21 12:00:00 With profit: 397.0
#
# 25895 New Short trade at price: 1833.948  On day: 2023-02-21 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25895 Short loss at price: 1839.734 On day: 2023-02-22 04:00:00 With loss: -372.66
#
# 25899 New Short trade at price: 1838.785  On day: 2023-02-22 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25899 Moved SL to BE: 1838.765 On day: 2023-02-22 16:00:00
#
# 25899 Trailing SL to first ATR: 1835.5222 On day: 2023-02-22 16:00:00
#
# 25899 Short exited after 12 hours: 1819.038 On day: 2023-02-24 08:00:00 With profit: 1972.7
#
# 25912 New Short trade at price: 1810.518  On day: 2023-02-24 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25912 Short loss at price: 1815.258 On day: 2023-02-27 12:00:00 With loss: -368.15
#
# 25920 New Short trade at price: 1817.305  On day: 2023-02-27 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25920 Moved SL to BE: 1817.285 On day: 2023-02-28 04:00:00
#
# 25920 Trailing SL to first ATR: 1814.2779 On day: 2023-02-28 04:00:00
#
# 25920 Short loss at price: 1823.975 On day: 2023-02-28 12:00:00 With loss: 300.7125
#
# 25927 New Short trade at price: 1825.395  On day: 2023-02-28 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25927 Short loss at price: 1830.895 On day: 2023-03-01 00:00:00 With loss: -326.5075
#
# 25956 New Short trade at price: 1817.905  On day: 2023-03-07 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25956 Moved SL to BE: 1817.885 On day: 2023-03-07 16:00:00
#
# 25956 Short loss at price: 1820.555 On day: 2023-03-08 12:00:00 With loss: -0.0
#
# 25963 New Short trade at price: 1816.195  On day: 2023-03-08 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25963 Short loss at price: 1828.595 On day: 2023-03-09 12:00:00 With loss: -375.915
#
# 25969 New Short trade at price: 1830.495  On day: 2023-03-09 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25969 Short loss at price: 1834.865 On day: 2023-03-10 08:00:00 With loss: -399.675

# %%
pairs_results = {}
profits = {}
losses = {}
be = {}

for pair in range(len(pairs_list)):
    profits[pair] = []
    losses[pair] = []
    be[pair] = []
    
    pairs_results[pair] = pd.DataFrame.from_dict({(i, j): trade[pair][j] for j in trade[pair].keys()}, orient = 'index')
    pairs_results[pair] = pairs_results[pair].drop(['signal', 'ID', 'TP', 'SL'], axis = 1)
    pairs_results[pair].set_index('date_of_trade', inplace = True)
    pairs_results[pair]['cum_res'] = pairs_results[pair]['result'].cumsum() + account_size
    
    for t in trade[pair]:
        profits[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] > 0.1 else ''
        losses[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] < -0.1 else ''
        be[pair].append(trade[pair][t]['result']) if -0.1 <= trade[pair][t]['result'] <= 0.1 else ''
        
my_reduce = partial(pd.merge, on = 'date_of_trade', how = 'outer')
strategy_results = reduce(my_reduce, pairs_results.values())
strategy_results = strategy_results.sort_index()
strategy_results['final_res'] = strategy_results.filter(like = 'result', axis = 1).sum(axis = 1)
strategy_results['cum_res'] = strategy_results['final_res'].cumsum() + account_size

profits_keys = list(profits.keys())
profits_values = [profits[x] for x in profits_keys]
str_profits = list(flatten(profits_values))

losses_keys = list(losses.keys())
losses_values = [losses[x] for x in losses_keys]
str_losses = list(flatten(losses_values))

be_keys = list(be.keys())
be_values = [be[x] for x in be_keys]
str_be = list(flatten(be_values))

# %%
plt.figure(figsize = (26, 10))
for pair in range(len(pairs_list)):
    plt.plot(pairs_results[pair]['cum_res'], label = pairs_list[pair])
plt.legend()
plt.title('Returns of each pair', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Returns of each pair')

# %%
#Strategy performance
print('***** STRATEGY PERFORMANCE *****')
print('--------------------------------')
print('CAGR:', CAGR(strategy_results, df[0],account_size), '%')
print('Sharpe ratio:', sharpe_ratio(strategy_results))
print('Maximum drawdown', max_drawdown(strategy_results), '% \n')
print('Number of trades:', len(str_profits + str_losses + str_be))
print('Number of profits:', len(str_profits))
print('Number of losses:', len(str_losses))
print('Number of breakevens:', len(str_be), '\n')
print('Winning percentage', (round(len(str_profits) / (len(str_profits) + len(str_losses)) * 100, 2)), '%')
print('ROI:', round(strategy_results['cum_res'][-1]) - account_size)
print('--------------------------------')
print('Average profitable trade:', round(sum(str_profits) / len(str_profits), 2))
print('Average lossing trade:', round(sum(str_losses) / len(str_losses), 2))
print('Max profitable trade:', round(max(str_profits), 2))
print('Max lossing trade:', round(min(str_losses), 2))

plt.figure(figsize = (26, 6))
plt.plot(strategy_results['cum_res'])
plt.title('return of strategy', fontsize = 18)
# Out:
# ***** STRATEGY PERFORMANCE *****
# --------------------------------
# CAGR: 353.7 %
# Sharpe ratio: -0.02
# Maximum drawdown 50.28 %
#
# Number of trades: 2373
# Number of profits: 760
# Number of losses: 1181
# Number of breakevens: 432
#
# Winning percentage 39.16 %
# ROI: 660959
# --------------------------------
# Average profitable trade: 1451.29
# Average lossing trade: -374.28
# Max profitable trade: 8109.27
# Max lossing trade: -1462.85
# c:\Users\Win10\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Text(0.5, 1.0, 'return of strategy')

# %%
#performance for each pair
for pair in range(len(pairs_list)):
    print(pairs_list[pair], '- PERFORMANCE')
    print('--------------------------------')
    print('Number of trades:', len(profits[pair] + losses[pair] + be[pair]))
    print('Number of profits:', len(profits[pair]))
    print('Number of losses:', len(losses[pair]))
    print('Number of breakevens:', len(be[pair]), '\n')
    print('Winning percentage', (round(len(profits[pair]) / (len(profits[pair]) + len(losses[pair])) * 100, 2)), '%')
    print('ROI:', round(pairs_results[pair]['cum_res'][-1] - account_size, 2))
    print('--------------------------------')
    print('Average profitable trade:', round(sum(profits[pair]) / len(profits[pair]), 2))
    print('Average lossing trade:', round(sum(losses[pair]) / len(losses[pair]), 2))
    print('Max profitable trade:', round(max(profits[pair]), 2))
    print('Max lossing trade:', round(min(losses[pair]), 2))
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx \n')
    
    plt.figure(figsize = (26, 8))
    plt.plot(pairs_results[pair]['cum_res'])
    plt.show()
# Out:
# XAUUSD/XAUUSD_H4 - XAUUSD_H4 - PERFORMANCE
# --------------------------------
# Number of trades: 2373
# Number of profits: 760
# Number of losses: 1181
# Number of breakevens: 432
#
# Winning percentage 39.16 %
# ROI: 660958.63
# --------------------------------
# Average profitable trade: 1451.29
# Average lossing trade: -374.28
# Max profitable trade: 8109.27
# Max lossing trade: -1462.85
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
