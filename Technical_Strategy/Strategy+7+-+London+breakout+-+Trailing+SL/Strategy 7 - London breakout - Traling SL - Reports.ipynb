# %% [markdown]
# # London breakout

# %% [markdown]
# ## Import Library

# %%
import sys
sys.path.append('../../')

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import os
import pandas as pd
# import pandas_datareader as pdr
import numpy as np
import quantstats as qs
from config.constants import *
from util.plot_equity import plot_equity_trades
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get Result

# %% [markdown]
# ## Load results strategy Buy and Hold

# %%
benchmark_D1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
benchmark_H4 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
benckmark_H1 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
benckmark_M30 = pd.read_csv(
    '../../out/Technical_Strategy/Buy_and_Hold/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %% [markdown]
# ## Load results Strategy

# %%
folder_strategy = 'London_breakout'

# %%
result_D1 = pd.read_csv(f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_D1.csv', index_col='Time', parse_dates=True)
result_H4 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H4.csv', index_col='Time', parse_dates=True)
result_H1 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_H1.csv', index_col='Time', parse_dates=True)
result_M30 = pd.read_csv(
    f'../../out/Technical_Strategy/{folder_strategy}/Backtest/result_M30.csv', index_col='Time', parse_dates=True)

# %% [markdown]
# ## Define Strategy

# %% [markdown]
# # Reports each time frame

# %% [markdown]
# ## TF D1

# %% [markdown]
# ### Reports

# %%
# qs.reports.full(result_D1['Equity'].resample('D').last().dropna().pct_change())

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
# qs.reports.full(result_D1['Equity'].resample('D').last().dropna().pct_change(
# ), benchmark=benchmark_D1['Equity'].resample('D').last().dropna().pct_change())

# %% [markdown]
# ## TF H4

# %% [markdown]
# ### Reports

# %%
# qs.reports.full(result_H4['Equity'].resample('D').last().dropna().pct_change())

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
# qs.reports.full(result_H4['Equity'].resample('D').last().dropna().pct_change(
# ), benchmark=benchmark_H4['Equity'].resample('D').last().dropna().pct_change())

# %% [markdown]
# ## TF H1

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_H1['Equity'].resample('D').last().dropna().pct_change())
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2007-01-02
# End Period                 2023-03-10
# Risk-Free Rate             0.0%
# Time in Market             41.0%
#
# Cumulative Return          -2.18%
# CAGR﹪                     -0.09%
#
# Sharpe                     -0.23
# Prob. Sharpe Ratio         15.47%
# Smart Sharpe               -0.23
# Sortino                    -0.49
# Smart Sortino              -0.49
# Sortino/√2                 -0.35
# Smart Sortino/√2           -0.34
# Omega                      0.94
#
# Max Drawdown               -2.86%
# Longest DD Days            5405
# Volatility (ann.)          0.47%
# Calmar                     -0.03
# Skew                       3.12
# Kurtosis                   17.18
#
# Expected Daily %           -0.0%
# Expected Monthly %         -0.01%
# Expected Yearly %          -0.13%
# Kelly Criterion            -1.33%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.05%
# Expected Shortfall (cVaR)  -0.05%
#
# Max Consecutive Wins       4
# Max Consecutive Losses     6
# Gain/Pain Ratio            -0.06
# Gain/Pain (1M)             -0.18
#
# Payoff Ratio               3.68
# Profit Factor              0.94
# Common Sense Ratio         2.06
# CPC Index                  0.7
# Tail Ratio                 2.19
# Outlier Win Ratio          12.75
# Outlier Loss Ratio         2.02
#
# MTD                        -0.09%
# 3M                         -0.3%
# 6M                         -0.17%
# YTD                        -0.38%
# 1Y                         0.25%
# 3Y (ann.)                  -0.08%
# 5Y (ann.)                  -0.14%
# 10Y (ann.)                 -0.03%
# All-time (ann.)            -0.09%
#
# Best Day                   0.37%
# Worst Day                  -0.17%
# Best Month                 0.68%
# Worst Month                -0.45%
# Best Year                  1.75%
# Worst Year                 -0.97%
#
# Avg. Drawdown              -0.52%
# Avg. Drawdown Days         842
# Recovery Factor            0.76
# Ulcer Index                0.02
# Serenity Index             -0.02
#
# Avg. Up Month              0.12%
# Avg. Down Month            -0.1%
# Win Days %                 20.3%
# Win Month %                41.03%
# Win Quarter %              46.15%
# Win Year %                 29.41%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-05-23  2011-12-23  2023-03-10  5405     -2.857690         -2.756870
# 2  2007-01-08  2007-05-04  2007-11-26   323     -0.341878         -0.341509
# 3  2008-01-09  2008-04-25  2008-05-21   134     -0.276170         -0.255975
# 4  2007-11-28  2007-12-07  2007-12-13    16     -0.105736         -0.092071
# 5  2008-01-04  2008-01-04  2008-01-07     4     -0.020236               NaN
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_H1['Equity'].resample('D').last().dropna().pct_change(
), benchmark=benckmark_H1['Equity'].resample('D').last().dropna().pct_change())
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-03   2007-01-03
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       41.0%
#
# Cumulative Return          12.51%       -2.17%
# CAGR﹪                     0.5%         -0.09%
#
# Sharpe                     0.32         -0.23
# Prob. Sharpe Ratio         91.99%       15.56%
# Smart Sharpe               0.31         -0.23
# Sortino                    0.43         -0.49
# Smart Sortino              0.43         -0.48
# Sortino/√2                 0.31         -0.35
# Smart Sortino/√2           0.3          -0.34
# Omega                      0.94         0.94
#
# Max Drawdown               -7.6%        -2.86%
# Longest DD Days            3259         5405
# Volatility (ann.)          1.92%        0.47%
# R^2                        0.0          0.0
# Information Ratio          -0.02        -0.02
# Calmar                     0.07         -0.03
# Skew                       -0.73        3.12
# Kurtosis                   8.47         17.18
#
# Expected Daily %           0.0%         -0.0%
# Expected Monthly %         0.06%        -0.01%
# Expected Yearly %          0.7%         -0.13%
# Kelly Criterion            20.09%       -2.85%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.2%        -0.05%
# Expected Shortfall (cVaR)  -0.2%        -0.05%
#
# Max Consecutive Wins       11           4
# Max Consecutive Losses     9            6
# Gain/Pain Ratio            0.06         -0.06
# Gain/Pain (1M)             0.3          -0.18
#
# Payoff Ratio               1.4          3.44
# Profit Factor              1.06         0.94
# Common Sense Ratio         1.07         2.06
# CPC Index                  0.8          0.66
# Tail Ratio                 1.0          2.19
# Outlier Win Ratio          2.88         22.89
# Outlier Loss Ratio         2.36         9.08
#
# MTD                        0.27%        -0.09%
# 3M                         0.54%        -0.3%
# 6M                         1.26%        -0.17%
# YTD                        0.28%        -0.38%
# 1Y                         -1.18%       0.25%
# 3Y (ann.)                  0.37%        -0.08%
# 5Y (ann.)                  0.67%        -0.14%
# 10Y (ann.)                 0.17%        -0.03%
# All-time (ann.)            0.5%         -0.09%
#
# Best Day                   0.85%        0.37%
# Worst Day                  -1.27%       -0.17%
# Best Month                 1.93%        0.68%
# Worst Month                -1.82%       -0.45%
# Best Year                  3.5%         1.75%
# Worst Year                 -4.25%       -0.97%
#
# Avg. Drawdown              -0.37%       -0.52%
# Avg. Drawdown Days         74           842
# Recovery Factor            1.6          0.76
# Ulcer Index                0.04         0.02
# Serenity Index             0.05         -0.02
#
# Avg. Up Month              0.47%        0.12%
# Avg. Down Month            -0.46%       -0.1%
# Win Days %                 53.33%       20.31%
# Win Month %                51.79%       41.03%
# Win Quarter %              64.62%       46.15%
# Win Year %                 64.71%       29.41%
#
# Beta                       -            -0.02
# Alpha                      -            -0.0
# Correlation                -            -6.69%
# Treynor Ratio              -            132.95%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-05-23  2011-12-23  2023-03-10  5405     -2.857690         -2.756870
# 2  2007-01-08  2007-05-04  2007-11-26   323     -0.341878         -0.341509
# 3  2008-01-09  2008-04-25  2008-05-21   134     -0.276170         -0.255975
# 4  2007-11-28  2007-12-07  2007-12-13    16     -0.105736         -0.092071
# 5  2008-01-04  2008-01-04  2008-01-07     4     -0.020236               NaN
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ## TF M30

# %% [markdown]
# ### Reports

# %%
qs.reports.full(result_M30['Equity'].resample('D').last().dropna().pct_change())
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2007-01-02
# End Period                 2023-03-10
# Risk-Free Rate             0.0%
# Time in Market             57.0%
#
# Cumulative Return          -8.1%
# CAGR﹪                     -0.36%
#
# Sharpe                     -1.25
# Prob. Sharpe Ratio         0.0%
# Smart Sharpe               -1.23
# Sortino                    -2.41
# Smart Sortino              -2.37
# Sortino/√2                 -1.7
# Smart Sortino/√2           -1.67
# Omega                      0.75
#
# Max Drawdown               -8.23%
# Longest DD Days            5857
# Volatility (ann.)          0.34%
# Calmar                     -0.04
# Skew                       3.64
# Kurtosis                   28.3
#
# Expected Daily %           -0.0%
# Expected Monthly %         -0.04%
# Expected Yearly %          -0.5%
# Kelly Criterion            -6.27%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.04%
# Expected Shortfall (cVaR)  -0.04%
#
# Max Consecutive Wins       3
# Max Consecutive Losses     6
# Gain/Pain Ratio            -0.25
# Gain/Pain (1M)             -0.65
#
# Payoff Ratio               3.3
# Profit Factor              0.75
# Common Sense Ratio         1.4
# CPC Index                  0.45
# Tail Ratio                 1.88
# Outlier Win Ratio          8.64
# Outlier Loss Ratio         2.37
#
# MTD                        -0.12%
# 3M                         -0.21%
# 6M                         -0.15%
# YTD                        -0.27%
# 1Y                         -0.59%
# 3Y (ann.)                  -0.58%
# 5Y (ann.)                  -0.54%
# 10Y (ann.)                 -0.31%
# All-time (ann.)            -0.36%
#
# Best Day                   0.3%
# Worst Day                  -0.1%
# Best Month                 0.31%
# Worst Month                -0.65%
# Best Year                  0.72%
# Worst Year                 -1.1%
#
# Avg. Drawdown              -4.18%
# Avg. Drawdown Days         2952
# Recovery Factor            1.03
# Ulcer Index                0.04
# Serenity Index             -0.01
#
# Avg. Up Month              0.07%
# Avg. Down Month            -0.1%
# Win Days %                 18.47%
# Win Month %                31.28%
# Win Quarter %              18.46%
# Win Year %                 5.88%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2007-02-26  2022-10-25  2023-03-10  5857     -8.228882         -8.061400
# 2  2007-01-08  2007-01-26  2007-02-22    46     -0.124416         -0.117471
# <h4>Strategy Visualization</h4>

# %% [markdown]
# ### Compare benchmark Buy and Hold

# %%
qs.reports.full(result_M30['Equity'].resample('D').last().dropna().pct_change(
), benchmark=benckmark_M30['Equity'].resample('D').last().dropna().pct_change())
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2007-01-03   2007-01-03
# End Period                 2023-03-10   2023-03-10
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       57.0%
#
# Cumulative Return          12.58%       -8.09%
# CAGR﹪                     0.51%        -0.36%
#
# Sharpe                     0.32         -1.25
# Prob. Sharpe Ratio         92.1%        0.0%
# Smart Sharpe               0.31         -1.23
# Sortino                    0.43         -2.41
# Smart Sortino              0.43         -2.36
# Sortino/√2                 0.31         -1.7
# Smart Sortino/√2           0.3          -1.67
# Omega                      0.75         0.75
#
# Max Drawdown               -7.6%        -8.23%
# Longest DD Days            3259         5857
# Volatility (ann.)          1.92%        0.34%
# R^2                        0.0          0.0
# Information Ratio          -0.03        -0.03
# Calmar                     0.07         -0.04
# Skew                       -0.72        3.64
# Kurtosis                   8.47         28.29
#
# Expected Daily %           0.0%         -0.0%
# Expected Monthly %         0.06%        -0.04%
# Expected Yearly %          0.7%         -0.5%
# Kelly Criterion            9.65%        -6.23%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.2%        -0.04%
# Expected Shortfall (cVaR)  -0.2%        -0.04%
#
# Max Consecutive Wins       11           3
# Max Consecutive Losses     9            6
# Gain/Pain Ratio            0.06         -0.25
# Gain/Pain (1M)             0.3          -0.65
#
# Payoff Ratio               1.07         3.3
# Profit Factor              1.06         0.75
# Common Sense Ratio         1.07         1.4
# CPC Index                  0.61         0.46
# Tail Ratio                 1.0          1.88
# Outlier Win Ratio          2.59         21.93
# Outlier Loss Ratio         2.3          13.47
#
# MTD                        0.33%        -0.12%
# 3M                         0.6%         -0.21%
# 6M                         1.32%        -0.15%
# YTD                        0.35%        -0.27%
# 1Y                         -1.12%       -0.59%
# 3Y (ann.)                  0.39%        -0.58%
# 5Y (ann.)                  0.68%        -0.54%
# 10Y (ann.)                 0.18%        -0.31%
# All-time (ann.)            0.51%        -0.36%
#
# Best Day                   0.85%        0.3%
# Worst Day                  -1.27%       -0.1%
# Best Month                 1.93%        0.31%
# Worst Month                -1.82%       -0.65%
# Best Year                  3.5%         0.72%
# Worst Year                 -4.25%       -1.1%
#
# Avg. Drawdown              -0.37%       -4.18%
# Avg. Drawdown Days         74           2952
# Recovery Factor            1.61         1.02
# Ulcer Index                0.04         0.04
# Serenity Index             0.05         -0.01
#
# Avg. Up Month              0.62%        0.06%
# Avg. Down Month            -0.4%        -0.1%
# Win Days %                 53.33%       18.47%
# Win Month %                51.79%       31.28%
# Win Quarter %              64.62%       18.46%
# Win Year %                 64.71%       5.88%
#
# Beta                       -            -0.01
# Alpha                      -            -0.0
# Correlation                -            -4.27%
# Treynor Ratio              -            1078.39%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2007-02-26  2022-10-25  2023-03-10  5857     -8.228882         -8.061400
# 2  2007-01-08  2007-01-26  2007-02-22    46     -0.124416         -0.117471
# <h4>Strategy Visualization</h4>
