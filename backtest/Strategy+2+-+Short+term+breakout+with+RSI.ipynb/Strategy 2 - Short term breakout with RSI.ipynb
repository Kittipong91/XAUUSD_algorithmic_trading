# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
import os
import matplotlib.style
from pandas.core.common import flatten
from functools import partial, reduce

# %%
import sys
sys.path.append('../../')

# %%
from config.constants import *

# %%
plt.style.use('ggplot')

# %%
pairs_list = [
    'XAUUSD/XAUUSD_H4 - XAUUSD_H4',
]

# %%
df = {}
for pair in range(len(pairs_list)):
    df[pair] = pd.read_csv(PATH_DATA + SYMBOL['XAUUSD']['H4'] + '.csv', index_col='Time',parse_dates=True)

# %%
plt.figure(figsize = (26, 8))
plt.plot(df[0]['Close'])

# %%
def rsi(df, n):
    df['diff'] = df['Close'].diff(1).dropna()
    df['gains'] = np.where(df['diff'] > 0, df['diff'], np.nan)
    df['losses'] = np.where(df['diff'] <= 0, df['diff'], np.nan)
    df['average_gains'] = df['gains'].rolling(n, min_periods = 1).mean()
    df['average_losses'] = df['losses'].rolling(n, min_periods = 1).mean()
    rs = abs(df['average_gains'] / df['average_losses'])
    df['RSI'] = 100 - (100 / (1 + rs))
    df = df.drop(['diff', 'gains', 'losses', 'average_gains', 'average_losses'], axis = 1)
    return df

def ATR(df, n):
    df = df.copy()
    df['High-Low'] = abs(df['High'] - df['Low'])
    df['High-PrevClose'] = abs(df['High'] - df['Close'].shift(1))
    df['Low-PrevClose'] = abs(df['Low'] - df['Close'].shift(1))
    df['TR'] = df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis = 1, skipna = False)
    df['ATR'] = df['TR'].rolling(n).mean()
    df = df.drop(['High-Low', 'High-PrevClose', 'Low-PrevClose'], axis = 1)
    return df

# %%
#Strategy parameters
account_size = 10000
slippage = 2
size = 1
ATR_SL = 0.5

for pair in range(len(pairs_list)):
    df[pair]['ATR'] = ATR(df[pair], 20)['ATR']
    df[pair]['RSI'] = rsi(df[pair], 14)['RSI']
    df[pair]['average_close'] = df[pair]['Close'].rolling(5).mean()
    if 'JPY' not in pairs_list[pair]:
        df[pair]['spread'] = float(slippage) / float(10000)
        df[pair]['size'] = float(size) * float(10000)
        print('Pair: ', pairs_list[pair], 'a')
    else:
        df[pair]['spread'] = float(slippage) / float(100)
        df[pair]['size'] = float(size) * float(100)
        print('Pair: ', pairs_list[pair], 'b')
# Out:
# Pair:  XAUUSD/XAUUSD_H4 - XAUUSD_H4 a

# %%
df[0]
# Out:
#                          Open      High       Low     Close  Volume      ATR  \
# Time
# 2007-01-01 00:00:00   635.679   636.194   635.009   635.497      95      NaN
# 2007-01-01 04:00:00   635.336   636.220   635.254   635.699      97      NaN
# 2007-01-01 08:00:00   635.780   636.225   635.201   635.993      99      NaN
# 2007-01-01 12:00:00   636.053   636.189   635.117   636.006      90      NaN
# 2007-01-01 16:00:00   635.902   636.185   635.006   635.989      96      NaN
# ...                       ...       ...       ...       ...     ...      ...
# 2023-03-10 00:00:00  1831.428  1834.765  1827.974  1829.085     240  7.78390
# 2023-03-10 04:00:00  1829.085  1834.575  1827.675  1833.405     240  8.04590
# 2023-03-10 08:00:00  1833.415  1837.245  1830.778  1834.865     240  8.05175
# 2023-03-10 12:00:00  1834.885  1867.348  1831.384  1862.975     240  9.53595
# 2023-03-10 16:00:00  1862.985  1865.005  1854.005  1864.098     120  9.65145
#
#                        diff   gains  losses  average_gains  average_losses  \
# Time
# 2007-01-01 00:00:00     NaN     NaN     NaN            NaN             NaN
# 2007-01-01 04:00:00   0.202   0.202     NaN       0.202000             NaN
# 2007-01-01 08:00:00   0.294   0.294     NaN       0.248000             NaN
# 2007-01-01 12:00:00   0.013   0.013     NaN       0.169667             NaN
# 2007-01-01 16:00:00  -0.017     NaN  -0.017       0.169667        -0.01700
# ...                     ...     ...     ...            ...             ...
# 2023-03-10 00:00:00  -2.330     NaN  -2.330       3.190444        -2.69280
# 2023-03-10 04:00:00   4.320   4.320     NaN       3.667111        -2.69280
# 2023-03-10 08:00:00   1.460   1.460     NaN       3.446400        -2.32175
# 2023-03-10 12:00:00  28.110  28.110     NaN       5.812700        -2.32175
# 2023-03-10 16:00:00   1.123   1.123     NaN       5.843000        -2.32175
#
#                            RSI  average_close  spread     size
# Time
# 2007-01-01 00:00:00        NaN            NaN  0.0002  10000.0
# 2007-01-01 04:00:00        NaN            NaN  0.0002  10000.0
# 2007-01-01 08:00:00        NaN            NaN  0.0002  10000.0
# 2007-01-01 12:00:00        NaN            NaN  0.0002  10000.0
# 2007-01-01 16:00:00  90.892857       635.8368  0.0002  10000.0
# ...                        ...            ...     ...      ...
# 2023-03-10 00:00:00  54.229337      1827.6390  0.0002  10000.0
# 2023-03-10 04:00:00  57.659786      1830.5990  0.0002  10000.0
# 2023-03-10 08:00:00  59.748793      1831.8530  0.0002  10000.0
# 2023-03-10 12:00:00  71.457812      1838.3490  0.0002  10000.0
# 2023-03-10 16:00:00  71.563734      1844.8856  0.0002  10000.0
#
# [25976 rows x 15 columns]

# %%
open_trade = {}
trade = {}
long_take_profit = {}
short_take_profit = {}
long_stop_loss = {}
short_stop_loss = {}
long_entry_price = {}
short_entry_price = {}

for pair in range(len(pairs_list)):
    open_trade[pair] = []
    trade[pair] = {}
    long_take_profit[pair] = []
    short_take_profit[pair] = []
    long_stop_loss[pair] = []
    short_stop_loss[pair] = []
    long_entry_price[pair] = []
    short_entry_price[pair] = []
    
    for i in range(50, len(df[pair])):
        #Buy
        if df[pair]['RSI'][i-1] < 20 and df[pair]['Close'][i - 1] < df[pair]['average_close'][i - 1] and df[pair]['Close'][i] >= df[pair]['average_close'][i] \
            and len(open_trade[pair]) == 0:
            print(i, 'New Long trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                             'date_of_trade': df[pair].index[i],
                             'entry_price': df[pair]['Close'][i],
                             'signal': 'Buy',
                             'result': 0, 
                             'TP': df[pair]['Close'][i] + df[pair]['ATR'][i] * ATR_SL,
                             'SL': df[pair]['Close'][i] - df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            long_take_profit[pair].append(trade[pair][i]['TP'])
            long_stop_loss[pair].append(trade[pair][i]['SL'])
            long_entry_price[pair].append(trade[pair][i]['entry_price'])
        
        #Sell
        if df[pair]['RSI'][i-1] > 80 and df[pair]['Close'][i - 1] > df[pair]['average_close'][i - 1] and df[pair]['Close'][i] <= df[pair]['average_close'][i] \
            and len(open_trade[pair]) == 0:
            print(i, 'New Short trade at price:', round(df[pair]['Close'][i], 4), ' On day:', df[pair].index[i], 'Pair:', pairs_list[pair])
            trade[pair][i] = {'ID': i,
                             'date_of_trade': df[pair].index[i],
                             'entry_price': df[pair]['Close'][i],
                             'signal': 'Sell',
                             'result': 0, 
                             'TP': df[pair]['Close'][i] - df[pair]['ATR'][i] * ATR_SL,
                             'SL': df[pair]['Close'][i] + df[pair]['ATR'][i] * ATR_SL}
            open_trade[pair].append(i)
            short_take_profit[pair].append(trade[pair][i]['TP'])
            short_stop_loss[pair].append(trade[pair][i]['SL'])
            short_entry_price[pair].append(trade[pair][i]['entry_price'])
            
        #Exit trades---------------------------------------------------------------------------
        #Buy profit
        if any(y <= df[pair]['Close'][i] for y in long_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] >= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['TP'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Buy loss
        if any(y >= df[pair]['Close'][i] for y in long_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    if df[pair]['Close'][i] <= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['SL'] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Long loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        long_take_profit[pair].remove(trade[pair][j]['TP'])
                        long_stop_loss[pair].remove(trade[pair][j]['SL'])
                        
        #Sell profit
        if any(y >= df[pair]['Close'][i] for y in short_take_profit[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] <= trade[pair][j]['TP']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['TP'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short profit at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With profit:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Sell loss
        if any(y <= df[pair]['Close'][i] for y in short_stop_loss[pair]):
            for j in open_trade[pair]:
                if trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    if df[pair]['Close'][i] >= trade[pair][j]['SL']:
                        trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - trade[pair][j]['SL'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                        print(j, 
                             'Short loss at price:', round(df[pair]['Close'][i], 4),
                             'On day:', df[pair].index[i],
                             'With loss:', round(trade[pair][j]['result'], 4), '\n')
                        open_trade[pair].remove(j)
                        short_take_profit[pair].remove(trade[pair][j]['TP'])
                        short_stop_loss[pair].remove(trade[pair][j]['SL'])
        #Exit after time
        if len(open_trade[pair]) != 0:
            for j in open_trade[pair]:
                if (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Buy':
                    trade[pair][j].update({'result' : (df[pair]['Close'][i] - trade[pair][j]['entry_price'] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Long exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    long_take_profit[pair].remove(trade[pair][j]['TP'])
                    long_stop_loss[pair].remove(trade[pair][j]['SL'])
                elif (i - trade[pair][j]['ID']) >= 12 and trade[pair][j].get('result', {}) == 0 and trade[pair][j].get('signal', {}) == 'Sell':
                    trade[pair][j].update({'result' : (trade[pair][j]['entry_price'] - df[pair]['Close'][i] - df[pair]['spread'][i]) * df[pair]['size'][i]})
                    print(j, 
                         'Short exited after 12 hours:', round(df[pair]['Close'][i], 4),
                         'On day:', df[pair].index[i],
                         'With profit:', round(trade[pair][j]['result'], 4), '\n')
                    open_trade[pair].remove(j)
                    short_take_profit[pair].remove(trade[pair][j]['TP'])
                    short_stop_loss[pair].remove(trade[pair][j]['SL'])
# Out:
# 68 New Short trade at price: 624.598  On day: 2007-01-16 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 68 Short loss at price: 628.667 On day: 2007-01-17 12:00:00 With loss: -18657.75
#
# 143 New Short trade at price: 652.34  On day: 2007-02-01 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 143 Short loss at price: 657.762 On day: 2007-02-01 12:00:00 With loss: -19095.5
#
# 148 New Short trade at price: 655.387  On day: 2007-02-02 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 148 Short profit at price: 644.994 On day: 2007-02-02 12:00:00 With profit: 19130.75
#
# 558 New Short trade at price: 687.993  On day: 2007-05-07 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 558 Short loss at price: 690.228 On day: 2007-05-07 08:00:00 With loss: -15132.5
#
# 682 New Short trade at price: 668.674  On day: 2007-06-04 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 682 Short loss at price: 671.068 On day: 2007-06-04 08:00:00 With loss: -16060.0
#
# 790 New Long trade at price: 644.398  On day: 2007-06-27 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 790 Long profit at price: 646.373 On day: 2007-06-28 08:00:00 With profit: 16695.25
#
# 1110 New Short trade at price: 692.775  On day: 2007-09-07 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1110 Short loss at price: 698.539 On day: 2007-09-07 08:00:00 With loss: -16890.75
#
# 1119 New Short trade at price: 700.795  On day: 2007-09-10 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 1119 Short loss at price: 703.09 On day: 2007-09-11 00:00:00 With loss: -21718.75
#
# 2530 New Long trade at price: 926.048  On day: 2008-07-24 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2530 Long loss at price: 921.485 On day: 2008-07-24 12:00:00 With loss: -39783.25
#
# 2533 New Long trade at price: 926.74  On day: 2008-07-24 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2533 Long profit at price: 931.202 On day: 2008-07-25 00:00:00 With profit: 43975.25
#
# 2604 New Long trade at price: 862.528  On day: 2008-08-11 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2604 Long loss at price: 839.46 On day: 2008-08-11 12:00:00 With loss: -32705.0
#
# 2612 New Long trade at price: 817.565  On day: 2008-08-12 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2612 Long loss at price: 810.681 On day: 2008-08-12 20:00:00 With loss: -48277.75
#
# 2935 New Long trade at price: 721.136  On day: 2008-10-23 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 2935 Long loss at price: 714.124 On day: 2008-10-24 00:00:00 With loss: -69460.0
#
# 3944 New Long trade at price: 953.154  On day: 2009-06-09 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 3944 Long profit at price: 957.367 On day: 2009-06-10 00:00:00 With profit: 41013.0
#
# 4831 New Short trade at price: 1103.773  On day: 2009-12-25 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 4831 Short loss at price: 1107.275 On day: 2009-12-27 20:00:00 With loss: -30758.5
#
# 4839 New Short trade at price: 1102.667  On day: 2009-12-28 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 4839 Short profit at price: 1099.277 On day: 2009-12-29 12:00:00 With profit: 23367.0
#
# 4989 New Long trade at price: 1080.525  On day: 2010-01-29 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 4989 Long loss at price: 1076.407 On day: 2010-02-01 00:00:00 With loss: -36736.0
#
# 5006 New Short trade at price: 1114.32  On day: 2010-02-03 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5006 Short profit at price: 1108.221 On day: 2010-02-03 16:00:00 With profit: 41048.0
#
# 5239 New Short trade at price: 1105.636  On day: 2010-03-29 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5239 Short loss at price: 1111.883 On day: 2010-03-29 04:00:00 With loss: -30286.0
#
# 5384 New Short trade at price: 1165.312  On day: 2010-04-29 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5384 Short loss at price: 1168.519 On day: 2010-04-29 20:00:00 With loss: -30529.5
#
# 5442 New Short trade at price: 1237.685  On day: 2010-05-12 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5442 Short profit at price: 1231.984 On day: 2010-05-13 08:00:00 With profit: 43777.75
#
# 5447 New Short trade at price: 1231.679  On day: 2010-05-13 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5447 Short loss at price: 1238.344 On day: 2010-05-14 04:00:00 With loss: -41613.25
#
# 5544 New Long trade at price: 1205.805  On day: 2010-06-04 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5544 Long profit at price: 1212.475 On day: 2010-06-04 12:00:00 With profit: 27812.75
#
# 5744 New Long trade at price: 1189.709  On day: 2010-07-20 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5744 Long profit at price: 1194.956 On day: 2010-07-21 08:00:00 With profit: 32167.75
#
# 5788 New Long trade at price: 1168.284  On day: 2010-07-29 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 5788 Long profit at price: 1177.292 On day: 2010-07-30 12:00:00 With profit: 29962.75
#
# 6093 New Short trade at price: 1344.515  On day: 2010-10-06 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 6093 Short loss at price: 1353.392 On day: 2010-10-07 00:00:00 With loss: -26623.0
#
# 6410 New Long trade at price: 1375.049  On day: 2010-12-17 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 6410 Long loss at price: 1369.686 On day: 2010-12-17 08:00:00 With loss: -40233.75
#
# 6648 New Short trade at price: 1362.487  On day: 2011-02-09 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 6648 Short profit at price: 1357.492 On day: 2011-02-10 08:00:00 With profit: 27449.5
#
# 7051 New Short trade at price: 1514.974  On day: 2011-05-11 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 7051 Short profit at price: 1502.962 On day: 2011-05-11 12:00:00 With profit: 44915.0
#
# 7136 New Short trade at price: 1536.88  On day: 2011-05-31 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 7136 Short loss at price: 1539.433 On day: 2011-05-31 04:00:00 With loss: -25515.5
#
# 7273 New Short trade at price: 1508.476  On day: 2011-06-30 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 7273 Short profit at price: 1498.885 On day: 2011-06-30 16:00:00 With profit: 30835.0
#
# 7299 New Short trade at price: 1511.347  On day: 2011-07-06 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 7299 Short loss at price: 1528.756 On day: 2011-07-06 12:00:00 With loss: -26361.5
#
# 8459 New Short trade at price: 1689.503  On day: 2012-03-27 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8459 Short profit at price: 1680.252 On day: 2012-03-27 16:00:00 With profit: 46049.0
#
# 8709 New Long trade at price: 1561.236  On day: 2012-05-23 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8709 Long loss at price: 1554.452 On day: 2012-05-24 04:00:00 With loss: -53639.0
#
# 8781 New Long trade at price: 1581.052  On day: 2012-06-08 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8781 Long profit at price: 1594.352 On day: 2012-06-08 16:00:00 With profit: 65997.25
#
# 8809 New Short trade at price: 1621.052  On day: 2012-06-14 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8809 Short loss at price: 1626.034 On day: 2012-06-15 12:00:00 With loss: -45633.5
#
# 8843 New Long trade at price: 1570.657  On day: 2012-06-22 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 8843 Long loss at price: 1563.823 On day: 2012-06-22 12:00:00 With loss: -49084.25
#
# 9116 New Short trade at price: 1658.633  On day: 2012-08-23 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 9116 Short loss at price: 1673.311 On day: 2012-08-23 12:00:00 With loss: -32684.25
#
# 9221 New Short trade at price: 1769.767  On day: 2012-09-17 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 9221 Short profit at price: 1757.681 On day: 2012-09-17 16:00:00 With profit: 47327.25
#
# 9471 New Short trade at price: 1733.952  On day: 2012-11-12 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 9471 Short profit at price: 1727.552 On day: 2012-11-12 16:00:00 With profit: 40112.75
#
# 9791 New Long trade at price: 1671.13  On day: 2013-01-25 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 9791 Long loss at price: 1666.243 On day: 2013-01-25 08:00:00 With loss: -26266.75
#
# 10188 New Short trade at price: 1461.67  On day: 2013-04-26 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10188 Short profit at price: 1455.413 On day: 2013-04-26 12:00:00 With profit: 58554.0
#
# 10435 New Long trade at price: 1290.705  On day: 2013-06-21 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10435 Long profit at price: 1300.261 On day: 2013-06-23 20:00:00 With profit: 63820.25
#
# 10528 New Short trade at price: 1283.5  On day: 2013-07-12 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10528 Short profit at price: 1275.955 On day: 2013-07-12 04:00:00 With profit: 56616.0
#
# 10573 New Short trade at price: 1332.787  On day: 2013-07-23 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10573 Short profit at price: 1328.841 On day: 2013-07-23 08:00:00 With profit: 38148.75
#
# 10653 New Short trade at price: 1309.71  On day: 2013-08-09 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10653 Short loss at price: 1314.153 On day: 2013-08-09 20:00:00 With loss: -44193.25
#
# 10889 New Long trade at price: 1291.553  On day: 2013-10-02 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 10889 Long profit at price: 1315.862 On day: 2013-10-02 12:00:00 With profit: 52590.0
#
# 11113 New Long trade at price: 1248.903  On day: 2013-11-21 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11113 Long loss at price: 1241.823 On day: 2013-11-21 12:00:00 With loss: -34330.0
#
# 11118 New Long trade at price: 1244.133  On day: 2013-11-22 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11118 Long loss at price: 1240.569 On day: 2013-11-24 20:00:00 With loss: -35000.5
#
# 11211 New Long trade at price: 1228.842  On day: 2013-12-13 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11211 Long profit at price: 1236.583 On day: 2013-12-13 12:00:00 With profit: 37539.5
#
# 11330 New Short trade at price: 1246.143  On day: 2014-01-13 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11330 Short loss at price: 1253.142 On day: 2014-01-13 16:00:00 With loss: -32548.75
#
# 11463 New Short trade at price: 1286.831  On day: 2014-02-11 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11463 Short loss at price: 1293.583 On day: 2014-02-12 12:00:00 With loss: -30353.75
#
# 11932 New Long trade at price: 1256.343  On day: 2014-05-29 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 11932 Long loss at price: 1243.361 On day: 2014-05-30 12:00:00 With loss: -24709.25
#
# 12000 New Short trade at price: 1273.492  On day: 2014-06-13 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12000 Short loss at price: 1276.8 On day: 2014-06-13 16:00:00 With loss: -20170.0
#
# 12007 New Short trade at price: 1274.49  On day: 2014-06-16 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12007 Short profit at price: 1271.722 On day: 2014-06-16 16:00:00 With profit: 20976.5
#
# 12134 New Long trade at price: 1309.575  On day: 2014-07-15 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12134 Long loss at price: 1295.28 On day: 2014-07-15 12:00:00 With loss: -30662.5
#
# 12140 New Long trade at price: 1297.485  On day: 2014-07-16 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12140 Long profit at price: 1301.009 On day: 2014-07-16 12:00:00 With profit: 30830.75
#
# 12620 New Long trade at price: 1172.41  On day: 2014-10-31 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12620 Long loss at price: 1166.222 On day: 2014-11-02 20:00:00 With loss: -37192.25
#
# 12623 New Long trade at price: 1170.331  On day: 2014-11-03 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12623 Long loss at price: 1165.071 On day: 2014-11-03 20:00:00 With loss: -41169.75
#
# 12790 New Short trade at price: 1226.942  On day: 2014-12-10 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12790 Short profit at price: 1222.19 On day: 2014-12-11 08:00:00 With profit: 41507.0
#
# 12815 New Long trade at price: 1212.201  On day: 2014-12-16 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12815 Long loss at price: 1191.282 On day: 2014-12-16 12:00:00 With loss: -40737.75
#
# 12906 New Short trade at price: 1212.269  On day: 2015-01-07 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12906 Short profit at price: 1207.449 On day: 2015-01-08 00:00:00 With profit: 39465.0
#
# 12945 New Short trade at price: 1257.332  On day: 2015-01-16 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12945 Short loss at price: 1272.249 On day: 2015-01-16 12:00:00 With loss: -49798.0
#
# 12951 New Short trade at price: 1276.301  On day: 2015-01-19 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 12951 Short loss at price: 1285.919 On day: 2015-01-20 08:00:00 With loss: -49795.25
#
# 13050 New Long trade at price: 1242.97  On day: 2015-02-10 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13050 Long loss at price: 1236.706 On day: 2015-02-10 08:00:00 With loss: -34942.0
#
# 13404 New Long trade at price: 1182.668  On day: 2015-05-01 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13404 Long loss at price: 1179.671 On day: 2015-05-01 08:00:00 With loss: -29618.0
#
# 13521 New Long trade at price: 1187.538  On day: 2015-05-28 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13521 Long profit at price: 1189.948 On day: 2015-05-28 04:00:00 With profit: 17787.0
#
# 13899 New Short trade at price: 1153.602  On day: 2015-08-21 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 13899 Short loss at price: 1160.409 On day: 2015-08-21 12:00:00 With loss: -30242.0
#
# 14091 New Short trade at price: 1137.451  On day: 2015-10-05 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14091 Short profit at price: 1132.198 On day: 2015-10-05 08:00:00 With profit: 28006.25
#
# 14246 New Long trade at price: 1093.748  On day: 2015-11-09 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14246 Long loss at price: 1089.918 On day: 2015-11-09 12:00:00 With loss: -25647.5
#
# 14251 New Long trade at price: 1092.818  On day: 2015-11-09 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14251 Long loss at price: 1088.349 On day: 2015-11-10 12:00:00 With loss: -23117.75
#
# 14504 New Short trade at price: 1103.368  On day: 2016-01-08 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14504 Short profit at price: 1099.291 On day: 2016-01-08 08:00:00 With profit: 30014.0
#
# 14812 New Short trade at price: 1256.72  On day: 2016-03-17 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14812 Short loss at price: 1263.89 On day: 2016-03-18 00:00:00 With loss: -45536.5
#
# 14917 New Short trade at price: 1256.781  On day: 2016-04-12 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 14917 Short profit at price: 1252.959 On day: 2016-04-13 00:00:00 With profit: 32022.25
#
# 15394 New Short trade at price: 1333.971  On day: 2016-07-28 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15394 Short loss at price: 1340.42 On day: 2016-07-29 00:00:00 With loss: -32323.0
#
# 15521 New Long trade at price: 1323.908  On day: 2016-08-26 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15521 Long profit at price: 1327.739 On day: 2016-08-26 08:00:00 With profit: 21171.0
#
# 15920 New Long trade at price: 1187.132  On day: 2016-11-24 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 15920 Long loss at price: 1178.021 On day: 2016-11-25 00:00:00 With loss: -33979.0
#
# 16320 New Short trade at price: 1255.821  On day: 2017-02-26 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16320 Short loss at price: 1259.679 On day: 2017-02-27 12:00:00 With loss: -22135.25
#
# 16325 New Short trade at price: 1255.168  On day: 2017-02-27 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16325 Short profit at price: 1252.848 On day: 2017-02-28 08:00:00 With profit: 22977.25
#
# 16412 New Short trade at price: 1228.528  On day: 2017-03-17 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16412 Short loss at price: 1231.261 On day: 2017-03-19 20:00:00 With loss: -24818.75
#
# 16528 New Short trade at price: 1284.089  On day: 2017-04-13 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16528 Short loss at price: 1287.921 On day: 2017-04-13 16:00:00 With loss: -26709.5
#
# 16533 New Short trade at price: 1288.931  On day: 2017-04-17 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16533 Short profit at price: 1283.838 On day: 2017-04-17 16:00:00 With profit: 26417.5
#
# 16619 New Long trade at price: 1233.639  On day: 2017-05-05 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16619 Long loss at price: 1228.479 On day: 2017-05-05 12:00:00 With loss: -22497.75
#
# 16675 New Short trade at price: 1258.351  On day: 2017-05-18 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 16675 Short profit at price: 1255.601 On day: 2017-05-18 12:00:00 With profit: 24882.25
#
# 17057 New Short trade at price: 1288.258  On day: 2017-08-11 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17057 Short profit at price: 1283.071 On day: 2017-08-14 04:00:00 With profit: 24223.5
#
# 17221 New Long trade at price: 1309.502  On day: 2017-09-19 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17221 Long profit at price: 1312.532 On day: 2017-09-20 04:00:00 With profit: 26393.5
#
# 17549 New Long trade at price: 1276.282  On day: 2017-12-01 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17549 Long profit at price: 1282.312 On day: 2017-12-01 16:00:00 With profit: 19860.75
#
# 17567 New Long trade at price: 1268.111  On day: 2017-12-06 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17567 Long loss at price: 1263.432 On day: 2017-12-06 12:00:00 With loss: -21782.25
#
# 17678 New Short trade at price: 1314.071  On day: 2018-01-03 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17678 Short loss at price: 1316.501 On day: 2018-01-03 12:00:00 With loss: -19969.25
#
# 17732 New Short trade at price: 1339.938  On day: 2018-01-15 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17732 Short profit at price: 1335.008 On day: 2018-01-16 08:00:00 With profit: 21696.25
#
# 17897 New Long trade at price: 1328.151  On day: 2018-02-21 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 17897 Long loss at price: 1323.892 On day: 2018-02-22 00:00:00 With loss: -24222.5
#
# 18027 New Short trade at price: 1329.872  On day: 2018-03-22 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18027 Short loss at price: 1332.678 On day: 2018-03-22 20:00:00 With loss: -26296.25
#
# 18060 New Long trade at price: 1326.409  On day: 2018-03-29 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18060 Long profit at price: 1329.298 On day: 2018-04-02 00:00:00 With profit: 24905.5
#
# 18262 New Long trade at price: 1295.489  On day: 2018-05-16 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18262 Long loss at price: 1288.638 On day: 2018-05-16 08:00:00 With loss: -21114.25
#
# 18266 New Long trade at price: 1291.739  On day: 2018-05-16 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18266 Long loss at price: 1288.348 On day: 2018-05-17 08:00:00 With loss: -21905.75
#
# 18271 New Long trade at price: 1291.021  On day: 2018-05-17 16:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18271 Long loss at price: 1288.448 On day: 2018-05-21 00:00:00 With loss: -24284.75
#
# 18925 New Short trade at price: 1218.562  On day: 2018-10-12 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 18925 Short loss at price: 1221.591 On day: 2018-10-12 08:00:00 With loss: -26032.25
#
# 19728 New Long trade at price: 1288.605  On day: 2019-04-15 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 19728 Long loss at price: 1285.185 On day: 2019-04-16 00:00:00 With loss: -18614.25
#
# 20023 New Short trade at price: 1384.358  On day: 2019-06-21 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 20023 Short loss at price: 1395.065 On day: 2019-06-21 08:00:00 With loss: -47635.25
#
# 20309 New Short trade at price: 1530.488  On day: 2019-08-26 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 20309 Short loss at price: 1542.258 On day: 2019-08-27 12:00:00 With loss: -44209.0
#
# 21090 New Short trade at price: 1607.175  On day: 2020-02-20 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 21090 Short loss at price: 1617.425 On day: 2020-02-20 08:00:00 With loss: -24470.75
#
# 21270 New Long trade at price: 1595.768  On day: 2020-04-01 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 21270 Long loss at price: 1588.365 On day: 2020-04-01 08:00:00 With loss: -69108.75
#
# 21783 New Short trade at price: 1943.548  On day: 2020-07-28 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 21783 Short profit at price: 1913.015 On day: 2020-07-28 04:00:00 With profit: 78033.0
#
# 21852 New Long trade at price: 1936.468  On day: 2020-08-12 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 21852 Long loss at price: 1908.005 On day: 2020-08-12 16:00:00 With loss: -124321.5
#
# 22124 New Short trade at price: 1911.345  On day: 2020-10-13 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22124 Short loss at price: 1918.528 On day: 2020-10-13 04:00:00 With loss: -45354.25
#
# 22317 New Long trade at price: 1809.988  On day: 2020-11-25 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22317 Long exited after 12 hours: 1809.908 On day: 2020-11-27 04:00:00 With profit: -802.0
#
# 22488 New Short trade at price: 1942.045  On day: 2021-01-06 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22488 Short loss at price: 1947.765 On day: 2021-01-06 04:00:00 With loss: -50810.5
#
# 22873 New Short trade at price: 1724.838  On day: 2021-04-05 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22873 Short loss at price: 1730.328 On day: 2021-04-05 12:00:00 With loss: -45366.75
#
# 22934 New Short trade at price: 1776.675  On day: 2021-04-18 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22934 Short loss at price: 1786.905 On day: 2021-04-19 04:00:00 With loss: -37003.25
#
# 22938 New Short trade at price: 1772.097  On day: 2021-04-19 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22938 Short loss at price: 1778.638 On day: 2021-04-20 12:00:00 With loss: -43546.75
#
# 22954 New Short trade at price: 1791.22  On day: 2021-04-22 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 22954 Short profit at price: 1786.085 On day: 2021-04-22 08:00:00 With profit: 40814.5
#
# 23028 New Short trade at price: 1832.498  On day: 2021-05-10 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23028 Short loss at price: 1841.038 On day: 2021-05-10 08:00:00 With loss: -41100.0
#
# 23159 New Short trade at price: 1892.568  On day: 2021-06-08 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23159 Short loss at price: 1899.968 On day: 2021-06-08 08:00:00 With loss: -43815.75
#
# 23161 New Short trade at price: 1891.155  On day: 2021-06-08 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23161 Short profit at price: 1877.408 On day: 2021-06-10 04:00:00 With profit: 46255.75
#
# 23568 New Long trade at price: 1798.857  On day: 2021-09-08 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23568 Long loss at price: 1791.877 On day: 2021-09-08 12:00:00 With loss: -30112.75
#
# 23599 New Short trade at price: 1801.855  On day: 2021-09-15 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23599 Short profit at price: 1793.818 On day: 2021-09-15 12:00:00 With profit: 34041.5
#
# 23913 New Long trade at price: 1789.528  On day: 2021-11-24 20:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 23913 Long profit at price: 1796.928 On day: 2021-11-26 00:00:00 With profit: 48585.25
#
# 24285 New Short trade at price: 1890.938  On day: 2022-02-18 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24285 Short loss at price: 1897.768 On day: 2022-02-18 20:00:00 With loss: -46947.0
#
# 24399 New Long trade at price: 1924.498  On day: 2022-03-16 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24399 Long loss at price: 1911.578 On day: 2022-03-16 12:00:00 With loss: -68523.0
#
# 24692 New Short trade at price: 1851.888  On day: 2022-05-23 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24692 Short loss at price: 1859.929 On day: 2022-05-24 04:00:00 With loss: -46895.5
#
# 24735 New Long trade at price: 1845.468  On day: 2022-06-01 12:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24735 Long profit at price: 1851.058 On day: 2022-06-02 04:00:00 With profit: 39195.0
#
# 24893 New Long trade at price: 1745.698  On day: 2022-07-07 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 24893 Long loss at price: 1739.678 On day: 2022-07-07 12:00:00 With loss: -47995.75
#
# 25290 New Short trade at price: 1719.224  On day: 2022-10-05 00:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25290 Short profit at price: 1706.088 On day: 2022-10-05 08:00:00 With profit: 52063.75
#
# 25317 New Long trade at price: 1670.086  On day: 2022-10-11 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25317 Long profit at price: 1681.448 On day: 2022-10-11 12:00:00 With profit: 44649.75
#
# 25447 New Short trade at price: 1708.668  On day: 2022-11-09 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25447 Short loss at price: 1750.798 On day: 2022-11-10 12:00:00 With loss: -51564.25
#
# 25676 New Short trade at price: 1833.088  On day: 2023-01-03 08:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25676 Short loss at price: 1838.955 On day: 2023-01-03 16:00:00 With loss: -44288.25
#
# 25731 New Short trade at price: 1917.018  On day: 2023-01-16 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25731 Short profit at price: 1910.215 On day: 2023-01-17 00:00:00 With profit: 50139.0
#
# 25960 New Long trade at price: 1814.135  On day: 2023-03-08 04:00:00 Pair: XAUUSD/XAUUSD_H4 - XAUUSD_H4
# 25960 Long profit at price: 1820.555 On day: 2023-03-08 12:00:00 With profit: 36904.5

# %%
pairs_results = {}
profits = {}
losses = {}
be = {}

for pair in range(len(pairs_list)):
    profits[pair] = []
    losses[pair] = []
    be[pair] = []
    
    pairs_results[pair] = pd.DataFrame.from_dict({(i, j): trade[pair][j] for j in trade[pair].keys()}, orient = 'index')
    pairs_results[pair] = pairs_results[pair].drop(['signal', 'ID', 'TP', 'SL'], axis = 1)
    pairs_results[pair].set_index('date_of_trade', inplace = True)
    pairs_results[pair]['cum_res'] = pairs_results[pair]['result'].cumsum() + account_size
    
    for t in trade[pair]:
        profits[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] > 0.1 else ''
        losses[pair].append(trade[pair][t]['result']) if trade[pair][t]['result'] < -0.1 else ''
        be[pair].append(trade[pair][t]['result']) if -0.1 <= trade[pair][t]['result'] <= 0.1 else ''
        
my_reduce = partial(pd.merge, on = 'date_of_trade', how = 'outer')
strategy_results = reduce(my_reduce, pairs_results.values())
strategy_results = strategy_results.sort_index()
strategy_results['final_res'] = strategy_results.filter(like = 'result', axis = 1).sum(axis = 1)
strategy_results['cum_res'] = strategy_results['final_res'].cumsum() + account_size

profits_keys = list(profits.keys())
profits_values = [profits[x] for x in profits_keys]
str_profits = list(flatten(profits_values))

losses_keys = list(losses.keys())
losses_values = [losses[x] for x in losses_keys]
str_losses = list(flatten(losses_values))

be_keys = list(be.keys())
be_values = [be[x] for x in be_keys]
str_be = list(flatten(be_values))

# %%
plt.figure(figsize = (26, 10))
for pair in range(len(pairs_list)):
    plt.plot(pairs_results[pair]['cum_res'], label = pairs_list[pair])
plt.legend()
plt.title('Returns of each pair', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Returns of each pair')

# %%
#Strategy performance
print('***** STRATEGY PERFORMANCE *****')
print('--------------------------------')
print('Number of trades:', len(str_profits + str_losses + str_be))
print('Number of profits:', len(str_profits))
print('Number of losses:', len(str_losses))
print('Number of breakevens:', len(str_be), '\n')
print('Winning percentage', (round(len(str_profits) / (len(str_profits) + len(str_losses)) * 100, 2)), '%')
print('ROI:', round(strategy_results['cum_res'][-1]) - account_size)
print('--------------------------------')
print('Average profitable trade:', round(sum(str_profits) / len(str_profits), 2))
print('Average lossing trade:', round(sum(str_losses) / len(str_losses), 2))
print('Max profitable trade:', round(max(str_profits), 2))
print('Max lossing trade:', round(min(str_losses), 2))

plt.figure(figsize = (26, 6))
plt.plot(strategy_results['cum_res'])
plt.title('return of strategy', fontsize = 18)
# Out:
# ***** STRATEGY PERFORMANCE *****
# --------------------------------
# Number of trades: 128
# Number of profits: 50
# Number of losses: 78
# Number of breakevens: 0
#
# Winning percentage 39.06 %
# ROI: -921344
# --------------------------------
# Average profitable trade: 37054.46
# Average lossing trade: -35564.96
# Max profitable trade: 78033.0
# Max lossing trade: -124321.5
# Text(0.5, 1.0, 'return of strategy')
